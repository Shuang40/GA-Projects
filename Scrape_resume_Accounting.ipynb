# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Capstone - Resumes and Job Ads Recommender

# %% [markdown]
# # Problem Statement
#
# HR practitioners and/or hiring managers could have been spending too much time trying to sieve through many resumes for shortlisting suitable candidates whom they can contact for interview.
# As a job seeker, we may also find ourselves spending so much times looking through plentiful job advertisements which may not be relevant to us.
# Wouldn't it be nice if pre-selection can be done which will effectively save time for all of us?
#
# We will be using Natural Language Processing and Recommender System to group similar job seekers / job advertisements.
# Success will be evaluated by the (TBD on model) to match the job the grouped job seekers to the most suitable job advertisements and vice versa.

# %% [markdown]
# # Executive Summary
#
# We scrape the website spiderjob.com for resumes. In view that api key is not available, we used BeautifulSoup and regex to get the desired information. As we encounter roadblock on the time connection timeout despite introducing bot agent, we limit the job categories to Accounting and Information Technology for this capstone.
# For the job ads, we based it on existing dataset that is available on Kaggle which was used for predicting fake job posting since the features in this dataset has 80% simiarity to the resumes dataset.
#
# As we were cleaning the resumes dataset, we at the same made decision which features will be important for us to have and which are the one to drop. In view that job title, objective, experience and skills are free texts that hold meaningful words for our analysis, we create a new feature and combine all where we then split the text into words, return them to their root form and also remove the stop words. These are performed for the job ads dataset.
#
# TBC.....
#
#
# ### Contents:
# - [Scraping of resumes - Accounting](#Scraping-of-resumes---Accounting)

# %% [markdown]
# ## Scraping of resumes - Accounting

# %%
import requests
import pandas as pd
import regex as re
import numpy as np
import random
import time
from bs4 import BeautifulSoup

# %%
# Check if the link if working well for scraping
url = 'https://www.jobspider.com/job/resume-search-results.asp/category_1'
res = requests.get(url)
res
# Out:
# <Response [200]>

# %%
# %%time

# Scraping thru the table of contents
# Create an empty table for storing the scrape items
table = []

# To iterate thru pagination 
for num in range(1,31):
    link = url + '/page_' + str(num)
    res = requests.get(link)
    soup = BeautifulSoup(res.content, 'lxml')
    tbody = soup.find_all('td', align='center')
    
    # As there are 6 items listed in the ('td', align='center'), splitting the len of the post for iteration by group of 6
    for i in range(int(len(tbody)/6)):
        items = {}
        items['sn'] = tbody[6*int(i) + 0].text
        items['date_posted'] = tbody[6*int(i)+1].text
        items['job_func_sought'] = tbody[6*int(i)+2].text.lower()
        items['category'] = tbody[6*int(i)+3].text
        items['location'] = tbody[6*int(i)+4].text
        items['resume_href'] = tbody[6*int(i)+5].find('a')['href']
        
        table.append(items)
table
# Out:
# Wall time: 42.5 s
# [{'sn': '1',
#   'date_posted': '3/30/2020',
#   'job_func_sought': 'bookkeeping/accounting',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Dartmouth, NS',
#   'resume_href': '/job/view-resume-82533.html'},
#  {'sn': '2',
#   'date_posted': '3/16/2020',
#   'job_func_sought': 'stainless steel decorative sheet',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Xian, AL',
#   'resume_href': '/job/view-resume-82510.html'},
#  {'sn': '3',
#   'date_posted': '3/4/2020',
#   'job_func_sought': 'accountant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Orlando, FL',
#   'resume_href': '/job/view-resume-82487.html'},
#  {'sn': '4',
#   'date_posted': '2/27/2020',
#   'job_func_sought': 'admin assistant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Brampton, ON',
#   'resume_href': '/job/view-resume-82476.html'},
#  {'sn': '5',
#   'date_posted': '2/27/2020',
#   'job_func_sought': 'admin assistant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Brampton, ON',
#   'resume_href': '/job/view-resume-82475.html'},
#  {'sn': '6',
#   'date_posted': '2/22/2020',
#   'job_func_sought': 'auditor',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Houston, TX',
#   'resume_href': '/job/view-resume-82470.html'},
#  {'sn': '7',
#   'date_posted': '2/11/2020',
#   'job_func_sought': 'senior accountant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Columbus, OH',
#   'resume_href': '/job/view-resume-82450.html'},
#  {'sn': '8',
#   'date_posted': '2/8/2020',
#   'job_func_sought': ' recruiter for mba-hr fresher',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Bareilly, IN',
#   'resume_href': '/job/view-resume-82440.html'},
#  {'sn': '9',
#   'date_posted': '2/8/2020',
#   'job_func_sought': ' required: diploma, b.e/b.tech (cs/it), bca, mca. ',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Bareilly, IN',
#   'resume_href': '/job/view-resume-82439.html'},
#  {'sn': '10',
#   'date_posted': '2/7/2020',
#   'job_func_sought': 'we have job opening for accounts executive accounts assistant who has an experie',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Bareilly, IN',
#   'resume_href': '/job/view-resume-82436.html'},
#  {'sn': '11',
#   'date_posted': '1/31/2020',
#   'job_func_sought': 'fresher candidates with good communication ',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'bareilly Uttar Pradesh, IN',
#   'resume_href': '/job/view-resume-82424.html'},
#  {'sn': '12',
#   'date_posted': '1/31/2020',
#   'job_func_sought': 'senior/mid-level financial services manager',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Duncanville, TX',
#   'resume_href': '/job/view-resume-82423.html'},
#  {'sn': '13',
#   'date_posted': '1/16/2020',
#   'job_func_sought': ' brokerage operations',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'QUEENS, NY',
#   'resume_href': '/job/view-resume-82397.html'},
#  {'sn': '14',
#   'date_posted': '1/9/2020',
#   'job_func_sought': 'accounting technician/bookkeeping',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Burnaby, BC',
#   'resume_href': '/job/view-resume-82369.html'},
#  {'sn': '15',
#   'date_posted': '12/16/2019',
#   'job_func_sought': 'full charge bookkeeper',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Canon City, CO',
#   'resume_href': '/job/view-resume-82338.html'},
#  {'sn': '16',
#   'date_posted': '12/6/2019',
#   'job_func_sought': 'accounting bookkeeper',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Toronto, ON',
#   'resume_href': '/job/view-resume-82324.html'},
#  {'sn': '17',
#   'date_posted': '12/1/2019',
#   'job_func_sought': 'accountant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Ondangwa, QC',
#   'resume_href': '/job/view-resume-82313.html'},
#  {'sn': '18',
#   'date_posted': '11/14/2019',
#   'job_func_sought': 'remote bookkeeper or ranch management',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Hayfork, CA',
#   'resume_href': '/job/view-resume-82293.html'},
#  {'sn': '19',
#   'date_posted': '10/28/2019',
#   'job_func_sought': 'financial analyst',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Bayonne, NJ',
#   'resume_href': '/job/view-resume-82266.html'},
#  {'sn': '20',
#   'date_posted': '10/3/2019',
#   'job_func_sought': 'loan seeker',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Birmingham, WY',
#   'resume_href': '/job/view-resume-82232.html'},
#  {'sn': '21',
#   'date_posted': '10/3/2019',
#   'job_func_sought': 'loan seeker',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Birmingham, WY',
#   'resume_href': '/job/view-resume-82231.html'},
#  {'sn': '22',
#   'date_posted': '10/1/2019',
#   'job_func_sought': '장성출장안마がㅋr톡am555',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'NewYork, AL',
#   'resume_href': '/job/view-resume-82226.html'},
#  {'sn': '23',
#   'date_posted': '9/10/2019',
#   'job_func_sought': 'accountant , auditor',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Middletown, NY',
#   'resume_href': '/job/view-resume-82183.html'},
#  {'sn': '24',
#   'date_posted': '7/24/2019',
#   'job_func_sought': 'clerk ',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Cultus Lake, BC',
#   'resume_href': '/job/view-resume-82118.html'},
#  {'sn': '25',
#   'date_posted': '6/28/2019',
#   'job_func_sought': 'product manager',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Mumbai, IN',
#   'resume_href': '/job/view-resume-82082.html'},
#  {'sn': '26',
#   'date_posted': '6/26/2019',
#   'job_func_sought': 'data clerk',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Alpharetta, GA',
#   'resume_href': '/job/view-resume-82080.html'},
#  {'sn': '27',
#   'date_posted': '5/12/2019',
#   'job_func_sought': 'best office chair parts',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'dfdf, AK',
#   'resume_href': '/job/view-resume-82008.html'},
#  {'sn': '28',
#   'date_posted': '5/12/2019',
#   'job_func_sought': 'roller door hardwares price',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'sdsds, AL',
#   'resume_href': '/job/view-resume-82000.html'},
#  {'sn': '29',
#   'date_posted': '4/30/2019',
#   'job_func_sought': 'data entire',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'new york, NY',
#   'resume_href': '/job/view-resume-81985.html'},
#  {'sn': '30',
#   'date_posted': '4/26/2019',
#   'job_func_sought': 'accounting specialist',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Cleveland, OH',
#   'resume_href': '/job/view-resume-81980.html'},
#  {'sn': '31',
#   'date_posted': '3/29/2019',
#   'job_func_sought': 'financial analyst',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Anaheim, CA',
#   'resume_href': '/job/view-resume-81922.html'},
#  {'sn': '32',
#   'date_posted': '3/14/2019',
#   'job_func_sought': 'full or part time bookkeeping accounting',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Greenville, SC',
#   'resume_href': '/job/view-resume-81888.html'},
#  {'sn': '33',
#   'date_posted': '2/27/2019',
#   'job_func_sought': 'accounting manager',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Fullerton, CA',
#   'resume_href': '/job/view-resume-81854.html'},
#  {'sn': '34',
#   'date_posted': '2/20/2019',
#   'job_func_sought': 'account or controller',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Arlington, TX',
#   'resume_href': '/job/view-resume-81838.html'},
#  {'sn': '35',
#   'date_posted': '2/16/2019',
#   'job_func_sought': 'administrative assistant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Danville, QC',
#   'resume_href': '/job/view-resume-81828.html'},
#  {'sn': '36',
#   'date_posted': '2/8/2019',
#   'job_func_sought': 'acounting technician/ bookkeeping',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Port Angeles, WA',
#   'resume_href': '/job/view-resume-81799.html'},
#  {'sn': '37',
#   'date_posted': '1/3/2019',
#   'job_func_sought': 'senior business analyst/controller | strategy analyst | senior financial analyst',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Dallas, TX',
#   'resume_href': '/job/view-resume-81732.html'},
#  {'sn': '38',
#   'date_posted': '12/19/2018',
#   'job_func_sought': 'business process and controls senior consultant | risk and financial auditor',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Queen Creek, AZ',
#   'resume_href': '/job/view-resume-81706.html'},
#  {'sn': '39',
#   'date_posted': '12/12/2018',
#   'job_func_sought': 'accountant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Minneapolis, MN',
#   'resume_href': '/job/view-resume-81689.html'},
#  {'sn': '40',
#   'date_posted': '12/12/2018',
#   'job_func_sought': 'accountant ',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Bronxville, NY',
#   'resume_href': '/job/view-resume-81686.html'},
#  {'sn': '41',
#   'date_posted': '11/29/2018',
#   'job_func_sought': 'accounting',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Westerville, OH',
#   'resume_href': '/job/view-resume-81652.html'},
#  {'sn': '42',
#   'date_posted': '11/25/2018',
#   'job_func_sought': 'accountant/auditor',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Rapid City, SD',
#   'resume_href': '/job/view-resume-81648.html'},
#  {'sn': '43',
#   'date_posted': '11/15/2018',
#   'job_func_sought': 'administrative bookkeeper office manager ',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Saint Cloud, MN',
#   'resume_href': '/job/view-resume-81625.html'},
#  {'sn': '44',
#   'date_posted': '11/10/2018',
#   'job_func_sought': 'personal assistant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'canifonia, CA',
#   'resume_href': '/job/view-resume-81615.html'},
#  {'sn': '45',
#   'date_posted': '11/7/2018',
#   'job_func_sought': 'accountant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Fort Smith, AR',
#   'resume_href': '/job/view-resume-81603.html'},
#  {'sn': '46',
#   'date_posted': '10/30/2018',
#   'job_func_sought': 'bookkeeper',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Abbotsford, BC',
#   'resume_href': '/job/view-resume-81580.html'},
#  {'sn': '47',
#   'date_posted': '10/23/2018',
#   'job_func_sought': 'accounting clerk',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'New York, NY',
#   'resume_href': '/job/view-resume-81556.html'},
#  {'sn': '48',
#   'date_posted': '9/18/2018',
#   'job_func_sought': 'financial controller',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Lincoln Park, NJ',
#   'resume_href': '/job/view-resume-81455.html'},
#  {'sn': '49',
#   'date_posted': '9/16/2018',
#   'job_func_sought': 'accountant/bookkeeper',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'baltimore, MD',
#   'resume_href': '/job/view-resume-81439.html'},
#  {'sn': '50',
#   'date_posted': '9/4/2018',
#   'job_func_sought': 'hotmail customer service number  1-800-725-7732',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Altamonte Springs, FL',
#   'resume_href': '/job/view-resume-81407.html'},
#  {'sn': '51',
#   'date_posted': '8/27/2018',
#   'job_func_sought': 'account manager',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Indianapolis, IN',
#   'resume_href': '/job/view-resume-81377.html'},
#  {'sn': '52',
#   'date_posted': '8/27/2018',
#   'job_func_sought': 'storekeeper',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Victoria, BC',
#   'resume_href': '/job/view-resume-81372.html'},
#  {'sn': '53',
#   'date_posted': '8/16/2018',
#   'job_func_sought': 'indhira pradeep - accounts payable clerk',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'TORONTO, ON',
#   'resume_href': '/job/view-resume-81344.html'},
#  {'sn': '54',
#   'date_posted': '7/31/2018',
#   'job_func_sought': 'account  manager',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Brick, NJ',
#   'resume_href': '/job/view-resume-81289.html'},
#  {'sn': '55',
#   'date_posted': '7/12/2018',
#   'job_func_sought': 'accounting',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Bethlehem Village, CT',
#   'resume_href': '/job/view-resume-81211.html'},
#  {'sn': '56',
#   'date_posted': '7/5/2018',
#   'job_func_sought': 'accountant/financier',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Frederick, MD',
#   'resume_href': '/job/view-resume-81189.html'},
#  {'sn': '57',
#   'date_posted': '7/5/2018',
#   'job_func_sought': 'accountant/financier',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Frederick, MD',
#   'resume_href': '/job/view-resume-81188.html'},
#  {'sn': '58',
#   'date_posted': '7/5/2018',
#   'job_func_sought': 'accountant/financier',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Frederick, MD',
#   'resume_href': '/job/view-resume-81187.html'},
#  {'sn': '59',
#   'date_posted': '7/5/2018',
#   'job_func_sought': 'accountant/financier',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Frederick, MD',
#   'resume_href': '/job/view-resume-81186.html'},
#  {'sn': '60',
#   'date_posted': '7/5/2018',
#   'job_func_sought': 'accountant/financier',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Frederick, MD',
#   'resume_href': '/job/view-resume-81185.html'},
#  {'sn': '61',
#   'date_posted': '7/5/2018',
#   'job_func_sought': 'accountant/financier',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Frederick, MD',
#   'resume_href': '/job/view-resume-81184.html'},
#  {'sn': '62',
#   'date_posted': '7/5/2018',
#   'job_func_sought': 'accountant/financier',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Frederick, MD',
#   'resume_href': '/job/view-resume-81183.html'},
#  {'sn': '63',
#   'date_posted': '6/18/2018',
#   'job_func_sought': 'bookkeeper',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Vancouver, BC',
#   'resume_href': '/job/view-resume-81093.html'},
#  {'sn': '64',
#   'date_posted': '6/4/2018',
#   'job_func_sought': 'accounts payable specialist',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Temple Hills, MD',
#   'resume_href': '/job/view-resume-81047.html'},
#  {'sn': '65',
#   'date_posted': '6/4/2018',
#   'job_func_sought': 'accounting manager',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Hamilton, ON',
#   'resume_href': '/job/view-resume-81046.html'},
#  {'sn': '66',
#   'date_posted': '5/19/2018',
#   'job_func_sought': 'entry level accounts payable',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'New York, NY',
#   'resume_href': '/job/view-resume-81000.html'},
#  {'sn': '67',
#   'date_posted': '5/7/2018',
#   'job_func_sought': 'director of financial services & capital markets',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Frankfort, IL',
#   'resume_href': '/job/view-resume-80962.html'},
#  {'sn': '68',
#   'date_posted': '4/10/2018',
#   'job_func_sought': 'bookkeeper, accountant, cashier',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Toronto, ON',
#   'resume_href': '/job/view-resume-80847.html'},
#  {'sn': '69',
#   'date_posted': '4/6/2018',
#   'job_func_sought': 'accountant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'New Freedom, PA',
#   'resume_href': '/job/view-resume-80841.html'},
#  {'sn': '70',
#   'date_posted': '3/7/2018',
#   'job_func_sought': 'director of finance / accounting / reporting',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Strongsville, OH',
#   'resume_href': '/job/view-resume-80736.html'},
#  {'sn': '71',
#   'date_posted': '3/7/2018',
#   'job_func_sought': 'director of finance / accounting / reporting',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Strongsville, OH',
#   'resume_href': '/job/view-resume-80735.html'},
#  {'sn': '72',
#   'date_posted': '3/1/2018',
#   'job_func_sought': 'financial analyst',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Springfield, IL',
#   'resume_href': '/job/view-resume-80701.html'},
#  {'sn': '73',
#   'date_posted': '2/14/2018',
#   'job_func_sought': 'bookkeeping',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Calhan, CO',
#   'resume_href': '/job/view-resume-80619.html'},
#  {'sn': '74',
#   'date_posted': '2/1/2018',
#   'job_func_sought': 'accounting',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Warman, SK',
#   'resume_href': '/job/view-resume-80558.html'},
#  {'sn': '75',
#   'date_posted': '1/25/2018',
#   'job_func_sought': 'billing/accounts receivable manager',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Frisco, TX',
#   'resume_href': '/job/view-resume-80525.html'},
#  {'sn': '76',
#   'date_posted': '1/15/2018',
#   'job_func_sought': 'examiner-market regulation-tfce',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Jericho, NY',
#   'resume_href': '/job/view-resume-80475.html'},
#  {'sn': '77',
#   'date_posted': '1/15/2018',
#   'job_func_sought': 'a/p, a/r, data entry and administrative',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Cleveland, Ohio, OH',
#   'resume_href': '/job/view-resume-80472.html'},
#  {'sn': '78',
#   'date_posted': '12/31/2017',
#   'job_func_sought': 'database developer',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Lewis Center, OH',
#   'resume_href': '/job/view-resume-80387.html'},
#  {'sn': '79',
#   'date_posted': '12/25/2017',
#   'job_func_sought': 'staff accounting',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Detroit, MI',
#   'resume_href': '/job/view-resume-80351.html'},
#  {'sn': '80',
#   'date_posted': '12/4/2017',
#   'job_func_sought': 'assistant controller/senior accountant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Phoenix, AZ',
#   'resume_href': '/job/view-resume-80266.html'},
#  {'sn': '81',
#   'date_posted': '11/26/2017',
#   'job_func_sought': 'accountant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Landing, NJ',
#   'resume_href': '/job/view-resume-80230.html'},
#  {'sn': '82',
#   'date_posted': '11/26/2017',
#   'job_func_sought': 'accountant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Landing, NJ',
#   'resume_href': '/job/view-resume-80229.html'},
#  {'sn': '83',
#   'date_posted': '11/8/2017',
#   'job_func_sought': 'administrative assistant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'PA, PA',
#   'resume_href': '/job/view-resume-80135.html'},
#  {'sn': '84',
#   'date_posted': '11/2/2017',
#   'job_func_sought': 'accounting/administration',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Westerville, OH',
#   'resume_href': '/job/view-resume-80102.html'},
#  {'sn': '85',
#   'date_posted': '11/1/2017',
#   'job_func_sought': 'accountant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Astoria, NY',
#   'resume_href': '/job/view-resume-80100.html'},
#  {'sn': '86',
#   'date_posted': '10/24/2017',
#   'job_func_sought': 'accounting',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Frisco, TX',
#   'resume_href': '/job/view-resume-80067.html'},
#  {'sn': '87',
#   'date_posted': '10/19/2017',
#   'job_func_sought': 'purchasing manager | accounting manager',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Miami, FL',
#   'resume_href': '/job/view-resume-80045.html'},
#  {'sn': '88',
#   'date_posted': '9/19/2017',
#   'job_func_sought': 'staff accountant | financial analyst',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Midlothian, VA',
#   'resume_href': '/job/view-resume-79925.html'},
#  {'sn': '89',
#   'date_posted': '9/19/2017',
#   'job_func_sought': 'accounting clerk',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Tempe, AZ',
#   'resume_href': '/job/view-resume-79921.html'},
#  {'sn': '90',
#   'date_posted': '9/5/2017',
#   'job_func_sought': 'assistant controller',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Merrick, NY',
#   'resume_href': '/job/view-resume-79864.html'},
#  {'sn': '91',
#   'date_posted': '9/5/2017',
#   'job_func_sought': 'senior accountant or senior financial analyst',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Elgin, IL',
#   'resume_href': '/job/view-resume-79860.html'},
#  {'sn': '92',
#   'date_posted': '9/4/2017',
#   'job_func_sought': 'bonnie  swan - billing analyst',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Arlington, TX',
#   'resume_href': '/job/view-resume-79855.html'},
#  {'sn': '93',
#   'date_posted': '8/25/2017',
#   'job_func_sought': 'staff accountant ',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Levittown, PA',
#   'resume_href': '/job/view-resume-79814.html'},
#  {'sn': '94',
#   'date_posted': '8/13/2017',
#   'job_func_sought': 'accountant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Appleton, WI',
#   'resume_href': '/job/view-resume-79744.html'},
#  {'sn': '95',
#   'date_posted': '8/2/2017',
#   'job_func_sought': 'accountant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Los Angeles, CA',
#   'resume_href': '/job/view-resume-79690.html'},
#  {'sn': '96',
#   'date_posted': '7/11/2017',
#   'job_func_sought': 'accountant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Arnoldsville, GA',
#   'resume_href': '/job/view-resume-79561.html'},
#  {'sn': '97',
#   'date_posted': '7/7/2017',
#   'job_func_sought': 'finance and operations',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'New York, NY',
#   'resume_href': '/job/view-resume-79552.html'},
#  {'sn': '98',
#   'date_posted': '7/4/2017',
#   'job_func_sought': 'accounting | bookkeeping | finance',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Lynchburg, VA',
#   'resume_href': '/job/view-resume-79523.html'},
#  {'sn': '99',
#   'date_posted': '7/2/2017',
#   'job_func_sought': 'accountant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Lamesa, TX',
#   'resume_href': '/job/view-resume-79509.html'},
#  {'sn': '100',
#   'date_posted': '6/28/2017',
#   'job_func_sought': 'senior accountant | real estate investment accountant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Alexandria, VA',
#   'resume_href': '/job/view-resume-79491.html'},
#  {'sn': '101',
#   'date_posted': '6/27/2017',
#   'job_func_sought': 'senior accountant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Houston, TX',
#   'resume_href': '/job/view-resume-79485.html'},
#  {'sn': '102',
#   'date_posted': '6/22/2017',
#   'job_func_sought': 'accounting intern',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Flushing, NY',
#   'resume_href': '/job/view-resume-79461.html'},
#  {'sn': '103',
#   'date_posted': '6/22/2017',
#   'job_func_sought': 'controller',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Toronto, ON',
#   'resume_href': '/job/view-resume-79459.html'},
#  {'sn': '104',
#   'date_posted': '6/8/2017',
#   'job_func_sought': 'a/r, a/p, payroll',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Streetsboro, OH',
#   'resume_href': '/job/view-resume-79376.html'},
#  {'sn': '105',
#   'date_posted': '6/7/2017',
#   'job_func_sought': 'robert boyd - finance and accounts receivable',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Toronto, ON',
#   'resume_href': '/job/view-resume-79370.html'},
#  {'sn': '106',
#   'date_posted': '5/22/2017',
#   'job_func_sought': 'tax director',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Sioux Falls, SD',
#   'resume_href': '/job/view-resume-79304.html'},
#  {'sn': '107',
#   'date_posted': '5/21/2017',
#   'job_func_sought': '--senior accountant--',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Hebron, OH',
#   'resume_href': '/job/view-resume-79297.html'},
#  {'sn': '108',
#   'date_posted': '5/15/2017',
#   'job_func_sought': 'accountant / bookkeeper',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Spring, TX',
#   'resume_href': '/job/view-resume-79284.html'},
#  {'sn': '109',
#   'date_posted': '5/10/2017',
#   'job_func_sought': 'accountant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Rogers, AR',
#   'resume_href': '/job/view-resume-79268.html'},
#  {'sn': '110',
#   'date_posted': '5/2/2017',
#   'job_func_sought': 'audit associate | tax associate | staff accountant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Charlotte, CA',
#   'resume_href': '/job/view-resume-79224.html'},
#  {'sn': '111',
#   'date_posted': '4/19/2017',
#   'job_func_sought': 'accountant, cfo, enrolled agent',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Andover, MN',
#   'resume_href': '/job/view-resume-79146.html'},
#  {'sn': '112',
#   'date_posted': '4/2/2017',
#   'job_func_sought': 'administrative assistant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Appleton, WI',
#   'resume_href': '/job/view-resume-79055.html'},
#  {'sn': '113',
#   'date_posted': '3/23/2017',
#   'job_func_sought': 'associate member',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'kathmandu, AL',
#   'resume_href': '/job/view-resume-79001.html'},
#  {'sn': '114',
#   'date_posted': '3/8/2017',
#   'job_func_sought': 'account manager',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Atlanta, GA',
#   'resume_href': '/job/view-resume-78923.html'},
#  {'sn': '115',
#   'date_posted': '2/10/2017',
#   'job_func_sought': 'accountant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Washington, DC',
#   'resume_href': '/job/view-resume-78786.html'},
#  {'sn': '116',
#   'date_posted': '2/1/2017',
#   'job_func_sought': 'accounting',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'kozhikode, Kerala, India, IN',
#   'resume_href': '/job/view-resume-78742.html'},
#  {'sn': '117',
#   'date_posted': '1/22/2017',
#   'job_func_sought': 'book keeping',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'kandy, NY',
#   'resume_href': '/job/view-resume-78679.html'},
#  {'sn': '118',
#   'date_posted': '1/16/2017',
#   'job_func_sought': 'accountant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'albany, AL',
#   'resume_href': '/job/view-resume-78641.html'},
#  {'sn': '119',
#   'date_posted': '1/15/2017',
#   'job_func_sought': 'income tax manager/tax accounting manager',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Huntersville, NC',
#   'resume_href': '/job/view-resume-78638.html'},
#  {'sn': '120',
#   'date_posted': '12/22/2016',
#   'job_func_sought': 'staff accountant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Dacula, GA',
#   'resume_href': '/job/view-resume-78533.html'},
#  {'sn': '121',
#   'date_posted': '12/10/2016',
#   'job_func_sought': 'accounts receivables positions',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Irving, TX',
#   'resume_href': '/job/view-resume-78482.html'},
#  {'sn': '122',
#   'date_posted': '11/29/2016',
#   'job_func_sought': 'accounts receivable/collections',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Milwaukee, WI',
#   'resume_href': '/job/view-resume-78438.html'},
#  {'sn': '123',
#   'date_posted': '11/29/2016',
#   'job_func_sought': 'accounts payable/bookkeeping',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Calgary, AB',
#   'resume_href': '/job/view-resume-78432.html'},
#  {'sn': '124',
#   'date_posted': '11/22/2016',
#   'job_func_sought': 'internal auditing',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'New York, NY',
#   'resume_href': '/job/view-resume-78402.html'},
#  {'sn': '125',
#   'date_posted': '11/18/2016',
#   'job_func_sought': 'regulatory reporting/internal auditing',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'New York, NY',
#   'resume_href': '/job/view-resume-78374.html'},
#  {'sn': '126',
#   'date_posted': '11/11/2016',
#   'job_func_sought': 'accounting',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Philadelphia, PA',
#   'resume_href': '/job/view-resume-78347.html'},
#  {'sn': '127',
#   'date_posted': '11/6/2016',
#   'job_func_sought': 'accounting supervisor',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Canyon Country, CA',
#   'resume_href': '/job/view-resume-78318.html'},
#  {'sn': '128',
#   'date_posted': '10/26/2016',
#   'job_func_sought': 'webmethods',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Herndon, VA',
#   'resume_href': '/job/view-resume-78271.html'},
#  {'sn': '129',
#   'date_posted': '10/25/2016',
#   'job_func_sought': 'accounts payable',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Langley, BC',
#   'resume_href': '/job/view-resume-78267.html'},
#  {'sn': '130',
#   'date_posted': '10/25/2016',
#   'job_func_sought': 'controller/general accounting manager',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Houston, TX',
#   'resume_href': '/job/view-resume-78260.html'},
#  {'sn': '131',
#   'date_posted': '10/20/2016',
#   'job_func_sought': 'virtual bookkeeper/full charge bookkeeper',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Murphy, NC',
#   'resume_href': '/job/view-resume-78241.html'},
#  {'sn': '132',
#   'date_posted': '10/11/2016',
#   'job_func_sought': 'accounting',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Concord, NH',
#   'resume_href': '/job/view-resume-78187.html'},
#  {'sn': '133',
#   'date_posted': '9/13/2016',
#   'job_func_sought': 'bookkeeper/entry level accountant, edmonton, alberta',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Edmonton, AB',
#   'resume_href': '/job/view-resume-78031.html'},
#  {'sn': '134',
#   'date_posted': '8/21/2016',
#   'job_func_sought': 'accounts payable accountant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Oakton, VA',
#   'resume_href': '/job/view-resume-77905.html'},
#  {'sn': '135',
#   'date_posted': '8/21/2016',
#   'job_func_sought': 'bookkeeper',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'cresco, PA',
#   'resume_href': '/job/view-resume-77901.html'},
#  {'sn': '136',
#   'date_posted': '8/17/2016',
#   'job_func_sought': 'accountant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Louisville, KY',
#   'resume_href': '/job/view-resume-77885.html'},
#  {'sn': '137',
#   'date_posted': '8/10/2016',
#   'job_func_sought': 'accountant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Santa Clara, CA',
#   'resume_href': '/job/view-resume-77847.html'},
#  {'sn': '138',
#   'date_posted': '8/7/2016',
#   'job_func_sought': 'staff accountant/ tax analyst',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Plano, TX',
#   'resume_href': '/job/view-resume-77829.html'},
#  {'sn': '139',
#   'date_posted': '8/1/2016',
#   'job_func_sought': 'accounting/finance intership',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Wallington, NJ',
#   'resume_href': '/job/view-resume-77770.html'},
#  {'sn': '140',
#   'date_posted': '7/31/2016',
#   'job_func_sought': 'accountant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Cincinnati, OH',
#   'resume_href': '/job/view-resume-77767.html'},
#  {'sn': '141',
#   'date_posted': '7/26/2016',
#   'job_func_sought': 'assistant controller / accounting manager',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Rockville, MD',
#   'resume_href': '/job/view-resume-77742.html'},
#  {'sn': '142',
#   'date_posted': '7/17/2016',
#   'job_func_sought': 'account manager/account coordinator/project management',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Canonsburg, PA',
#   'resume_href': '/job/view-resume-77676.html'},
#  {'sn': '143',
#   'date_posted': '7/16/2016',
#   'job_func_sought': 'all field',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'High Springs, FL',
#   'resume_href': '/job/view-resume-77672.html'},
#  {'sn': '144',
#   'date_posted': '7/14/2016',
#   'job_func_sought': 'medical/health',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'South San Francisco,, CA',
#   'resume_href': '/job/view-resume-77659.html'},
#  {'sn': '145',
#   'date_posted': '7/14/2016',
#   'job_func_sought': 'medical/health',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'South San Francisco,, CA',
#   'resume_href': '/job/view-resume-77658.html'},
#  {'sn': '146',
#   'date_posted': '7/14/2016',
#   'job_func_sought': 'medical/health',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Lake Forest,, CA',
#   'resume_href': '/job/view-resume-77650.html'},
#  {'sn': '147',
#   'date_posted': '7/6/2016',
#   'job_func_sought': 'accountant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Buffalo Springs, TX',
#   'resume_href': '/job/view-resume-77595.html'},
#  {'sn': '148',
#   'date_posted': '6/23/2016',
#   'job_func_sought': 'customer service/ sales',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Gulf Shores, AL',
#   'resume_href': '/job/view-resume-77534.html'},
#  {'sn': '149',
#   'date_posted': '6/21/2016',
#   'job_func_sought': 'administrative assistance',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Applewood, CO',
#   'resume_href': '/job/view-resume-77523.html'},
#  {'sn': '150',
#   'date_posted': '6/17/2016',
#   'job_func_sought': 'administrative/ accounting assistant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'DAVAO CITY, PA',
#   'resume_href': '/job/view-resume-77512.html'},
#  {'sn': '151',
#   'date_posted': '6/1/2016',
#   'job_func_sought': 'senior accountant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Alexandria, VA',
#   'resume_href': '/job/view-resume-77437.html'},
#  {'sn': '152',
#   'date_posted': '5/23/2016',
#   'job_func_sought': 'dynamics gp consultant/reporting',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Fort Worth, TX',
#   'resume_href': '/job/view-resume-77391.html'},
#  {'sn': '153',
#   'date_posted': '5/11/2016',
#   'job_func_sought': 'staff accountant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Vienna, VA',
#   'resume_href': '/job/view-resume-77347.html'},
#  {'sn': '154',
#   'date_posted': '5/2/2016',
#   'job_func_sought': 'data entry',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Anywhere in USA, FL',
#   'resume_href': '/job/view-resume-77309.html'},
#  {'sn': '155',
#   'date_posted': '4/28/2016',
#   'job_func_sought': 'staff accountant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Marlborough, MA',
#   'resume_href': '/job/view-resume-77297.html'},
#  {'sn': '156',
#   'date_posted': '4/26/2016',
#   'job_func_sought': 'accountant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Longview, WA',
#   'resume_href': '/job/view-resume-77284.html'},
#  {'sn': '157',
#   'date_posted': '4/20/2016',
#   'job_func_sought': 'customer service ',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'New York, NY',
#   'resume_href': '/job/view-resume-77256.html'},
#  {'sn': '158',
#   'date_posted': '4/20/2016',
#   'job_func_sought': 'finance/accounting',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Orlando, FL',
#   'resume_href': '/job/view-resume-77254.html'},
#  {'sn': '159',
#   'date_posted': '4/14/2016',
#   'job_func_sought': 'ap/ar, customer service, office administration',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Columbus, OH',
#   'resume_href': '/job/view-resume-77219.html'},
#  {'sn': '160',
#   'date_posted': '4/12/2016',
#   'job_func_sought': 'accounts receivable',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Augusta-Richmond County, GA',
#   'resume_href': '/job/view-resume-77203.html'},
#  {'sn': '161',
#   'date_posted': '3/27/2016',
#   'job_func_sought': 'bookkeeping/accounting',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'San Diego, CA',
#   'resume_href': '/job/view-resume-77135.html'},
#  {'sn': '162',
#   'date_posted': '3/18/2016',
#   'job_func_sought': 'credit collections specialist',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'New York, NY',
#   'resume_href': '/job/view-resume-77098.html'},
#  {'sn': '163',
#   'date_posted': '3/7/2016',
#   'job_func_sought': 'customer relation',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Arcadia, FL',
#   'resume_href': '/job/view-resume-77033.html'},
#  {'sn': '164',
#   'date_posted': '3/6/2016',
#   'job_func_sought': 'financial analyst',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Delano, CA',
#   'resume_href': '/job/view-resume-77031.html'},
#  {'sn': '165',
#   'date_posted': '3/1/2016',
#   'job_func_sought': 'accountant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Rockville, MD',
#   'resume_href': '/job/view-resume-77004.html'},
#  {'sn': '166',
#   'date_posted': '2/29/2016',
#   'job_func_sought': 'marketing executive',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Indian Heights, IN',
#   'resume_href': '/job/view-resume-76993.html'},
#  {'sn': '167',
#   'date_posted': '2/22/2016',
#   'job_func_sought': 'accounting/bookeeping',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Cook County, IL',
#   'resume_href': '/job/view-resume-76967.html'},
#  {'sn': '168',
#   'date_posted': '2/11/2016',
#   'job_func_sought': 'receivables analyst, credit analyst, collections',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Concord, NH',
#   'resume_href': '/job/view-resume-76899.html'},
#  {'sn': '169',
#   'date_posted': '2/5/2016',
#   'job_func_sought': 'accounting',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Dorval, QC',
#   'resume_href': '/job/view-resume-76869.html'},
#  {'sn': '170',
#   'date_posted': '2/5/2016',
#   'job_func_sought': 'accountant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Sanger, CA',
#   'resume_href': '/job/view-resume-76868.html'},
#  {'sn': '171',
#   'date_posted': '2/3/2016',
#   'job_func_sought': 'accountant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Herndon, VA',
#   'resume_href': '/job/view-resume-76843.html'},
#  {'sn': '172',
#   'date_posted': '1/30/2016',
#   'job_func_sought': 'administrative assistant / data entry / clerical specialist',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Fort Lauderdale, FL',
#   'resume_href': '/job/view-resume-76821.html'},
#  {'sn': '173',
#   'date_posted': '1/22/2016',
#   'job_func_sought': 'bookkeeping',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Sanger, CA',
#   'resume_href': '/job/view-resume-76776.html'},
#  {'sn': '174',
#   'date_posted': '1/21/2016',
#   'job_func_sought': 'project controller, cost analyst, project accountant, assistant controller',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Saint Paul, MN',
#   'resume_href': '/job/view-resume-76768.html'},
#  {'sn': '175',
#   'date_posted': '1/18/2016',
#   'job_func_sought': 'inside sales',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Austin, TX',
#   'resume_href': '/job/view-resume-76747.html'},
#  {'sn': '176',
#   'date_posted': '1/10/2016',
#   'job_func_sought': 'accounts payable ',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Aurora, OH',
#   'resume_href': '/job/view-resume-76711.html'},
#  {'sn': '177',
#   'date_posted': '1/5/2016',
#   'job_func_sought': 'receptionist',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Parlier, CA',
#   'resume_href': '/job/view-resume-76683.html'},
#  {'sn': '178',
#   'date_posted': '12/18/2015',
#   'job_func_sought': 'senior financial analyst',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Los Angeles, CA',
#   'resume_href': '/job/view-resume-76649.html'},
#  {'sn': '179',
#   'date_posted': '12/13/2015',
#   'job_func_sought': 'cost accounting clerk',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Saint louis, MO',
#   'resume_href': '/job/view-resume-76627.html'},
#  {'sn': '180',
#   'date_posted': '12/12/2015',
#   'job_func_sought': 'student',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Kensington, PE',
#   'resume_href': '/job/view-resume-76624.html'},
#  {'sn': '181',
#   'date_posted': '12/10/2015',
#   'job_func_sought': 'sr. accountant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Varna, IL',
#   'resume_href': '/job/view-resume-76614.html'},
#  {'sn': '182',
#   'date_posted': '12/9/2015',
#   'job_func_sought': 'controller',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Scranton, PA',
#   'resume_href': '/job/view-resume-76605.html'},
#  {'sn': '183',
#   'date_posted': '11/29/2015',
#   'job_func_sought': 'auditor',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Camp Hill, PA',
#   'resume_href': '/job/view-resume-76563.html'},
#  {'sn': '184',
#   'date_posted': '11/26/2015',
#   'job_func_sought': 'enterprise account executive',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Wilmington, NC',
#   'resume_href': '/job/view-resume-76559.html'},
#  {'sn': '185',
#   'date_posted': '11/10/2015',
#   'job_func_sought': 'accounting assistance',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'wabash, IN',
#   'resume_href': '/job/view-resume-76495.html'},
#  {'sn': '186',
#   'date_posted': '10/19/2015',
#   'job_func_sought': 'management analyst',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Washington, DC',
#   'resume_href': '/job/view-resume-76379.html'},
#  {'sn': '187',
#   'date_posted': '10/18/2015',
#   'job_func_sought': 'accounting clerk',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Saint Albans, NY',
#   'resume_href': '/job/view-resume-76367.html'},
#  {'sn': '188',
#   'date_posted': '10/16/2015',
#   'job_func_sought': 'bookkeeper',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'orland park, IL',
#   'resume_href': '/job/view-resume-76364.html'},
#  {'sn': '189',
#   'date_posted': '10/13/2015',
#   'job_func_sought': 'manager',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Gallup, NM',
#   'resume_href': '/job/view-resume-76342.html'},
#  {'sn': '190',
#   'date_posted': '10/7/2015',
#   'job_func_sought': 'accountant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Pompton Lakes, NJ',
#   'resume_href': '/job/view-resume-76315.html'},
#  {'sn': '191',
#   'date_posted': '10/6/2015',
#   'job_func_sought': 'banking,finances,insurance',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Midland, MI',
#   'resume_href': '/job/view-resume-76306.html'},
#  {'sn': '192',
#   'date_posted': '9/16/2015',
#   'job_func_sought': 'account manager',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Claremont, CA',
#   'resume_href': '/job/view-resume-76183.html'},
#  {'sn': '193',
#   'date_posted': '9/15/2015',
#   'job_func_sought': 'controller',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'VICTORVILLE, CA',
#   'resume_href': '/job/view-resume-76172.html'},
#  {'sn': '194',
#   'date_posted': '8/26/2015',
#   'job_func_sought': 'entry level',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Newark, DE',
#   'resume_href': '/job/view-resume-76053.html'},
#  {'sn': '195',
#   'date_posted': '8/14/2015',
#   'job_func_sought': 'senior manager',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'New York, NY',
#   'resume_href': '/job/view-resume-75987.html'},
#  {'sn': '196',
#   'date_posted': '7/27/2015',
#   'job_func_sought': 'accounts payable analyst',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Mississauga, ON',
#   'resume_href': '/job/view-resume-75873.html'},
#  {'sn': '197',
#   'date_posted': '7/7/2015',
#   'job_func_sought': 'entry level accountant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Daly City, CA',
#   'resume_href': '/job/view-resume-75737.html'},
#  {'sn': '198',
#   'date_posted': '7/6/2015',
#   'job_func_sought': 'staff accountant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Beaverton, OR',
#   'resume_href': '/job/view-resume-75722.html'},
#  {'sn': '199',
#   'date_posted': '7/1/2015',
#   'job_func_sought': 'accountant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Cincinnati, OH',
#   'resume_href': '/job/view-resume-75683.html'},
#  {'sn': '200',
#   'date_posted': '6/30/2015',
#   'job_func_sought': 'office assistant/admin assistant/clerical',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'San Jose, CA',
#   'resume_href': '/job/view-resume-75677.html'},
#  {'sn': '201',
#   'date_posted': '6/24/2015',
#   'job_func_sought': 'business analyst',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Waltham, MA',
#   'resume_href': '/job/view-resume-75650.html'},
#  {'sn': '202',
#   'date_posted': '6/17/2015',
#   'job_func_sought': 'bookkeeper or junior accountant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Surrey, BC',
#   'resume_href': '/job/view-resume-75599.html'},
#  {'sn': '203',
#   'date_posted': '6/3/2015',
#   'job_func_sought': 'forensic accountant manager',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Houston, TX',
#   'resume_href': '/job/view-resume-75511.html'},
#  {'sn': '204',
#   'date_posted': '6/2/2015',
#   'job_func_sought': 'accountant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Boca Raton, FL',
#   'resume_href': '/job/view-resume-75497.html'},
#  {'sn': '205',
#   'date_posted': '5/27/2015',
#   'job_func_sought': 'bookkeeping, a/r a/p',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Piermont, NY',
#   'resume_href': '/job/view-resume-75465.html'},
#  {'sn': '206',
#   'date_posted': '5/27/2015',
#   'job_func_sought': 'controller',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Ajax, ON',
#   'resume_href': '/job/view-resume-75464.html'},
#  {'sn': '207',
#   'date_posted': '5/22/2015',
#   'job_func_sought': 'office clerk ',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Shawano, WI',
#   'resume_href': '/job/view-resume-75441.html'},
#  {'sn': '208',
#   'date_posted': '5/18/2015',
#   'job_func_sought': 'account manager',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Kansas City, MO',
#   'resume_href': '/job/view-resume-75410.html'},
#  {'sn': '209',
#   'date_posted': '5/13/2015',
#   'job_func_sought': 'customer service representative',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Fort Lauderdale, FL',
#   'resume_href': '/job/view-resume-75385.html'},
#  {'sn': '210',
#   'date_posted': '5/10/2015',
#   'job_func_sought': 'collections, call center',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Mississauga, ON',
#   'resume_href': '/job/view-resume-75356.html'},
#  {'sn': '211',
#   'date_posted': '5/6/2015',
#   'job_func_sought': 'senior accountant and consultant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Milton, WI',
#   'resume_href': '/job/view-resume-75335.html'},
#  {'sn': '212',
#   'date_posted': '5/4/2015',
#   'job_func_sought': 'accounting specialist (ar/ap)',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Sunnyvale, CA',
#   'resume_href': '/job/view-resume-75323.html'},
#  {'sn': '213',
#   'date_posted': '5/4/2015',
#   'job_func_sought': 'accountant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Boca Raton, FL',
#   'resume_href': '/job/view-resume-75320.html'},
#  {'sn': '214',
#   'date_posted': '5/4/2015',
#   'job_func_sought': 'bookkeeper',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Rocky Mount, VA',
#   'resume_href': '/job/view-resume-75317.html'},
#  {'sn': '215',
#   'date_posted': '4/28/2015',
#   'job_func_sought': 'bookkeeper',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Jacksonville, FL',
#   'resume_href': '/job/view-resume-75279.html'},
#  {'sn': '216',
#   'date_posted': '4/21/2015',
#   'job_func_sought': 'accountant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Boca Raton, FL',
#   'resume_href': '/job/view-resume-75211.html'},
#  {'sn': '217',
#   'date_posted': '4/20/2015',
#   'job_func_sought': 'accounting or mortgage lending',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'RIVERSIDE, CA',
#   'resume_href': '/job/view-resume-75209.html'},
#  {'sn': '218',
#   'date_posted': '4/20/2015',
#   'job_func_sought': 'part-time accountant/consultant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Fishkill, NY',
#   'resume_href': '/job/view-resume-75208.html'},
#  {'sn': '219',
#   'date_posted': '4/16/2015',
#   'job_func_sought': 'accountant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Memphis, TN',
#   'resume_href': '/job/view-resume-75178.html'},
#  {'sn': '220',
#   'date_posted': '4/9/2015',
#   'job_func_sought': 'senior financial analyst',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Temecula, CA',
#   'resume_href': '/job/view-resume-75121.html'},
#  {'sn': '221',
#   'date_posted': '4/6/2015',
#   'job_func_sought': 'accountant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Raleigh, NC',
#   'resume_href': '/job/view-resume-75106.html'},
#  {'sn': '222',
#   'date_posted': '4/6/2015',
#   'job_func_sought': 'supervisory accountant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Jackson, WY',
#   'resume_href': '/job/view-resume-75103.html'},
#  {'sn': '223',
#   'date_posted': '4/5/2015',
#   'job_func_sought': 'ar, credit, collections,',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'New York, NY',
#   'resume_href': '/job/view-resume-75090.html'},
#  {'sn': '224',
#   'date_posted': '4/3/2015',
#   'job_func_sought': 'accountant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Brooklyn, NY',
#   'resume_href': '/job/view-resume-75082.html'},
#  {'sn': '225',
#   'date_posted': '3/26/2015',
#   'job_func_sought': 'accounting assistant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Rosedale, NY',
#   'resume_href': '/job/view-resume-75007.html'},
#  {'sn': '226',
#   'date_posted': '3/25/2015',
#   'job_func_sought': 'senior staff accountant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Patchogue, NY',
#   'resume_href': '/job/view-resume-74990.html'},
#  {'sn': '227',
#   'date_posted': '3/24/2015',
#   'job_func_sought': 'contractor/accounting',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Wilmington, DE',
# ...
#   'resume_href': '/job/view-resume-51863.html'},
#  {'sn': '926',
#   'date_posted': '6/14/2011',
#   'job_func_sought': 'accounting manager',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Santa Rosa, CA',
#   'resume_href': '/job/view-resume-51793.html'},
#  {'sn': '927',
#   'date_posted': '6/14/2011',
#   'job_func_sought': 'accounts payable supervisor',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Willowbrook, IL',
#   'resume_href': '/job/view-resume-51792.html'},
#  {'sn': '928',
#   'date_posted': '6/14/2011',
#   'job_func_sought': 'administrative assistant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'elk grove village, IL',
#   'resume_href': '/job/view-resume-51773.html'},
#  {'sn': '929',
#   'date_posted': '6/14/2011',
#   'job_func_sought': 'administrative assistant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'elk grove village, IL',
#   'resume_href': '/job/view-resume-51772.html'},
#  {'sn': '930',
#   'date_posted': '6/14/2011',
#   'job_func_sought': 'administrative assistant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'elk grove village, IL',
#   'resume_href': '/job/view-resume-51771.html'},
#  {'sn': '931',
#   'date_posted': '6/14/2011',
#   'job_func_sought': 'accounts receivables ',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Alexandria, VA',
#   'resume_href': '/job/view-resume-51764.html'},
#  {'sn': '932',
#   'date_posted': '6/13/2011',
#   'job_func_sought': 'accounting',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Sacramento, CA',
#   'resume_href': '/job/view-resume-51746.html'},
#  {'sn': '933',
#   'date_posted': '6/13/2011',
#   'job_func_sought': 'collection specialist',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'houston, TX',
#   'resume_href': '/job/view-resume-51732.html'},
#  {'sn': '934',
#   'date_posted': '6/13/2011',
#   'job_func_sought': 'customer service',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Louisburg, NC',
#   'resume_href': '/job/view-resume-51731.html'},
#  {'sn': '935',
#   'date_posted': '6/12/2011',
#   'job_func_sought': 'staff accountant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Seattle, WA',
#   'resume_href': '/job/view-resume-51708.html'},
#  {'sn': '936',
#   'date_posted': '6/11/2011',
#   'job_func_sought': 'accounting manager/controller',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Sarasota, FL',
#   'resume_href': '/job/view-resume-51681.html'},
#  {'sn': '937',
#   'date_posted': '6/10/2011',
#   'job_func_sought': 'accounts payable/ receivable',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'orlando, FL',
#   'resume_href': '/job/view-resume-51672.html'},
#  {'sn': '938',
#   'date_posted': '6/10/2011',
#   'job_func_sought': 'bookkeeping/office management',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Middletown, CT',
#   'resume_href': '/job/view-resume-51661.html'},
#  {'sn': '939',
#   'date_posted': '6/10/2011',
#   'job_func_sought': 'accounts payable specialist',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Southern Pines, NC',
#   'resume_href': '/job/view-resume-51657.html'},
#  {'sn': '940',
#   'date_posted': '6/9/2011',
#   'job_func_sought': 'high level',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Siliguri, AL',
#   'resume_href': '/job/view-resume-51648.html'},
#  {'sn': '941',
#   'date_posted': '6/9/2011',
#   'job_func_sought': 'part / full time job on internet',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'sillugri, TX',
#   'resume_href': '/job/view-resume-51630.html'},
#  {'sn': '942',
#   'date_posted': '6/9/2011',
#   'job_func_sought': 'administrative assistant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Wilmington, DE',
#   'resume_href': '/job/view-resume-51628.html'},
#  {'sn': '943',
#   'date_posted': '6/8/2011',
#   'job_func_sought': 'accounting',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Houston, TX',
#   'resume_href': '/job/view-resume-51598.html'},
#  {'sn': '944',
#   'date_posted': '6/7/2011',
#   'job_func_sought': 'cfo/audit director',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Sarasota, FL',
#   'resume_href': '/job/view-resume-51568.html'},
#  {'sn': '945',
#   'date_posted': '6/7/2011',
#   'job_func_sought': 'cpa',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Roseland, NJ',
#   'resume_href': '/job/view-resume-51552.html'},
#  {'sn': '946',
#   'date_posted': '6/6/2011',
#   'job_func_sought': 'bank attendant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'california city, CA',
#   'resume_href': '/job/view-resume-51539.html'},
#  {'sn': '947',
#   'date_posted': '6/6/2011',
#   'job_func_sought': 'corporate office personnel job',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Sarasota, FL',
#   'resume_href': '/job/view-resume-51531.html'},
#  {'sn': '948',
#   'date_posted': '6/5/2011',
#   'job_func_sought': 'senior accountant-cpa firm',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Brooklyn, NY',
#   'resume_href': '/job/view-resume-51506.html'},
#  {'sn': '949',
#   'date_posted': '6/5/2011',
#   'job_func_sought': 'a powerful online opportunity',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Siliguri, AL',
#   'resume_href': '/job/view-resume-51497.html'},
#  {'sn': '950',
#   'date_posted': '6/5/2011',
#   'job_func_sought': 'bookkeeper, accountant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Tampa, FL',
#   'resume_href': '/job/view-resume-51494.html'},
#  {'sn': '951',
#   'date_posted': '6/4/2011',
#   'job_func_sought': 'a+ technician, systems analyst, project manager, trainer,',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Wausau, WI',
#   'resume_href': '/job/view-resume-51491.html'},
#  {'sn': '952',
#   'date_posted': '6/1/2011',
#   'job_func_sought': 'accounting/finance',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Atlanta, GA',
#   'resume_href': '/job/view-resume-51410.html'},
#  {'sn': '953',
#   'date_posted': '6/1/2011',
#   'job_func_sought': 'accountant/auditor',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Milwaukee, WI',
#   'resume_href': '/job/view-resume-51388.html'},
#  {'sn': '954',
#   'date_posted': '5/31/2011',
#   'job_func_sought': 'manageral',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Alpharetta, GA',
#   'resume_href': '/job/view-resume-51362.html'},
#  {'sn': '955',
#   'date_posted': '5/31/2011',
#   'job_func_sought': 'accounting manager',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Houston, TX',
#   'resume_href': '/job/view-resume-51359.html'},
#  {'sn': '956',
#   'date_posted': '5/31/2011',
#   'job_func_sought': 'accountant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Atlanta, GA',
#   'resume_href': '/job/view-resume-51346.html'},
#  {'sn': '957',
#   'date_posted': '5/26/2011',
#   'job_func_sought': 'accountant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Hollywood, FL',
#   'resume_href': '/job/view-resume-51251.html'},
#  {'sn': '958',
#   'date_posted': '5/24/2011',
#   'job_func_sought': 'accounting',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Highlands Ranch, CT',
#   'resume_href': '/job/view-resume-51179.html'},
#  {'sn': '959',
#   'date_posted': '5/24/2011',
#   'job_func_sought': 'senior accountant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Philadelphia, PA',
#   'resume_href': '/job/view-resume-51169.html'},
#  {'sn': '960',
#   'date_posted': '5/20/2011',
#   'job_func_sought': 'staff accountant / fc bookkeeper',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Winter Haven, FL',
#   'resume_href': '/job/view-resume-51069.html'},
#  {'sn': '961',
#   'date_posted': '5/19/2011',
#   'job_func_sought': 'accountant ',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Lakeland, FL',
#   'resume_href': '/job/view-resume-51050.html'},
#  {'sn': '962',
#   'date_posted': '5/18/2011',
#   'job_func_sought': 'bookkeeper',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Delray Beach, FL',
#   'resume_href': '/job/view-resume-50996.html'},
#  {'sn': '963',
#   'date_posted': '5/18/2011',
#   'job_func_sought': 'clerk accountant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Tampa, FL',
#   'resume_href': '/job/view-resume-50994.html'},
#  {'sn': '964',
#   'date_posted': '5/18/2011',
#   'job_func_sought': 'account payable',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'sanjose, CA',
#   'resume_href': '/job/view-resume-50990.html'},
#  {'sn': '965',
#   'date_posted': '5/17/2011',
#   'job_func_sought': 'accountant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Miami, FL',
#   'resume_href': '/job/view-resume-50946.html'},
#  {'sn': '966',
#   'date_posted': '5/16/2011',
#   'job_func_sought': 'accounting',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Newark, NJ',
#   'resume_href': '/job/view-resume-50924.html'},
#  {'sn': '967',
#   'date_posted': '5/14/2011',
#   'job_func_sought': 'mystery shopper',
#   'category': 'Accounting/Bookkeeping',
#   'location': '46031, GA',
#   'resume_href': '/job/view-resume-50882.html'},
#  {'sn': '968',
#   'date_posted': '5/13/2011',
#   'job_func_sought': 'auditor',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Shreveport, LA',
#   'resume_href': '/job/view-resume-50851.html'},
#  {'sn': '969',
#   'date_posted': '5/12/2011',
#   'job_func_sought': 'lockbox',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Jersey City, NJ',
#   'resume_href': '/job/view-resume-50822.html'},
#  {'sn': '970',
#   'date_posted': '5/10/2011',
#   'job_func_sought': 'accounting',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'St. Paul, MN',
#   'resume_href': '/job/view-resume-50750.html'},
#  {'sn': '971',
#   'date_posted': '5/9/2011',
#   'job_func_sought': 'adminstrative assistant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'houston, TX',
#   'resume_href': '/job/view-resume-50741.html'},
#  {'sn': '972',
#   'date_posted': '5/9/2011',
#   'job_func_sought': 'internship',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'palatine, IL',
#   'resume_href': '/job/view-resume-50735.html'},
#  {'sn': '973',
#   'date_posted': '5/8/2011',
#   'job_func_sought': 'senior accountant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Garden City, NY',
#   'resume_href': '/job/view-resume-50705.html'},
#  {'sn': '974',
#   'date_posted': '5/5/2011',
#   'job_func_sought': 'uknown',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Unknown, IN',
#   'resume_href': '/job/view-resume-50641.html'},
#  {'sn': '975',
#   'date_posted': '5/3/2011',
#   'job_func_sought': 'account executive/sales operations-technology',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Confidential, CA',
#   'resume_href': '/job/view-resume-50607.html'},
#  {'sn': '976',
#   'date_posted': '5/3/2011',
#   'job_func_sought': 'accounts payable',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'South Plainfield, NJ',
#   'resume_href': '/job/view-resume-50571.html'},
#  {'sn': '977',
#   'date_posted': '5/2/2011',
#   'job_func_sought': 'senior reinsurance accountant/ar/ap accountant/collection accountant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Hoffman Estates, IL',
#   'resume_href': '/job/view-resume-50565.html'},
#  {'sn': '978',
#   'date_posted': '5/1/2011',
#   'job_func_sought': 'accounts payable',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Anaheim, CA',
#   'resume_href': '/job/view-resume-50522.html'},
#  {'sn': '979',
#   'date_posted': '4/29/2011',
#   'job_func_sought': 'accountant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'cleveland, OH',
#   'resume_href': '/job/view-resume-50489.html'},
#  {'sn': '980',
#   'date_posted': '4/27/2011',
#   'job_func_sought': 'cfo/controller-manufacturing,/services/distribution',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Onalaska, WI',
#   'resume_href': '/job/view-resume-50447.html'},
#  {'sn': '981',
#   'date_posted': '4/27/2011',
#   'job_func_sought': 'accounting',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Memphis, TN',
#   'resume_href': '/job/view-resume-50434.html'},
#  {'sn': '982',
#   'date_posted': '4/26/2011',
#   'job_func_sought': 'accounting, admiminstrative, collections',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'nashville, TN',
#   'resume_href': '/job/view-resume-50400.html'},
#  {'sn': '983',
#   'date_posted': '4/23/2011',
#   'job_func_sought': 'take surveys from home earn $200 per day (id:182)',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Abbeville, AL',
#   'resume_href': '/job/view-resume-50303.html'},
#  {'sn': '984',
#   'date_posted': '4/22/2011',
#   'job_func_sought': 'accounting',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Atmore, AL',
#   'resume_href': '/job/view-resume-50299.html'},
#  {'sn': '985',
#   'date_posted': '4/22/2011',
#   'job_func_sought': 'work at home no sign up fee,unlimited income',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Akron, AL',
#   'resume_href': '/job/view-resume-50241.html'},
#  {'sn': '986',
#   'date_posted': '4/21/2011',
#   'job_func_sought': 'accountant/accounting assistant/financial analyst',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Annapolis, MD',
#   'resume_href': '/job/view-resume-50235.html'},
#  {'sn': '987',
#   'date_posted': '4/21/2011',
#   'job_func_sought': 'accounts receivable/customer service',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'la Habra, CA',
#   'resume_href': '/job/view-resume-50216.html'},
#  {'sn': '988',
#   'date_posted': '4/20/2011',
#   'job_func_sought': 'staff accountant and accounting/finance',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Moberly, MO',
#   'resume_href': '/job/view-resume-50195.html'},
#  {'sn': '989',
#   'date_posted': '4/20/2011',
#   'job_func_sought': 'bookkeeping',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'houston, TX',
#   'resume_href': '/job/view-resume-50178.html'},
#  {'sn': '990',
#   'date_posted': '4/20/2011',
#   'job_func_sought': 'administrative assistant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Nassau, NY',
#   'resume_href': '/job/view-resume-50171.html'},
#  {'sn': '991',
#   'date_posted': '4/19/2011',
#   'job_func_sought': 'financial accountant/ sr accountant',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Houston, TX',
#   'resume_href': '/job/view-resume-50127.html'},
#  {'sn': '992',
#   'date_posted': '4/17/2011',
#   'job_func_sought': 'abc news (coj230840)',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Adamsville, AL',
#   'resume_href': '/job/view-resume-50043.html'},
#  {'sn': '993',
#   'date_posted': '4/14/2011',
#   'job_func_sought': 'accounting/consulting/financial analyst',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Kenosha, WI',
#   'resume_href': '/job/view-resume-49992.html'},
#  {'sn': '994',
#   'date_posted': '4/14/2011',
#   'job_func_sought': 'junior accountant, financial analyst',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'New York, NY',
#   'resume_href': '/job/view-resume-49989.html'},
#  {'sn': '995',
#   'date_posted': '4/13/2011',
#   'job_func_sought': 'general manager-restaurants',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'San Marcos, CA',
#   'resume_href': '/job/view-resume-49940.html'},
#  {'sn': '996',
#   'date_posted': '4/12/2011',
#   'job_func_sought': 'controller/assistant controller/accounting/finance manager',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Syracuse, UT',
#   'resume_href': '/job/view-resume-49912.html'},
#  {'sn': '997',
#   'date_posted': '4/11/2011',
#   'job_func_sought': 'finance/accounting',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Chicago, IL',
#   'resume_href': '/job/view-resume-49878.html'},
#  {'sn': '998',
#   'date_posted': '4/11/2011',
#   'job_func_sought': 'finance/accounting',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Chicago, IL',
#   'resume_href': '/job/view-resume-49877.html'},
#  {'sn': '999',
#   'date_posted': '4/10/2011',
#   'job_func_sought': 'executive management',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'San Antonio, TX',
#   'resume_href': '/job/view-resume-49862.html'},
#  {'sn': '1000',
#   'date_posted': '4/7/2011',
#   'job_func_sought': 'accounting',
#   'category': 'Accounting/Bookkeeping',
#   'location': 'Cedar Hill, TX',
#   'resume_href': '/job/view-resume-49772.html'},
#  ...]

# %%
# Convert scraped data into DataFrame
table1 = pd.DataFrame(table)

# %%
# Check out the shape and first 5 items
print(table1.shape)
table1.head()
# Out:
# (1500, 6)
#   sn date_posted                   job_func_sought                category  \
# 0  1   3/30/2020            bookkeeping/accounting  Accounting/Bookkeeping
# 1  2   3/16/2020  stainless steel decorative sheet  Accounting/Bookkeeping
# 2  3    3/4/2020                        accountant  Accounting/Bookkeeping
# 3  4   2/27/2020                   admin assistant  Accounting/Bookkeeping
# 4  5   2/27/2020                   admin assistant  Accounting/Bookkeeping
#
#         location                  resume_href
# 0  Dartmouth, NS  /job/view-resume-82533.html
# 1       Xian, AL  /job/view-resume-82510.html
# 2    Orlando, FL  /job/view-resume-82487.html
# 3   Brampton, ON  /job/view-resume-82476.html
# 4   Brampton, ON  /job/view-resume-82475.html

# %%
# Scraping through the resume

# %%time

headers = {'User-agent': 'SL Bot 1.0'}
base_url = 'https://www.jobspider.com'
href_list = [table[n]['resume_href'] for n in range(800)] # After multiple tries, manual input a range of 800 and for successful scraping (without timeout error)
cv_dict = []

# Create for loop to combine resume_href from table1 to base url for iteration through each link
for j in range(800):
    cv_res = requests.get(base_url + href_list[j], headers=headers)
    cv_soup = BeautifulSoup(cv_res.content, 'lxml')
    cv_body = cv_soup.find_all('table', align='center')
    cv_list = cv_body[1].text.splitlines()
    
    # Create an empty dictionary to store the scrape items
    for items in cv_body:
        cv_items = {}
        
        # In each link, scrap through the resume and create columns to house the items
        for text in cv_list:
            cv_items['id'] = [text for text in cv_list if 'SpiderID:' in text]
            cv_items['emp_type'] = [text for text in cv_list if 'Type of Position:' in text]
            cv_items['availability'] = [text for text in cv_list if 'Availability Date:' in text]
            cv_items['desired_wage'] = [text for text in cv_list if 'Desired Wage:' in text]
            cv_items['work_auth'] = [text for text in cv_list if 'U.S. Work Authorization:' in text]
            cv_items['job_level'] = [text for text in cv_list if 'Job Level:' in text]
            cv_items['will_travel'] = [text for text in cv_list if 'Willing to Travel:' in text]
            cv_items['edu_level'] = [text for text in cv_list if 'Highest Degree Attained:' in text]
            cv_items['will_reloc'] = [text for text in cv_list if 'Willing to Relocate:' in text]
            cv_items['objective'] = [text for text in cv_list if 'Objective:' in text]
            cv_items['exp'] = [text for text in cv_list if 'Experience:' in text]
            cv_items['edu'] = [text for text in cv_list if 'Education:' in text]
            cv_items['skills'] = [text for text in cv_list if 'Skills:' in text]
            cv_items['add_info'] = [text for text in cv_list if 'Additional Information:' in text]
            cv_items['contact_info'] = [text for text in cv_list if 'Contact Information:' in text]
        
    cv_dict.append(cv_items)

cv_dict
# Out:
# Wall time: 15min 3s
# [{'id': ['SpiderID: 82533'],
#   'emp_type': ['Type of Position: Full-Time Permanent'],
#   'availability': ['Availability Date: '],
#   'desired_wage': ['Desired Wage: '],
#   'work_auth': ['U.S. Work Authorization: '],
#   'job_level': ['Job Level: Experienced with over 2 years experience'],
#   'will_travel': ['Willing to Travel: '],
#   'edu_level': ['Highest Degree Attained: Bachelors'],
#   'will_reloc': ['Willing to Relocate: '],
#   'objective': ["Objective:Bookkeeping/Finance professional with experience in preparing, maintaining, analyzing, verifying, and reconciling financial transactions, statements, records, and reports. Able to explain complicated financial principles and processes to a variety of professional and non-professional audience. Member of the Association of Chartered Certified Accountants (ACCA), holder of BSc in Applied Accounting from Oxford Brookes University in London with over 8 years' experience gained in Cameroon. Advanced communication (fluent in English and good in French) skills and ability to build engagement and maintain mutually beneficial relationships.Looking to use current skills in a challenging new role."],
#   'exp': ["Experience:Finance and Administration Director April 2015 - February 2020 International Language and Education Center Yaounde-Cameroon www.ilec-educ.comThe International language and Education Center (ILEC) is a professional training center located in Cameroon's political capital Yaounde. ILEC offers training in English/German languages, computer software certifications and other professional trainings based on corporate needs. ILEC is also an international exam center used by multiple institutions and an accredited ATHE (Awards for Higher Education and Training) satellite center.Primary Roles:• Managed the full accounting cycle using QuickBooks.• Ensured accurate and complete period-end close• Reviewed and reported quarterly internal control compliance, and recommended improvements• Review job descriptions and customer services manualsKey Achievements:• Enhanced governance through the design and implementation of internal control processes and policies in 2016 which led to 28all in surprise asset breakdown and 100uccess on exam compliance reviews• Wrote customer service manuals, job plans and trained employees transforming an employee from grade C (poorly performing) to 3 times winner of Customer Service employee of the month in 2015• Implemented half year corporate outings and service delivery evaluations which brought about 15ncrease in revenue from new streams and an 80ncrease in corporate loyalty• Spearheaded the move from departmental management to value chain management bring about a 38ncrease in customer satisfaction and 50eduction in lease cost and 12eduction in payroll expense in 2016• Transformed the accounting from a cash to an accruals basis within three months after the validation of the internal control processes and policies and implemented QuickBooks• Supervised budgets, cash flow statements and financial statement preparation. Carried out variance analysis withexplanatory notes for shareholder. Validated journals for recording.• Prepared monthly payroll, paid vendors and billed customers.• Monitored P&L/GL daily and performed various analyses, income and accounts reconciliations.• Recruited staff and managed performance.• Initiated and spearheaded the team that worked with ATHE for the recognition of ILEC as a satellite center in2017Finance Officer April 2014 to March 2015International Language and Education Center Yaounde-CameroonPrimary Roles:• Performed duties including but not limited to accounts receivable and payable, payroll and taxation, income andaccounts reconciliations, reporting and other admin duties.Main Achievements:• Prepared a tax and key dates plan, Initiated discussion with Educational Testing Services (ETS) which ended upwith ILEC becoming a TOEFL iBT test center• Spearheaded the creation of the Student Placement Unit and was sent to Dubai to attend ICEF (InternationalConference on Education and Fairs) to gain industry knowledge and negotiate B2B deals.Finance and Administrative Officer January 2014 to March 2014ETS ALNOORI Yaounde-CameroonETS ALNOORI is a General Service based company that supplies equipment’s, stationaries and services to its clients.Primary Roles:• Reconciled bank accounts; issued customer invoices; managed petty cash; monthly tax and social insurancedeclarations and payments among other bookkeeping duties.Main achievement:• Developed a work log-book signed by companies and technician who delivered a service. The log-book carriedrequest and delivery time plus a section for comments amongst others to permit effective client requestmanagementFinance Officer June 2011 to December 2013British Language Centre Yaounde-CameroonThe British Language Centre (BLC) was a professional training center located in Cameroon's political capital Yaounde. BLCoffered training in English languages and was as an IELTS speaking venue.Primary Roles:• Reconcile bank accounts, issue customer invoices, manage petty cash, monthly tax and social insurancedeclaration, other bookkeeping dut ...
#   'edu': ['Education:EducationBSc. in Applied Accounting, Oxford Brookes University London 2011 - 2015(Evaluated by WES in April 2018 as equivalent to a 4-year Canadian degree)'],
#   'skills': [],
#   'add_info': ['Additional Information:Certifications• QuickBooks Pro/Premier Certified User 2019• IFRS certification In progress'],
#   'contact_info': ['Candidate Contact Information:']},
#  {'id': ['SpiderID: 82510'],
#   'emp_type': ['Type of Position: Full-Time Permanent'],
#   'availability': ['Availability Date: '],
#   'desired_wage': ['Desired Wage: '],
#   'work_auth': ['U.S. Work Authorization: '],
#   'job_level': ['Job Level: New Grad/Entry Level'],
#   'will_travel': ['Willing to Travel: '],
#   'edu_level': ['Highest Degree Attained: '],
#   'will_reloc': ['Willing to Relocate: '],
#   'objective': ['Objective:Shaanxi Tonghui Steel Co., Ltd. is a leading Chinese company dedicated to manufacturing, distributing, processing and exporting stainless steel pipes / sheets / coils / bars / profiles / fittings / wires for more than ten years. Our products can be used in petroleum, chemical, pharmaceutical, machinery, decoration, construction, engineering, shipbuilding, food and other industries.As a professional stainless steel manufacturer, we also have a variety of Stainless Steel Decorative Sheet for sale. Our Mirror Stainless Steel Sheet is 8K sheet, also called mirror sheet. The surface of the stainless steel plate was polished using a polishing liquid by a polishing apparatus. The 8K mirror panel is corrosion resistant, and the mirror panel can also be processed by plating and etching. It is mainly used for various types of decorative or metal optical products.Brushing refers to the striped texture effect on the surface of stainless steel, which is the most common and widely used surface treatment technology. After brushing the frosted surface of the stainless steel plate, the surface is textured, but without unevenness. It has better performance than ordinary 2B stainless steel surface, because the surface wire drawing treatment can reflect the texture of metal materials. Compared with other textures, the scratches on the surface of the random pattern Brushed Stainless Steel Sheet are easier to repair. Therefore, this type of board is usually used in places with a lot of wear, such as kitchens, houses, public places, etc.In addition, we also have Stainless Steel Industrial Sheet, which have smooth surfaces and high plasticity, toughness and mechanical strength. It is resistant to acids, salts, alkaline gases, solutions and other media. It is an alloy steel that does not rust easily, which is widely used in industry and construction.If you are interested in our products, please visit: https://www.sxthsteel.com/stainless-steel-sheet/stainless-steel-decorative-sheet/'],
#   'exp': [],
#   'edu': [],
#   'skills': [],
#   'add_info': [],
#   'contact_info': ['Candidate Contact Information:']},
#  {'id': ['SpiderID: 82487'],
#   'emp_type': ['Type of Position: Contractor'],
#   'availability': ['Availability Date: '],
#   'desired_wage': ['Desired Wage: '],
#   'work_auth': ['U.S. Work Authorization: Yes'],
#   'job_level': ['Job Level: Management (Manager, Director)'],
#   'will_travel': ['Willing to Travel: No'],
#   'edu_level': ['Highest Degree Attained: '],
#   'will_reloc': ['Willing to Relocate: No'],
#   'objective': [],
#   'exp': [],
#   'edu': [],
#   'skills': [],
#   'add_info': [],
#   'contact_info': ['Candidate Contact Information:']},
#  {'id': ['SpiderID: 82476'],
#   'emp_type': ['Type of Position: Full-Time Permanent'],
#   'availability': ['Availability Date: ASAP'],
#   'desired_wage': ['Desired Wage: $20-$25'],
#   'work_auth': ['U.S. Work Authorization: No'],
#   'job_level': ['Job Level: New Grad/Entry Level'],
#   'will_travel': ['Willing to Travel: No'],
#   'edu_level': ['Highest Degree Attained: Masters'],
#   'will_reloc': ['Willing to Relocate: Undecided'],
#   'objective': ['Objective:A positive and motivated IT Post-graduate looking to start a career in Information Technology field. Currently looking for a position where I can utilize my knowledge and grow my technical abilities. Through university learning, I have developed the ability to learn new technologies very quickly, solve problems efficiently and undertake responsibilities.'],
#   'exp': ['Experience:BS Computers, Punjab, India•\tDiagnose Hardware problems and fix them or contact appropriate engineer to correct the problem.•\tProvide instructions to all lab users on proper use of equipment.•\tEnsures that Computer lab equipment is properly cared by its users.•\tMaking sure that food and beverages are not consumed in close proximity to computers.•\tMonitors files and programs that are downloaded on the computer to make sure spyware, malware and other dangerous programs are not being downloaded.•\tFile all required reports'],
#   'edu': ['Education:Master of Information technology\t\t                              \t\t  July, 2012 – July, 2014Punjabi University, Punjab, IndiaBachelor of computer application\t\t\t\t\t                  July, 2009 - July, 2012Punjabi University, Punjab, India'],
#   'skills': ['Skills:Computer software: Microsoft world (Word, Powerpoint ,ExcelLanguages: C, C++, HTMLComputer Systems: Windows XP, 7, 8'],
#   'add_info': ['Additional Information:•\tKeen Learner•\tSound Communication Skills both written and spoken•\tDiligent and Sincere with positive attitude in life•\tBelieve in teamwork and enthusiast in taking up new challenges'],
#   'contact_info': ['Candidate Contact Information:']},
#  {'id': ['SpiderID: 82475'],
#   'emp_type': ['Type of Position: Full-Time Permanent'],
#   'availability': ['Availability Date: '],
#   'desired_wage': ['Desired Wage: '],
#   'work_auth': ['U.S. Work Authorization: '],
#   'job_level': ['Job Level: New Grad/Entry Level'],
#   'will_travel': ['Willing to Travel: '],
#   'edu_level': ['Highest Degree Attained: '],
#   'will_reloc': ['Willing to Relocate: '],
#   'objective': [],
#   'exp': [],
#   'edu': [],
#   'skills': [],
#   'add_info': [],
#   'contact_info': ['Candidate Contact Information:']},
#  {'id': ['SpiderID: 82470'],
#   'emp_type': ['Type of Position: Contractor'],
#   'availability': ['Availability Date: 02/22/2020'],
#   'desired_wage': ['Desired Wage: '],
#   'work_auth': ['U.S. Work Authorization: Yes'],
#   'job_level': ['Job Level: Management (Manager, Director)'],
#   'will_travel': ['Willing to Travel: Yes, More Than 75%'],
#   'edu_level': ['Highest Degree Attained: Masters'],
#   'will_reloc': ['Willing to Relocate: Yes'],
#   'objective': ['Objective:Strategist provides clients with more than a decade of hands-on expertise in all aspects of public company accounting, internal audit, acquisition due-diligence, accounting transitions, complex financial analysis, risk identification and assistance with internal controls over financial reporting. Certifications address both business process and IT risk assessment, consumer and commercial insurance, forensic accounting and fraud investigation, all aspects of SOX compliance, policy and procedure documentation, and control development/implementation. Recent endeavors include financial and operational auditing, regulatory compliance and operational analysis reporting.'],
#   'exp': ['Experience:CPA Firm Consultant, Auditgoals.com 2019 - 2020• Planned and coordinated all stages of publicly traded and privately held company financial audits.• Performed routine SOX 404 audits and ad-hoc internal audits to identify gaps and propose corrective action.• Coordinated implementation and monitoring of internal corrective action plans.• Provided guidance to internal and external stakeholders to ensure understanding and compliance with regulatory and contractual requirements, as well as organizational policies and procedures.Chemicals and Manufacturing Consultant, Auditgoals.com 2017 – 2019• Conducts research and analysis on international regulatory requirements affecting vendor and plant relationships.• Performs routine SOX 404 audits and ad-hoc internal audits to identify gaps and propose corrective action.• Coordinates implementation and monitoring of internal corrective action plans.• Provides guidance to internal and external stakeholders to ensure understanding and compliance with regulatory and contractual requirements, as well as organizational policies and procedures.• Maintains the SOX 404 compliance audit program, including schedules, standards, processes, SAP reports and tools in close collaboration with the Compliance VP• Supports the development and renewal of mergers, sales and acquisitions strategic performance efforts, including coordination, verification, editing and submission of key documentation.• Assists the Compliance VP and Project Managers in conducting risk assessments of current business practices by determining areas of exposure and recommending risk-mitigating solutions.• Processes and maintains data, information, documents and files according to professional standardsOilfield and Construction Consultant, Auditgoals.com 2014 – 2017• Facilitate enterprise-wide risk management, SOX 404 activities and internal audit projects.• Review and approve the work of IT and ICFR audit consultants to ensure accuracy and PCAOB compliance.• Perform IT assessments in conjunction with third-party auditors to assess network security and firewall issues.• Propose changes to the internal control environment of all affiliated companies to ensure COSO framework objectives are met.• Advise senior management of the impact of business decisions on the achievement of organizational objectives.• Develop, implement and monitor risk control testing plans and activities to maintain an effective control environment.• Update external audit team on development of initiatives for the firm to increase reliance on internal audit documentation.• Administer the user access and document repository within the electronic audit filings and auditee certification systems.• Facilitate the planning of the ISO 9001 implementation efforts and steer the process mapping and control design initiatives.• Perform random operational audits to assess departmental compliance with recommended action plan updates.• Identify risk control system weaknesses and improvement opportunities to establish best practices.• Establish and consistently update risk control matrices and critical supporting documentsNonprofit and Food Service Consultant, Auditgoals.com 2013 – 2014• Managed staff of IT, billing and administrative professionals to ensure operational efficiency.• Collaborated with executive, finance and operations teams to introduce a mobile application to increase route performance.• Performed audits of key revenue and expense cycle activities to ensure accuracy of grant-writing estimates.• Performed assessments of operational compliance with regulatory standards and solicited executive advisory services.• Reviewed governmental contracts to ascertain levels of compliance risk and solidify knowledge of funding programs.• Created executive presentations for the education of the Board of Directors and other interested parties.• Assessed agency compliance with grantor funding contracts and produced reporting to prove compliance.• Acted as a  ...
#   'edu': ['Education:Master of Business Administration, FinanceBachelor of Business Administration, Finance'],
#   'skills': [],
#   'add_info': [],
#   'contact_info': ['Candidate Contact Information:']},
#  {'id': ['SpiderID: 82450'],
#   'emp_type': ['Type of Position: Full-Time Permanent'],
#   'availability': ['Availability Date: 02/01/20'],
#   'desired_wage': ['Desired Wage: 75,000.00'],
#   'work_auth': ['U.S. Work Authorization: Yes'],
#   'job_level': ['Job Level: Management (Manager, Director)'],
#   'will_travel': ['Willing to Travel: No'],
#   'edu_level': ['Highest Degree Attained: High School/Equivalent'],
#   'will_reloc': ['Willing to Relocate: No'],
#   'objective': [],
#   'exp': ['Experience:Accomplished finance and accounting professional with over 20 years of experience in progressively increasing finance and accounting responsibilities.'],
#   'edu': ['Education:Three years at University Wisconsin Superior'],
#   'skills': ['Skills:BudgetsAdvanced ExcelFinancial StatementsStaff SupervisionAccrualsMonthly ClosingsExternal AuditsGL ReconciliationsCash ManagementBank ReconciliationsBenefits/Payroll/401KGAAP/Statutory AccountingJournal Entries'],
#   'add_info': ['Additional Information:Software:Microsoft Dynamics GPPrism HRUltiproDarwinIntacctClient Space CRMCorrelation CRM'],
#   'contact_info': ['Candidate Contact Information:']},
#  {'id': ['SpiderID: 82440'],
#   'emp_type': ['Type of Position: Full-Time Permanent'],
#   'availability': ['Availability Date: 10-02-2020'],
#   'desired_wage': ['Desired Wage: 15000'],
#   'work_auth': ['U.S. Work Authorization: '],
#   'job_level': ['Job Level: New Grad/Entry Level'],
#   'will_travel': ['Willing to Travel: '],
#   'edu_level': ['Highest Degree Attained: None'],
#   'will_reloc': ['Willing to Relocate: '],
#   'objective': ['Objective:Manage end-to-end recruitment life cycle and managing staffing processIdentify staffing requirements to meet the goals and objectives of the organization'],
#   'exp': ['Experience:Manage end-to-end recruitment life cycle and managing staffing processIdentify staffing requirements to meet the goals and objectives of the organization'],
#   'edu': ['Education:Manage end-to-end recruitment life cycle and managing staffing processIdentify staffing requirements to meet the goals and objectives of the organization'],
#   'skills': ['Skills:Manage end-to-end recruitment life cycle and managing staffing processIdentify staffing requirements to meet the goals and objectives of the organization'],
#   'add_info': ['Additional Information:Manage end-to-end recruitment life cycle and managing staffing processIdentify staffing requirements to meet the goals and objectives of the organization'],
#   'contact_info': ['Candidate Contact Information:']},
#  {'id': ['SpiderID: 82439'],
#   'emp_type': ['Type of Position: Full-Time Permanent'],
#   'availability': ['Availability Date: 10-02-2020'],
#   'desired_wage': ['Desired Wage: 15000'],
#   'work_auth': ['U.S. Work Authorization: '],
#   'job_level': ['Job Level: New Grad/Entry Level'],
#   'will_travel': ['Willing to Travel: '],
#   'edu_level': ['Highest Degree Attained: None'],
#   'will_reloc': ['Willing to Relocate: '],
#   'objective': ['Objective:Speed Technosolutions (ITIndustry)Speed Technosolutions established in 1995 as speed solutions as a leading enterprise IT consulting firm in(Ranchi, Jharkhand).It also have its presence in Mumbai. It works across the World. It specializes in superior IT architecture design, end-to-end project implementation, Web Design and Development, Web based Application Development, E -commerce Development, E-commerce online shopping systems, Flash multimedia Website Hosting, Search Engine Optimization (SEO), Graphic Design and Software Development. It gives Internet technological solutions and services for the customer’s online business needs. Being a premier services company, our customers are our top priority and your success is our objective.'],
#   'exp': ['Experience:Speed Technosolutions (ITIndustry)Speed Technosolutions established in 1995 as speed solutions as a leading enterprise IT consulting firm in(Ranchi, Jharkhand).It also have its presence in Mumbai. It works across the World. It specializes in superior IT architecture design, end-to-end project implementation, Web Design and Development, Web based Application Development, E -commerce Development, E-commerce online shopping systems, Flash multimedia Website Hosting, Search Engine Optimization (SEO), Graphic Design and Software Development. It gives Internet technological solutions and services for the customer’s online business needs. Being a premier services company, our customers are our top priority and your success is our objective.'],
#   'edu': ['Education:Speed Technosolutions (ITIndustry)Speed Technosolutions established in 1995 as speed solutions as a leading enterprise IT consulting firm in(Ranchi, Jharkhand).It also have its presence in Mumbai. It works across the World. It specializes in superior IT architecture design, end-to-end project implementation, Web Design and Development, Web based Application Development, E -commerce Development, E-commerce online shopping systems, Flash multimedia Website Hosting, Search Engine Optimization (SEO), Graphic Design and Software Development. It gives Internet technological solutions and services for the customer’s online business needs. Being a premier services company, our customers are our top priority and your success is our objective.'],
#   'skills': ['Skills:Speed Technosolutions (ITIndustry)Speed Technosolutions established in 1995 as speed solutions as a leading enterprise IT consulting firm in(Ranchi, Jharkhand).It also have its presence in Mumbai. It works across the World. It specializes in superior IT architecture design, end-to-end project implementation, Web Design and Development, Web based Application Development, E -commerce Development, E-commerce online shopping systems, Flash multimedia Website Hosting, Search Engine Optimization (SEO), Graphic Design and Software Development. It gives Internet technological solutions and services for the customer’s online business needs. Being a premier services company, our customers are our top priority and your success is our objective.'],
#   'add_info': ['Additional Information:Speed Technosolutions (ITIndustry)Speed Technosolutions established in 1995 as speed solutions as a leading enterprise IT consulting firm in(Ranchi, Jharkhand).It also have its presence in Mumbai. It works across the World. It specializes in superior IT architecture design, end-to-end project implementation, Web Design and Development, Web based Application Development, E -commerce Development, E-commerce online shopping systems, Flash multimedia Website Hosting, Search Engine Optimization (SEO), Graphic Design and Software Development. It gives Internet technological solutions and services for the customer’s online business needs. Being a premier services company, our customers are our top priority and your success is our objective.'],
#   'contact_info': ['Candidate Contact Information:']},
#  {'id': ['SpiderID: 82436'],
#   'emp_type': ['Type of Position: Full-Time Permanent'],
#   'availability': ['Availability Date: 10-02-2020'],
#   'desired_wage': ['Desired Wage: 15000'],
#   'work_auth': ['U.S. Work Authorization: '],
#   'job_level': ['Job Level: New Grad/Entry Level'],
#   'will_travel': ['Willing to Travel: '],
#   'edu_level': ['Highest Degree Attained: '],
#   'will_reloc': ['Willing to Relocate: '],
#   'objective': ['Objective:We have job opening for Accounts executive Accounts assistant who has an experience of excise, tally software, journal cash entry recording expenses, Must know Tally software, General ledgers maintaining books of accounts of company Task oriented, responsible for the admin, status report, issuing contact reports after meetings & Handle all aspects of finance. Receivable and payable management MIS '],
#   'exp': ['Experience:We have job opening for Accounts executive Accounts assistant who has an experience of excise, tally software, journal cash entry recording expenses, Must know Tally software, General ledgers maintaining books of accounts of company Task oriented, responsible for the admin, status report, issuing contact reports after meetings & Handle all aspects of finance. Receivable and payable management MIS '],
#   'edu': ['Education:We have job opening for Accounts executive Accounts assistant who has an experience of excise, tally software, journal cash entry recording expenses, Must know Tally software, General ledgers maintaining books of accounts of company Task oriented, responsible for the admin, status report, issuing contact reports after meetings & Handle all aspects of finance. Receivable and payable management MIS '],
#   'skills': ['Skills:We have job opening for Accounts executive Accounts assistant who has an experience of excise, tally software, journal cash entry recording expenses, Must know Tally software, General ledgers maintaining books of accounts of company Task oriented, responsible for the admin, status report, issuing contact reports after meetings & Handle all aspects of finance. Receivable and payable management MIS '],
#   'add_info': ['Additional Information:We have job opening for Accounts executive Accounts assistant who has an experience of excise, tally software, journal cash entry recording expenses, Must know Tally software, General ledgers maintaining books of accounts of company Task oriented, responsible for the admin, status report, issuing contact reports after meetings & Handle all aspects of finance. Receivable and payable management MIS '],
#   'contact_info': ['Candidate Contact Information:']},
#  {'id': ['SpiderID: 82424'],
#   'emp_type': ['Type of Position: Full-Time Permanent'],
#   'availability': ['Availability Date: 01-02-2020'],
#   'desired_wage': ['Desired Wage: 150000'],
#   'work_auth': ['U.S. Work Authorization: Yes'],
#   'job_level': ['Job Level: New Grad/Entry Level'],
#   'will_travel': ['Willing to Travel: '],
#   'edu_level': ['Highest Degree Attained: High School/Equivalent'],
#   'will_reloc': ['Willing to Relocate: '],
#   'objective': ['Objective:Fresher candidates with Good communication '],
#   'exp': ['Experience:Fresher candidates with Good communication '],
#   'edu': ['Education:Bachelors or Masters degree in Human Resource Management from a recognized university'],
#   'skills': ['Skills:Fresher candidates with Good communication '],
#   'add_info': ['Additional Information:Fresher candidates with Good communication '],
#   'contact_info': ['Candidate Contact Information:']},
#  {'id': ['SpiderID: 82423'],
#   'emp_type': ['Type of Position: Full-Time Permanent'],
#   'availability': ['Availability Date: '],
#   'desired_wage': ['Desired Wage: '],
#   'work_auth': ['U.S. Work Authorization: Yes'],
#   'job_level': ['Job Level: Management (Manager, Director)'],
#   'will_travel': ['Willing to Travel: Yes, Less Than 25%'],
#   'edu_level': ['Highest Degree Attained: Bachelors'],
#   'will_reloc': ['Willing to Relocate: Yes'],
#   'objective': ['Objective:Growth-focused and astute executive and influential leader with a wide-range of experience in community, retail, and small business banking within the financial services industry.'],
#   'exp': ['Experience:WELLS FARGO ▪ DALLAS, TX (1994–2019)Senior Vice President | Community Banking District Manager\tMar 2003–Dec 2019\uf0a7\tManaged 11 banking branches with 115 team members that specialized in providing financial services to retail and business customers.\uf0a7\tManaged deposit relationships in excess of $750M.    \uf0a7\tProvided strategic direction to team members to support the organizations vision and goals.\uf0a7\tAchieved internal sales goals by referring customers to various lines of business as necessary.   \uf0a7\tEffectively managed all aspects of retail and affluent customers within the geographical market, growing household balances and branch primary customers.    \uf0a7\tCollaborated with Wholesale Banking, Wealth Management, Brokerage and Home Lending lines of business to guarantee shared success across all market segments.\uf0a7\tFacilitated execution and maintenance of prescribed risks and security controls in alignment with the organization’s standards, policies, procedures, vision and values.\uf0a7\tOptimized enterprise products and services to meet customer requirements by deepening relationships with existing and prospective customers.\uf0a7\tGuaranteed consistency of all regional initiatives with community banking by driving the “One Wells Fargo” approach.\uf0a7\tFacilitated recruitment, development and coaching of team members through balanced leadership, focusing on team member engagement, retention and performance management.\uf0a7\tRepresented the company and community banking in all aspects of federal, state, community leadership and development within markets.Key Accomplishments:\uf0fc\tReceived multiple Service of Excellence awards and distinctions by demonstrating outstanding customer management performance.\uf0fc\tPartnered closely with small to large enterprises to host workshops and development programs, which resulted in business growth and increased revenues.\uf0fc\tSuccessfully built working relationships with customers to provide assistance with meeting their financial goals. Earlier Positions HeldVice President | Branch Manager\tMay 1994–Jun 2003NATIONSBANK ▪ DALLAS, TXAssistant Vice President | Lobby/Teller Manager\tFeb 1981–May 1994ADDITIONAL EXPERIENCECITY OF DUNCANVILLE ▪ DUNCANVILLE, TX\tCouncilmember\tMay 2012– May 2014; May 2018–PresentMayor Pro Tem\tMay 2013– May 2014\uf0a7\tWork collaboratively with city manager, boards and commissions to drive economic development and a better quality of life for all citizens. \uf0a7\tAssist city staff with special projects when required. '],
#   'edu': ['Education:EDUCATIONApplied Business Administration Management/Behavior Management: Jul 2004DALLAS BAPTIST UNIVERSITY ▪ DALLAS, TXCertificate of Individualized Education Program (IEP): Jul 1992AMERICAN INSTITUTE OF BANKING ▪ DALLAS, TXAfrican American Leadership Program: May 2005UNIVERSITY OF CALIFORNIA, LOS ANGELES, ANDERSON SCHOOL OF BUSINESS ▪ LOS ANGELES, CA'],
#   'skills': ['Skills:Banking Administration | Risk Mitigation |Staff Coordination, Training and DevelopmentRegulatory Compliance | Operational Streamlining | Loan Management | Customer Retention'],
#   'add_info': [],
#   'contact_info': ['Candidate Contact Information:']},
#  {'id': ['SpiderID: 82397'],
#   'emp_type': ['Type of Position: Full-Time Permanent'],
#   'availability': ['Availability Date: Immediate'],
#   'desired_wage': ['Desired Wage: 90000'],
#   'work_auth': ['U.S. Work Authorization: Yes'],
#   'job_level': ['Job Level: Management (Manager, Director)'],
#   'will_travel': ['Willing to Travel: No'],
#   'edu_level': ['Highest Degree Attained: Other'],
#   'will_reloc': ['Willing to Relocate: No'],
#   'objective': ['Objective:Analytical, performance-focused, and forward-thinking professional, with comprehensive experience in equity, fixed income, and commodity operations support; and foreign exchange in investment banking, securities, and wealth management industries. Expert at dealing with domestic and foreign derivative transactions, finance systems, commodity options, and warrants in line with the set-forth procedures. Equipped with leadership abilities in determining organizational needs; recommending innovative solutions and alternatives to complex problems; and meeting tight deadlines toward company growth.'],
#   'exp': ['Experience:SOCIÉTÉ GÉNÉRALE – JERSEY CITY, NJVice President - Team Leader, Delivery Department: 2017–Present-\tEffectively supervise the Delivery Team in New York and Chicago with the daily business operations.-\tRegularly coordinate with internal and external customers to address their concern-\tProcess the release of stock warrants and send emails to client service group with client holding open commodity position approaching last trading day (LTD) and first notice day (FND).-\tTrack internal and exchange system in ensuring client trade out for open positions during LTD.-\tParticipate in all commodity option expirations and delivery processing.-\tPerform reconciliation of daily warrants inventory, client trades booking, and client petroleum trade breaks.-\tTake charge of processing client payment in the internal system.UBS INVESTMENT BANK – NEW YORK, NYExchange Traded Derivatives Client Margining Specialist: 2015–2017-\tFacilitated training to team members and new joiners regarding client margining.-\tConducted escalation with Credit Risk Team regarding payment overdue by three days.-\tClosely work with several stakeholders in Sales, Risk, and IT departments.-\tManaged client daily margining to ensure attainment and coverage of all margin calls.-\tDeveloped and evaluated standard operating procedures to identify new process improvements.-\tDealt with client requests on collateral substitution; daily/weekly foreign currency procedures; and cash and collateral file receipt for verification of the UBS internal payment system.-\tEfficiently handled T+1 cash fail reconciliation; SWIFT payment of the client; and missing fund settlement in partnership with a custodian. UBS INVESTMENT BANK – NEW YORK, NYExchange Traded Derivatives Delivery Control Specialist: 2005–2015-\tOversaw daily operations support for the Exchange Traded Derivatives Deliveries Division.-\tSpearheaded all commodity, single-stock future deliveries, and option expiration on the New York Mercantile Exchange, New York Commodity Exchange, Options Clearing Corporation, Chicago Board of Trade, and the Chicago Mercantile Exchange.-\tEnsured adherence to set rules and regulations of the exchange by collaborating with global branch offices and external clients-\tGenerated monthly global balance sheet sign-off and verification (GBSOV) to manage the balance and risk of the accounts.-\tManaged global hedge fund, money manager and commodity clients, as well as the large trader position and open interest to exchanges and clients.-\tInvestigate Commodity Futures Trading Commission (CFTC), internal compliance, and exchange regulatory inquiries, while also reconciling T+1 trade breaks in collaboration with the internal stakeholders, brokers, and external clients.-\tPromptly addressed and responded to customer inquiries.-\tDrove key efforts in reaching quarterly cross-currency for ICE Clear US and Chicago Mercantile Exchange, amounting to $56B.'],
#   'edu': ['Education:SCS Business and Technical Institute -New York, NY June 1986-June 1987Certificate of Academic Achievement in Bookkeeping & Business'],
#   'skills': ['Skills:Trade Posting and Payment EscalationInvestment and Finance AssessmentContinuous Process ImprovementCost Reduction Analysis\tFutures and Options OperationsRegulatory Compliance and StandardsCustomer Service and RetentionProject and Program Development'],
#   'add_info': ['Additional Information:EARLIER CAREERMAN FINANCIAL, INC. – NEW YORK, NYFutures Operations AssociateMERRILL LYNCH FUTURES, INC. – JERSEY CITY, NJManager - Deliveries SpecialistTECHNICAL ACUMENMicrosoft Office Suite (Word, Excel)SAP BusinessObjects ▪ CME Portal ▪ ICE US Clearing Application ▪ PTMS ▪ ECS ▪ ComaKeyLink ▪ Swiss Key Clearing ▪ MYOCC and GMI System'],
#   'contact_info': ['Candidate Contact Information:']},
#  {'id': ['SpiderID: 82369'],
#   'emp_type': ['Type of Position: Full-Time Permanent'],
#   'availability': ['Availability Date: ASAP'],
#   'desired_wage': ['Desired Wage: 50,000'],
#   'work_auth': ['U.S. Work Authorization: No'],
#   'job_level': ['Job Level: New Grad/Entry Level'],
#   'will_travel': ['Willing to Travel: '],
#   'edu_level': ['Highest Degree Attained: Bachelors'],
#   'will_reloc': ['Willing to Relocate: Yes'],
#   'objective': ['Objective:• Successfully completed Canadian Securities Course (CSC) credentials• While delivering grocery to save on food customers, I promote more-rewards card, based on number of sign ups I have been rewarded with commission• Got an opportunity to work on StockTrak to get familiar with the trading of stocks of different securities, and planned Estate and Retirement planning while completing Financial Planning Program• Technically – Good Knowledge of MS Office (Excel, Outlook, PowerPoint), quick learner who can easily adapt to new environments and new challenges'],
#   'exp': ['Experience:Ecommerce and Store Clerk \t(May 2019 – Present)Save on Foods (Surrey, British Columbia)•\tDeliver groceries and provide exceptional customer service by delivering customers’ orders to their homes safely, accurately and on time•\tProvide customers with a timely and positive experience to build and maintain customer relationships•\tShare customer feedback with the E-Commerce Operations Specialist/Team Leader•\tWorked as cashier and customer service representative in order to handle returns and complaints'],
#   'edu': ['Education:Post-Graduate Diploma: Financial Planning                                                                      (Sept 2018 – Aug 2019)Douglas College (New Westminster, BC, Canada) GPA – 3.0Post-Graduate Diploma: Supply Chain Management                                                         (May 2017 - Aug 2018)     Douglas College (New Westminster, BC, Canada) GPA – 3.10Bachelor of Engineering: Manufacturing Processes and Automation                             (Aug 2012 - June 2016)Netaji Subhas Institute of Technology (New Delhi, DL, India) '],
#   'skills': ['Skills:Quickbooks, Sage, MS Exccel, Python, SQLLanguages - English, Hindi and Punjabi'],
#   'add_info': [],
#   'contact_info': ['Candidate Contact Information:']},
#  {'id': ['SpiderID: 82338'],
#   'emp_type': ['Type of Position: Full-Time Permanent'],
#   'availability': ['Availability Date: '],
#   'desired_wage': ['Desired Wage: 35000'],
#   'work_auth': ['U.S. Work Authorization: Yes'],
#   'job_level': ['Job Level: Experienced with over 2 years experience'],
#   'will_travel': ['Willing to Travel: No'],
#   'edu_level': ['Highest Degree Attained: Bachelors'],
#   'will_reloc': ['Willing to Relocate: No'],
#   'objective': ['Objective:Dynamic, goal-oriented, and analytical professional with years of experience in operations, revenue cycle, and account management, business analysis, and regulatory compliance.Expert at evaluating financial situation of individuals and businesses, as well as generating detailed financial reports for efficient business flow and decision making. Skilled at identifying and addressing business requirements to maximize growth opportunities. Equipped with proven ability to accomplish multiple assignments while ensuring strict compliance with the established financial guidelines. Armed with excellent communication and interpersonal aptitudes in collaborating with and building productive relationships with various individuals with diverse backgrounds.'],
#   'exp': ['Experience:Echo River Expeditions, Cañon City, COReservationist\t2019–Present\uf0a7\tCarry out the planning of travel itineraries by providing recommendations on local tourist attractions and places of interest\uf0a7\tEfficiently handle the processing of payments and sending of details and confirmation to the guest, as well as acquiring of check-in requests and work retailAllegiance Mobile Health, Georgetown, TXRevenue Cycle Manager\t2015–2018\uf0a7\tExpertly managed all business-related functions of the emergency medical services (EMS) transports\uf0a7\tKeenly administered specific areas, including revenue cycle training, credentialing registration, claims management, billing, collections, patient insurance, integrity of patient accounts, accounts receivable management, medical records custodian, and third-party revenue cycle vendors\uf0a7\tTook charge of tracking aged accounts and ensuring that all appropriate collections procedures were followed, as well as evaluating business metrics to improve processes and increase efficiencies\uf0a7\tSet internal goals and determined external benchmarks\uf0a7\tGenerated effective resolution for all escalated reimbursement problems with payers by personally analyzing and managing important concerns\uf0a7\tExecuted and upheld the supplier’s and emergency medical services (EMS) revenue cycle standard operating procedures (SOP)\uf0a7\tAssumed accountability in identifying goals and vision of team as well as providing guidance with individuals and team toward priorities and clarifying roles and duties of others\uf0a7\tEffectively supervised high-caliber personnel as well as a staff of 35 including hiring, evaluating performance, controlling salary changes, and executing disciplinary action\uf0a7\tProvided timely, specific feedback and helpful coaching and guaranteed full compliance with supplier’s and EMS policiesAdvance Medical Practice Management AMPM) Medical Billing and Practice Management, Austin, TXSenior Account Manager\t2014–2015\uf0a7\tEfficiently handled account management of three cardiology accounts, one orthopedic practice and one Surgical Trauma Group\uf0a7\tSpearheaded the processing of appeals and correcting claims and medical record reviews, as well as reconciliation of ERA’s and recoupments\uf0a7\tCreated account receivable (A/R) and decreased the aging report from 40% over 120 to 10% over 60\uf0a7\tAdministered the posting of patient payments and processing of post-credit card insurance payments form commercials carriers\uf0a7\tConducted month-end close and balance, which included client package presentationHarden Healthcare, LLC, Austin, TXOperations Manager\t2006-2014\uf0a7\tOversaw the reception, scheduling, insurance verification, referrals, specialty, revenue cycle, and patient claims\uf0a7\tDirected the verification of provider credentials, licensure, and certifications per Harden Healthcare (HHC) policies and industry standards, including development and maintenance of credentialing files for new and existing providers\uf0a7\tCarried out the processing of enrollment in Medicare and Medicaid, controlling of care plans and major commercial carrier including credentialing and revalidation using Council for Affordable Quality Healthcare (CAQH)\uf0a7\tManaged preparation of physician oversight and collaborative agreements\uf0a7\tCoordinated with controller, accountant, and HHC leadership on earnings before interest, tax, depreciation and amortization (EBITDA)\uf0a7\tSupervised a staff consisting of billing and insurance specialists and medical assistants, while executing performance evaluations'],
#   'edu': ['Education:Coursework in Accounting and ComputerBessemer Technical College, Bessemer, ALCoursework in Accounting and ComputerRiverside Community College, Riverside, CA'],
#   'skills': ['Skills:Microsoft Office Applications (Excel, Word, PowerPoint, Access, and Outlook) | ESO | PayorLogic | CMD | PUREDIMedisoft | e-MD | Allscripts | Amazing Charts EMR | QuickBooks Pro | PeopleSoft Financials | PeopleSoft HRPORTAL Billing System | Remedy | Advantage Financial System | Adobe Acrobat | Adventure Office'],
#   'add_info': [],
#   'contact_info': ['Candidate Contact Information:']},
#  {'id': ['SpiderID: 82324'],
#   'emp_type': ['Type of Position: Full-Time Permanent'],
#   'availability': ['Availability Date: '],
#   'desired_wage': ['Desired Wage: '],
#   'work_auth': ['U.S. Work Authorization: No'],
#   'job_level': ['Job Level: Experienced with over 2 years experience'],
#   'will_travel': ['Willing to Travel: Yes, More Than 75%'],
#   'edu_level': ['Highest Degree Attained: Bachelors'],
#   'will_reloc': ['Willing to Relocate: Yes'],
#   'objective': [],
#   'exp': [],
#   'edu': [],
#   'skills': [],
#   'add_info': [],
#   'contact_info': ['Candidate Contact Information:']},
#  {'id': ['SpiderID: 82313'],
#   'emp_type': ['Type of Position: Full-Time Permanent'],
#   'availability': ['Availability Date: 01/01/2020'],
#   'desired_wage': ['Desired Wage: £30 000'],
#   'work_auth': ['U.S. Work Authorization: No'],
#   'job_level': ['Job Level: Experienced with over 2 years experience'],
#   'will_travel': ['Willing to Travel: Yes, 25-50%'],
#   'edu_level': ['Highest Degree Attained: Bachelors'],
#   'will_reloc': ['Willing to Relocate: Yes'],
#   'objective': ['Objective:My objective is to grow in the accounting arena on a global scale level gaining as much experience in the process,whilst at the same time contributing efficiently and effectively for the organisation l am working for, with loyalty'],
#   'exp': ['Experience:l have attained vast experience in the accounting arena for the past 13 years, in colleges and organisations. My job position has allowed me to do be an adviser to management in companies, gained experience in managing of positions, as l would also act as a management representative, on a temporary basis'],
#   'edu': ['Education:After secondary education, l proceeded to University and did a Bachelor of Administration degree in Accounting. I have then engaged in doing a pre masters course in Global Management with Royal Roads University,Canada, of  which l will proceed to do the Masters programme.  '],
#   'skills': ['Skills:Microsoft packagePastelExcellent numeric skillsGood analytical skillsPublic speakerInterpersonal skills'],
#   'add_info': ['Additional Information:I will be available to start employment as from the 1st of January 2020'],
#   'contact_info': ['Candidate Contact Information:']},
#  {'id': ['SpiderID: 82293'],
#   'emp_type': ['Type of Position: Full-Time Permanent'],
#   'availability': ['Availability Date: Immediately'],
#   'desired_wage': ['Desired Wage: 45000'],
#   'work_auth': ['U.S. Work Authorization: Yes'],
#   'job_level': ['Job Level: Management (Manager, Director)'],
#   'will_travel': ['Willing to Travel: Yes, Less Than 25%'],
#   'edu_level': ['Highest Degree Attained: High School/Equivalent'],
#   'will_reloc': ['Willing to Relocate: Yes'],
#   'objective': ['Objective:Performance-focused, well organized, and multifaceted professional offering broad-based experience in facility management, accounting and bookkeeping, budgeting and finance, project administration, staff supervision, and client service within diverse industries.Known for excellent work ethic and exemplary ability in performing multiple responsibilities and meeting deadlines within demanding work environments. Equipped with excellent communication and interpersonal abilities in cultivating productive working relationships with professionals of all levels. Proficient with Microsoft Office Suite (Word, Excel, and PowerPoint) and QuickBooks.'],
# ...
#   'edu': ['Education:Education:  6/2008    Master of Science in Accountancy, University of North Carolina Wilmington5/1996    Bachelor of Arts in Psychology, University of North Carolina Wilmington'],
#   'skills': [],
#   'add_info': [],
#   'contact_info': ['Candidate Contact Information:']},
#  {'id': ['SpiderID: 55743'],
#   'emp_type': ['Type of Position: Full-Time Permanent'],
#   'availability': ['Availability Date: Immediately'],
#   'desired_wage': ['Desired Wage: 35000'],
#   'work_auth': ['U.S. Work Authorization: Yes'],
#   'job_level': ['Job Level: Experienced with over 2 years experience'],
#   'will_travel': ['Willing to Travel: '],
#   'edu_level': ['Highest Degree Attained: Masters'],
#   'will_reloc': ['Willing to Relocate: No'],
#   'objective': ['Objective:Highly analytical, results-driven, and versatile individual with academic background in accounting and finance. Equipped with solid foundation in the fundamentals of accounting and financial management with sharp analytical, communications, and teamwork abilities. Goal-oriented, thrive in challenges to meet organizational goals and excel in new environments. Armed with strategies to come up with the most appropriate solutions for businesses in fast-changing global market. Flexible and reliable in working independently or within a team environment, able to empower and motivate colleagues to refocus on the task at hand and achieve target goals. Known for integrity and professionalism, accomplishing work assignments objectively even under adverse situations. Quick learner and logical thinker, paying keen attention to detail in handling tasks. Possess excellent communication and presentation skills, along with interpersonal abilities; effectively listen and deal accordingly with individuals from all levels. Bilingual in Japanese and English.'],
#   'exp': ['Experience:WORK EXPERIENCETechnical Translator, ADA TECHNOLOGIES, INC. ~ Ada, OH \t2005–2008Office Coordinator, H&R BLOCK ~ Kenton, OH\t2005–2009Technical Writer/Translator, NK PARTS INDUSTRIES, INC. ~ Sidney, OH\t   2003–2004Administrative Coordinator | Technical Writer/Translator, AISIN BRAKE AND CHASSIS, INC. ~ Terre Haute, IN 2001–2003'],
#   'edu': ['Education:EDUCATIONKELLER GRADUATE SCHOOL OF MANAGEMENT ~ Columbus, Ohio | Latest GPA: 3.96/4.0Master of Accounting and Financial Management, with CPA Emphasis: In Progress (Expected Date of Completion: Jun 2012)COMPLETED ALL REGULAR ACCOUNTING COURSES, READY FOR CPA EXAM (BECKER CPA REVIEW)THE UNIVERSITY OF FINDLAY ~ Findlay, Ohio | Dean’s List: Fall 1997 and Spring 2001Bachelor of Science with Double Major in Marketing and English as in International Language: 2001'],
#   'skills': ['Skills:CORE STRENGTHSAccounting: Possess solid background in managerial and intermediate accounting and federal taxes, as well as in making management decisions and conducting financial analysis. Well-versed in business environment concepts, external auditing, financial accounting, and reporting issues. Capable of posting transactions and helping reconcile cash balances with financial records; tracking and compiling reports on financial transactions, including all income and expenses. Knowledgeable in federal accounting procedures, policies, rules, and regulations. Knowledgeable in handling compliance claims and disputes as well as computer fraud identification and tracking. Trained in reconciling general ledger and sub-ledger accounts as well in preparing financial statements and month-end journal entries. Possess an in-depth understanding of recent developments in accounting valuation and reporting practices. FINANCE: Keen in analyzing information in order to come up with impactful recommendations to help in investment decisions for businesses. Skilled and capable of finding the right mix of investment products to help meet clients’ objectives and financial needs. Possess solid understanding of due diligence process; capable of financial reports analysis, financial planning, retirement planning, portfolio management, and investor relations. Experienced in sorting daily transactions and reconciling balanced sheets along with researching new and existing investment options. COMMUNICATIONS SUPPORT/CLIENT RELATIONS: Adept at assisting customers by handling calls and addressing their concerns; facilitating communication between tax professionals and clients. Ensured accuracy of information in interpreting and translating communications among Japanese/American members. Drafted, edited, and translated training manuals, operations reports, speech materials, and presentations from Quality, New Model, Purchasing, and Manufacturing departments from Japanese to English and vice versa. '],
#   'add_info': ['Additional Information:~ ENTRY-LEVEL ACCOUNTANT ~Risk-Based Auditing ~ Financial Management Systems ~ Quantitative and Qualitative Analyses ~ Financial Controls and Budget Analysis ~ Program Assessment ~ Reports and Presentations'],
#   'contact_info': ['Candidate Contact Information:']},
#  {'id': ['SpiderID: 55579'],
#   'emp_type': ['Type of Position: Full-Time Permanent'],
#   'availability': ['Availability Date: 11/09/2011'],
#   'desired_wage': ['Desired Wage: 30,000'],
#   'work_auth': ['U.S. Work Authorization: '],
#   'job_level': ['Job Level: Management (Manager, Director)'],
#   'will_travel': ['Willing to Travel: No'],
#   'edu_level': ['Highest Degree Attained: High School/Equivalent'],
#   'will_reloc': ['Willing to Relocate: No'],
#   'objective': [],
#   'exp': [],
#   'edu': [],
#   'skills': [],
#   'add_info': [],
#   'contact_info': ['Candidate Contact Information:']},
#  {'id': ['SpiderID: 55525'],
#   'emp_type': ['Type of Position: Other'],
#   'availability': ['Availability Date: ASAP'],
#   'desired_wage': ['Desired Wage: '],
#   'work_auth': ['U.S. Work Authorization: Yes'],
#   'job_level': ['Job Level: New Grad/Entry Level'],
#   'will_travel': ['Willing to Travel: '],
#   'edu_level': ['Highest Degree Attained: Other'],
#   'will_reloc': ['Willing to Relocate: Yes'],
#   'objective': ['Objective:Bookkeeper/Accountant/Office '],
#   'exp': ['Experience:Please read next section'],
#   'edu': ['Education:College'],
#   'skills': ['Skills:Soft and hard skills'],
#   'add_info': ['Additional Information:Bookkeeper/accounting job wanted paid or unpaid (Van and surrounding cities)I am looking for a junior bookkeeper/accounting job Ft/Pt paid or unpaid in vancouver or surrounding cities. Job location should be close to and easily accessible by public transit. I have formal education in accounting and flexible with pay expectations. I have practical experience with using a variety of computer hardware and software. Only employers or companies who can be verified by either or all of this info: official email address, address, or phone number need contact me. Please reply to this ad through this website. I know English language only. I am flexible with work availability and can do both regular and irregular work times and days. Absolutely no obligation on you to give me any specific number of work hours. Trustworthy and keeps your information confidential. •\tLocation: Van and surrounding cities •\tCompensation: flexible- paid or unpaid •\t'],
#   'contact_info': ['Candidate Contact Information:']},
#  {'id': ['SpiderID: 55501'],
#   'emp_type': ['Type of Position: Full-Time Permanent'],
#   'availability': ['Availability Date: 11-02-11'],
#   'desired_wage': ['Desired Wage: 24,000'],
#   'work_auth': ['U.S. Work Authorization: '],
#   'job_level': ['Job Level: Experienced with over 2 years experience'],
#   'will_travel': ['Willing to Travel: Yes, Less Than 25%'],
#   'edu_level': ['Highest Degree Attained: High School/Equivalent'],
#   'will_reloc': ['Willing to Relocate: Yes'],
#   'objective': ['Objective:To find a job that matches my experience, my strengths, and offers chances for advancement in the future'],
#   'exp': ['Experience:I have over 25 years experience working in Office Management, Accounting/Bookkeeping, and love what I do'],
#   'edu': [],
#   'skills': ['Skills:I am a quick learner, efficient, will work any hours necessary to meet jobs goals and objectives '],
#   'add_info': [],
#   'contact_info': ['Candidate Contact Information:']},
#  {'id': ['SpiderID: 55479'],
#   'emp_type': ['Type of Position: Full-Time Permanent'],
#   'availability': ['Availability Date: 11/1/2011'],
#   'desired_wage': ['Desired Wage: 42,000.00'],
#   'work_auth': ['U.S. Work Authorization: Yes'],
#   'job_level': ['Job Level: Experienced with over 2 years experience'],
#   'will_travel': ['Willing to Travel: Yes, Less Than 25%'],
#   'edu_level': ['Highest Degree Attained: Other'],
#   'will_reloc': ['Willing to Relocate: Undecided'],
#   'objective': ['Objective:Seeking a challenging position in a company where my financial services experience will have available application.'],
#   'exp': ['Experience:The past 12 years with the Hartford Life Disability Insurance Company has provided me with the opportunity to perform many tasks, strive for and achieve many goals, and hone many skills. I have worked with financial transactions and the inner workings and financial impacts of disability insurance. I believe my success with these tasks has prepared me for further challenges and aspirations. Cross training was emphasized and it provided me with exposure to all of the functions within the area I reported.'],
#   'edu': [],
#   'skills': ['Skills:Customer Service\t\t\t\t\t    Unclaimed Property\t\t                                                                             Check Reversals\t\t\t\t\t\t\t\t       Refund Posting\t\t\t\t\t\t\t\t\t                          Data Source System Balancing\t\t\t              \t\t  Third-Party Account Balancing and ReversalsTax Account ReconciliationsExpense PaymentsTrainingCustodian for Annuity Vendor'],
#   'add_info': [],
#   'contact_info': ['Candidate Contact Information:']},
#  {'id': ['SpiderID: 55478'],
#   'emp_type': ['Type of Position: Full-Time Permanent'],
#   'availability': ['Availability Date: Immediately'],
#   'desired_wage': ['Desired Wage: 45000'],
#   'work_auth': ['U.S. Work Authorization: Yes'],
#   'job_level': ['Job Level: Experienced with over 2 years experience'],
#   'will_travel': ['Willing to Travel: Yes, 25-50%'],
#   'edu_level': ['Highest Degree Attained: Bachelors'],
#   'will_reloc': ['Willing to Relocate: No'],
#   'objective': ['Objective:Self-motivated, quality-focused, and resourceful candidate, offering progressive experience in developing business’ operational and financial effectiveness. Hardworking and effective in multitasking, with impressive background in improving efficiency and accuracy in accomplishing assigned tasks. Highly capable of solving problems and creating new opportunities for the organization to increase growth and efficiency. Competent in maximizing performance of financial operations concentrating on analysis, financial modeling, strategy formulation, budget implementation, cost reduction, and profitability improvement. Adept at simplifying and negotiating complex financial scenarios in adherence with company’s policies and procedures. Equipped with the ability to establish good relationships and communicate with people at all levels and with diverse backgrounds. Articulate communicator with fluency in Farsi, Dari, and English languages; conversant in Russian and Indian. Proficient in Microsoft Office Suite (Word, Excel, and Power Point).'],
#   'exp': ['Experience:ROOHIN NABIZADA INC. - TASHKENT, UZBEKISTAN\tAccounting Auditor\t2002-PRESENT-\tPrepare and perform bi-weekly bank account consolidation and expense reports.-\tCarry out all activities in updating company payroll and banking account databases.-\tManage accounts payable and receivable transactions.TD BANK - GERMANTOWN, MD, USA\tCustomer Service Representative\t2006-2009-\tRendered exceptional customer service in opening accounts, taking loan applications, and assisting customers with account-related problems.-\tEarned $50,000 extra income for TD Bank clients by coordinating extracurricular sporting events and several initiatives for bank subsidiary.-\tSuccessfully attained revenue and customer retention goals while boosting client profitability through relationship-building, excellent customer service delivery, cross-selling, and customer referral development.CLOSELINE SETTLEMENT INC. - ROCKVILLE, MD, USA\tHead Quarter Funder\t2004-2006-\tAnalyzed more than 50 HUD1 Settlement Statements daily, made sure that all liens had payoff statements or subordination agreements and that other necessary documents were in client’s file prior to ordering closing funds.-\tAdministered ordering of funds for settlement and monitoring of funding activities for six close line offices in three states, namely Ohio, Pennsylvania, and Florida.-\tHeld accountability in processing settlement checks in a timely matter-\tReceived “Employee of the Month” award five times for diligence, dedication, and fast workmanship.OTHER EXPERIENCEMONTGOMERY COLLEGE (TECHNOLOGY LABORATORY) ~ GERMANTOWN, MD, USA\tLaboratory Assistant\t2000–2004NORDSTROM MONTGOMERY MALL ~ BETHESDA, MD, USA\tSales Consultant/Cashier\t1999–2003'],
#   'edu': ['Education:Bachelor of Science in Business Administration Minor in Finance (2011)UNIVERSITY OF MARYLAND UNIVERSITY COLLEGE (UMUC) ~ ADELPHI, MDAssociate of Arts in General Studies (2004)MONTGOMERY COLLEGE ~ GERMANTOWN, MD'],
#   'skills': ['Skills:Strategic and Tactical Planning\tTime Management and Scheduling\tCustomer Relations ManagementInterpersonal Relations\tFinancial Planning and Analysis\tReporting and Documentation'],
#   'add_info': ['Additional Information:AWARDS AND HONORSAward for participating to a Java competition ~ Montgomery College (2010)'],
#   'contact_info': ['Candidate Contact Information:']},
#  {'id': ['SpiderID: 55472'],
#   'emp_type': ['Type of Position: Full-Time Permanent'],
#   'availability': ['Availability Date: 11/2/11'],
#   'desired_wage': ['Desired Wage: 75000'],
#   'work_auth': ['U.S. Work Authorization: Yes'],
#   'job_level': ['Job Level: Experienced with over 2 years experience'],
#   'will_travel': ['Willing to Travel: Yes, 25-50%'],
#   'edu_level': ['Highest Degree Attained: MBA'],
#   'will_reloc': ['Willing to Relocate: No'],
#   'objective': [],
#   'exp': [],
#   'edu': [],
#   'skills': [],
#   'add_info': [],
#   'contact_info': ['Candidate Contact Information:']}]

# %%
# Convert scraped data into DataFrame
table2 = pd.DataFrame(cv_dict)

# %%
# Checking the tail of table2 to identify the id of the last resume
table2.tail()
# Out:
#                     id                                 emp_type  \
# 795  [SpiderID: 55525]                [Type of Position: Other]
# 796  [SpiderID: 55501]  [Type of Position: Full-Time Permanent]
# 797  [SpiderID: 55479]  [Type of Position: Full-Time Permanent]
# 798  [SpiderID: 55478]  [Type of Position: Full-Time Permanent]
# 799  [SpiderID: 55472]  [Type of Position: Full-Time Permanent]
#
#                          availability               desired_wage  \
# 795         [Availability Date: ASAP]           [Desired Wage: ]
# 796     [Availability Date: 11-02-11]     [Desired Wage: 24,000]
# 797    [Availability Date: 11/1/2011]  [Desired Wage: 42,000.00]
# 798  [Availability Date: Immediately]      [Desired Wage: 45000]
# 799      [Availability Date: 11/2/11]      [Desired Wage: 75000]
#
#                           work_auth  \
# 795  [U.S. Work Authorization: Yes]
# 796     [U.S. Work Authorization: ]
# 797  [U.S. Work Authorization: Yes]
# 798  [U.S. Work Authorization: Yes]
# 799  [U.S. Work Authorization: Yes]
#
#                                              job_level  \
# 795                  [Job Level: New Grad/Entry Level]
# 796  [Job Level: Experienced with over 2 years expe...
# 797  [Job Level: Experienced with over 2 years expe...
# 798  [Job Level: Experienced with over 2 years expe...
# 799  [Job Level: Experienced with over 2 years expe...
#
#                                  will_travel  \
# 795                    [Willing to Travel: ]
# 796  [Willing to Travel: Yes, Less Than 25%]
# 797  [Willing to Travel: Yes, Less Than 25%]
# 798         [Willing to Travel: Yes, 25-50%]
# 799         [Willing to Travel: Yes, 25-50%]
#
#                                              edu_level  \
# 795                   [Highest Degree Attained: Other]
# 796  [Highest Degree Attained: High School/Equivalent]
# 797                   [Highest Degree Attained: Other]
# 798               [Highest Degree Attained: Bachelors]
# 799                     [Highest Degree Attained: MBA]
#
#                            will_reloc  \
# 795        [Willing to Relocate: Yes]
# 796        [Willing to Relocate: Yes]
# 797  [Willing to Relocate: Undecided]
# 798         [Willing to Relocate: No]
# 799         [Willing to Relocate: No]
#
#                                              objective  \
# 795          [Objective:Bookkeeper/Accountant/Office ]
# 796  [Objective:To find a job that matches my exper...
# 797  [Objective:Seeking a challenging position in a...
# 798  [Objective:Self-motivated, quality-focused, an...
# 799                                                 []
#
#                                                    exp  \
# 795              [Experience:Please read next section]
# 796  [Experience:I have over 25 years experience wo...
# 797  [Experience:The past 12 years with the Hartfor...
# 798  [Experience:ROOHIN NABIZADA INC. - TASHKENT, U...
# 799                                                 []
#
#                                                    edu  \
# 795                                [Education:College]
# 796                                                 []
# 797                                                 []
# 798  [Education:Bachelor of Science in Business Adm...
# 799                                                 []
#
#                                                 skills  \
# 795                      [Skills:Soft and hard skills]
# 796  [Skills:I am a quick learner, efficient, will ...
# 797  [Skills:Customer Service\t\t\t\t\t    Unclaime...
# 798  [Skills:Strategic and Tactical Planning\tTime ...
# 799                                                 []
#
#                                               add_info  \
# 795  [Additional Information:Bookkeeper/accounting ...
# 796                                                 []
# 797                                                 []
# 798  [Additional Information:AWARDS AND HONORSAward...
# 799                                                 []
#
#                          contact_info
# 795  [Candidate Contact Information:]
# 796  [Candidate Contact Information:]
# 797  [Candidate Contact Information:]
# 798  [Candidate Contact Information:]
# 799  [Candidate Contact Information:]

# %%
# As table1 has a shape of 1500 rows, deleting the last 700 rows so that we can concatenate with table2 which has a shape of 800
# Double check where to delete from table1 : based on the last id of table2 i.e. 55472
table1 = table1.iloc[0:800]

# %%
# Concatenate table1 and table2
df_accounting = pd.concat([table1, table2], axis=1)

# %%
# Checking out the shape and first 5 items
print(df_accounting.shape)
df_accounting.head()
# Out:
# (800, 21)
#   sn date_posted                   job_func_sought                category  \
# 0  1   3/30/2020            bookkeeping/accounting  Accounting/Bookkeeping
# 1  2   3/16/2020  stainless steel decorative sheet  Accounting/Bookkeeping
# 2  3    3/4/2020                        accountant  Accounting/Bookkeeping
# 3  4   2/27/2020                   admin assistant  Accounting/Bookkeeping
# 4  5   2/27/2020                   admin assistant  Accounting/Bookkeeping
#
#         location                  resume_href                 id  \
# 0  Dartmouth, NS  /job/view-resume-82533.html  [SpiderID: 82533]
# 1       Xian, AL  /job/view-resume-82510.html  [SpiderID: 82510]
# 2    Orlando, FL  /job/view-resume-82487.html  [SpiderID: 82487]
# 3   Brampton, ON  /job/view-resume-82476.html  [SpiderID: 82476]
# 4   Brampton, ON  /job/view-resume-82475.html  [SpiderID: 82475]
#
#                                   emp_type               availability  \
# 0  [Type of Position: Full-Time Permanent]      [Availability Date: ]
# 1  [Type of Position: Full-Time Permanent]      [Availability Date: ]
# 2           [Type of Position: Contractor]      [Availability Date: ]
# 3  [Type of Position: Full-Time Permanent]  [Availability Date: ASAP]
# 4  [Type of Position: Full-Time Permanent]      [Availability Date: ]
#
#               desired_wage  ...  \
# 0         [Desired Wage: ]  ...
# 1         [Desired Wage: ]  ...
# 2         [Desired Wage: ]  ...
# 3  [Desired Wage: $20-$25]  ...
# 4         [Desired Wage: ]  ...
#
#                                            job_level              will_travel  \
# 0  [Job Level: Experienced with over 2 years expe...    [Willing to Travel: ]
# 1                  [Job Level: New Grad/Entry Level]    [Willing to Travel: ]
# 2        [Job Level: Management (Manager, Director)]  [Willing to Travel: No]
# 3                  [Job Level: New Grad/Entry Level]  [Willing to Travel: No]
# 4                  [Job Level: New Grad/Entry Level]    [Willing to Travel: ]
#
#                               edu_level                        will_reloc  \
# 0  [Highest Degree Attained: Bachelors]           [Willing to Relocate: ]
# 1           [Highest Degree Attained: ]           [Willing to Relocate: ]
# 2           [Highest Degree Attained: ]         [Willing to Relocate: No]
# 3    [Highest Degree Attained: Masters]  [Willing to Relocate: Undecided]
# 4           [Highest Degree Attained: ]           [Willing to Relocate: ]
#
#                                            objective  \
# 0  [Objective:Bookkeeping/Finance professional wi...
# 1  [Objective:Shaanxi Tonghui Steel Co., Ltd. is ...
# 2                                                 []
# 3  [Objective:A positive and motivated IT Post-gr...
# 4                                                 []
#
#                                                  exp  \
# 0  [Experience:Finance and Administration Directo...
# 1                                                 []
# 2                                                 []
# 3  [Experience:BS Computers, Punjab, India•\tDiag...
# 4                                                 []
#
#                                                  edu  \
# 0  [Education:EducationBSc. in Applied Accounting...
# 1                                                 []
# 2                                                 []
# 3  [Education:Master of Information technology\t\...
# 4                                                 []
#
#                                               skills  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3  [Skills:Computer software: Microsoft world (Wo...
# 4                                                 []
#
#                                             add_info  \
# 0  [Additional Information:Certifications• QuickB...
# 1                                                 []
# 2                                                 []
# 3  [Additional Information:•\tKeen Learner•\tSoun...
# 4                                                 []
#
#                        contact_info
# 0  [Candidate Contact Information:]
# 1  [Candidate Contact Information:]
# 2  [Candidate Contact Information:]
# 3  [Candidate Contact Information:]
# 4  [Candidate Contact Information:]
#
# [5 rows x 21 columns]

# %%
# removing the square brackets in each entries

df_accounting['id'] = df_accounting['id'].str.get(0)
df_accounting['emp_type'] = df_accounting['emp_type'].str.get(0)
df_accounting['availability'] = df_accounting['availability'].str.get(0)
df_accounting['desired_wage'] = df_accounting['desired_wage'].str.get(0)
df_accounting['work_auth'] = df_accounting['work_auth'].str.get(0)
df_accounting['job_level'] = df_accounting['job_level'].str.get(0)
df_accounting['will_travel'] = df_accounting['will_travel'].str.get(0)
df_accounting['edu_level'] = df_accounting['edu_level'].str.get(0)
df_accounting['will_reloc'] = df_accounting['will_reloc'].str.get(0)
df_accounting['objective'] = df_accounting['objective'].str.get(0)
df_accounting['exp'] = df_accounting['exp'].str.get(0)
df_accounting['edu'] = df_accounting['edu'].str.get(0)
df_accounting['skills'] = df_accounting['skills'].str.get(0)
df_accounting['add_info'] = df_accounting['add_info'].str.get(0)
df_accounting['contact_info'] = df_accounting['contact_info'].str.get(0)

# %%
# Final check of the dataframe
df_accounting.head()
# Out:
#   sn date_posted                   job_func_sought                category  \
# 0  1   3/30/2020            bookkeeping/accounting  Accounting/Bookkeeping
# 1  2   3/16/2020  stainless steel decorative sheet  Accounting/Bookkeeping
# 2  3    3/4/2020                        accountant  Accounting/Bookkeeping
# 3  4   2/27/2020                   admin assistant  Accounting/Bookkeeping
# 4  5   2/27/2020                   admin assistant  Accounting/Bookkeeping
#
#         location                  resume_href               id  \
# 0  Dartmouth, NS  /job/view-resume-82533.html  SpiderID: 82533
# 1       Xian, AL  /job/view-resume-82510.html  SpiderID: 82510
# 2    Orlando, FL  /job/view-resume-82487.html  SpiderID: 82487
# 3   Brampton, ON  /job/view-resume-82476.html  SpiderID: 82476
# 4   Brampton, ON  /job/view-resume-82475.html  SpiderID: 82475
#
#                                 emp_type             availability  \
# 0  Type of Position: Full-Time Permanent      Availability Date:
# 1  Type of Position: Full-Time Permanent      Availability Date:
# 2           Type of Position: Contractor      Availability Date:
# 3  Type of Position: Full-Time Permanent  Availability Date: ASAP
# 4  Type of Position: Full-Time Permanent      Availability Date:
#
#             desired_wage  ...  \
# 0         Desired Wage:   ...
# 1         Desired Wage:   ...
# 2         Desired Wage:   ...
# 3  Desired Wage: $20-$25  ...
# 4         Desired Wage:   ...
#
#                                            job_level            will_travel  \
# 0  Job Level: Experienced with over 2 years exper...    Willing to Travel:
# 1                    Job Level: New Grad/Entry Level    Willing to Travel:
# 2          Job Level: Management (Manager, Director)  Willing to Travel: No
# 3                    Job Level: New Grad/Entry Level  Willing to Travel: No
# 4                    Job Level: New Grad/Entry Level    Willing to Travel:
#
#                             edu_level                      will_reloc  \
# 0  Highest Degree Attained: Bachelors           Willing to Relocate:
# 1           Highest Degree Attained:            Willing to Relocate:
# 2           Highest Degree Attained:          Willing to Relocate: No
# 3    Highest Degree Attained: Masters  Willing to Relocate: Undecided
# 4           Highest Degree Attained:            Willing to Relocate:
#
#                                            objective  \
# 0  Objective:Bookkeeping/Finance professional wit...
# 1  Objective:Shaanxi Tonghui Steel Co., Ltd. is a...
# 2                                                NaN
# 3  Objective:A positive and motivated IT Post-gra...
# 4                                                NaN
#
#                                                  exp  \
# 0  Experience:Finance and Administration Director...
# 1                                                NaN
# 2                                                NaN
# 3  Experience:BS Computers, Punjab, India•\tDiagn...
# 4                                                NaN
#
#                                                  edu  \
# 0  Education:EducationBSc. in Applied Accounting,...
# 1                                                NaN
# 2                                                NaN
# 3  Education:Master of Information technology\t\t...
# 4                                                NaN
#
#                                               skills  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Skills:Computer software: Microsoft world (Wor...
# 4                                                NaN
#
#                                             add_info  \
# 0  Additional Information:Certifications• QuickBo...
# 1                                                NaN
# 2                                                NaN
# 3  Additional Information:•\tKeen Learner•\tSound...
# 4                                                NaN
#
#                      contact_info
# 0  Candidate Contact Information:
# 1  Candidate Contact Information:
# 2  Candidate Contact Information:
# 3  Candidate Contact Information:
# 4  Candidate Contact Information:
#
# [5 rows x 21 columns]

# %%
# Save a copy to csv
#df_accounting.to_csv('./datasets/Accounting.csv', index=False)
