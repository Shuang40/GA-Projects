# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Capstone - Resumes and Job Ads Recommender

# %% [markdown]
# # Problem Statement
#
# HR practitioners and/or hiring managers could have been spending too much time trying to sieve through many resumes for shortlisting suitable candidates whom they can contact for interview.
# As a job seeker, we may also find ourselves spending so much times looking through plentiful job advertisements which may not be relevant to us.
# Wouldn't it be nice if pre-selection can be done which will effectively save time for all of us?
#
# We will be using Natural Language Processing (NLP) and Recommender System. Using cosine similarity, to identify similar job seekers / job advertisements.
# Success will be evaluated based on the top recommendations and its features to see how closely matched are the jobs for the job seekers and vice versa.

# %% [markdown]
# # Executive Summary
#
# We scrape the website jobspider.com for resumes. In view that api key is not available, we used BeautifulSoup and regex to get the desired information. As we encounter roadblock on the time connection timeout despite introducing bot agent, we limit the job categories to Accounting and Information Technology for this capstone.
# For the job ads, we based it on existing dataset that is available on Kaggle which was used for predicting fake job posting since the features in this dataset has 80% simiarity to the resumes dataset.
#
# As we were cleaning the resumes dataset,we also decide which features will be important for us to have and which are the one to drop. In view that job title, objective, experience and skills are free texts that hold meaningful words for our analysis, we create a new feature and combine all where we then split the text into words, return them to their root form and also remove the stop words. These are performed for the job ads dataset as well.
# We use TFidfVectorizer to calculate the weight of the words and not surprisely, words appear in resumes and often found in job ads.
#
# For feature selection, we picked `location`, `education level`, `employment type`, `function`, `job level` as our initial criteria. We then put these features through cosine similarity metric, measuring the consine of the angle the features projected in a multi-dimension space to determine their similarity.
#
# Noting that our dataset comprises of both job ads and resumes, we then need to slice the dataset together with the similarity scores that showcase resumes on the row index and job ads on the columns.
#
# With that, we will be able to filter based on resumes returning top similarity scores for job ads and by tranposing the dataset, we then will also be able to get recommendated resumes based on similarity scores against job ads.
#
#
# ### Contents:
# - [Pre-processing](#Pre-processing)
# - [Data Dictionary](#Data-Dictionary)
# - [Recommender System](#Recommender-System)
# - [Conclusion](#Conclusion)
# - [Limitation and Future Works](#Limitation-and-Future-Works)

# %%
import requests
import time
import pandas as pd
import numpy as np
import random
import matplotlib as plt
import seaborn as sns
import re
from scipy import sparse
from sklearn.metrics.pairwise import cosine_similarity, pairwise_distances
from IPython.display import HTML, display

# %matplotlib inline
# Out:
# C:\Users\eukar\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # Pre-processing

# %%
# Import resumes dataset
resumes = pd.read_csv('.\datasets\\resumes.csv')
resumes.head()
# Out:
#   date_posted                                    job_title    industry state  \
# 0  2020-02-22                                      auditor  Accounting    TX
# 1  2020-02-11                            senior accountant  Accounting    OH
# 2  2020-01-31  senior/mid-level financial services manager  Accounting    TX
# 3  2020-01-16                         brokerage operations  Accounting    NY
# 4  2019-12-16                       full charge bookkeeper  Accounting    CO
#
#   state_name                  resume_href     id   emp_type availability  \
# 0      Texas  /job/view-resume-82470.html  82470   contract   02/22/2020
# 1       Ohio  /job/view-resume-82450.html  82450  full-time     2/1/2020
# 2      Texas  /job/view-resume-82423.html  82423  full-time          NaN
# 3   New York  /job/view-resume-82397.html  82397  full-time    Immediate
# 4   Colorado  /job/view-resume-82338.html  82338  full-time          NaN
#
#   desired_wage  ...   job_level will_travel    edu_level will_reloc  \
# 0          NaN  ...  mid_senior         Yes      masters        Yes
# 1    75,000.00  ...  mid_senior          No  high_school         No
# 2          NaN  ...  mid_senior         Yes    bachelors        Yes
# 3        90000  ...  mid_senior          No  certificate         No
# 4        35000  ...   associate          No    bachelors         No
#
#                                            objective  \
# 0  Strategist provides clients with more than a d...
# 1                                                NaN
# 2  Growth-focused and astute executive and influe...
# 3  Analytical, performance-focused, and forward-t...
# 4  Dynamic, goal-oriented, and analytical profess...
#
#                                                  exp  \
# 0  CPA Firm Consultant, Auditgoals.com 2019 - 202...
# 1  Accomplished finance and accounting profession...
# 2  WELLS FARGO ▪ DALLAS, TX (1994–2019)Senior Vic...
# 3  SOCIÉTÉ GÉNÉRALE – JERSEY CITY, NJVice Preside...
# 4  Echo River Expeditions, Cañon City, COReservat...
#
#                                                  edu  \
# 0  Master of Business Administration, FinanceBach...
# 1       Three years at University Wisconsin Superior
# 2  EDUCATIONApplied Business Administration Manag...
# 3  SCS Business and Technical Institute -New York...
# 4  Coursework in Accounting and ComputerBessemer ...
#
#                                               skills  \
# 0                                                NaN
# 1  BudgetsAdvanced ExcelFinancial StatementsStaff...
# 2  Banking Administration | Risk Mitigation |Staf...
# 3  Trade Posting and Payment EscalationInvestment...
# 4  Microsoft Office Applications (Excel, Word, Po...
#
#                                             add_info  \
# 0                                                NaN
# 1  Software:Microsoft Dynamics GPPrism HRUltiproD...
# 2                                                NaN
# 3  EARLIER CAREERMAN FINANCIAL, INC. – NEW YORK, ...
# 4                                                NaN
#
#                                         combine_text
# 0  auditor strategist provides client decade hand...
# 1  senior accountant accomplished finance account...
# 2  senior mid level financial service manager gro...
# 3  brokerage operation analytical performance foc...
# 4  full charge bookkeeper dynamic goal oriented a...
#
# [5 rows x 21 columns]

# %%
# combine id and job_title as 1 for our index
resumes['index'] = 'R' + '_' + resumes['id'].astype(str) + '_' + resumes['job_title']

# %%
# Select features that we want to keep
res_df = resumes[['index', 'industry', 'state_name', 'emp_type', 'job_level', 'edu_level']]

# set id as the index
res_df = res_df.set_index('index')

res_df.head()
# Out:
#                                                       industry state_name  \
# index
# R_82470_auditor                                     Accounting      Texas
# R_82450_senior accountant                           Accounting       Ohio
# R_82423_senior/mid-level financial services man...  Accounting      Texas
# R_82397_ brokerage operations                       Accounting   New York
# R_82338_full charge bookkeeper                      Accounting   Colorado
#
#                                                      emp_type   job_level  \
# index
# R_82470_auditor                                      contract  mid_senior
# R_82450_senior accountant                           full-time  mid_senior
# R_82423_senior/mid-level financial services man...  full-time  mid_senior
# R_82397_ brokerage operations                       full-time  mid_senior
# R_82338_full charge bookkeeper                      full-time   associate
#
#                                                       edu_level
# index
# R_82470_auditor                                         masters
# R_82450_senior accountant                           high_school
# R_82423_senior/mid-level financial services man...    bachelors
# R_82397_ brokerage operations                       certificate
# R_82338_full charge bookkeeper                        bachelors

# %% [markdown]
# As previously, we just assign number to the state names in accordance to alphabetical order, we get recommendations for location that could be far away from job seeker / job ads preference. Hence, we noq include 1 more feature name region.

# %%
# Listed out the states and it's region with reference from
# https://www.worldatlas.com/articles/the-regions-of-the-united-states.html

west = ['Alaska', 'Arizona', 'California', 'Colorado', 'Hawaii', 'Idaho', 'Montana', 'Nevada','New Mexico', 'Oregon',
       'Utah', 'Washington', 'Wyoming']

midwest = ['Illinois', 'Indiana', 'Iowa', 'Kansas', 'Michigan', 'Missouri', 'Minnesota', 'Nebraska', 'North Dakota', 
           'Ohio', 'South Dakota','Wisconsin']

south = ['Alabama', 'Arkansas', 'Delaware', 'Florida', 'Georgia', 'Kentucky', 'Louisiana', 'Maryland', 'Mississippi',
        'Oklahoma', 'North Carolina', 'South Carolina', 'Tennessee', 'Texas', 'Virginia', 'West Virginia', 'WashingtonDC']

northeast = ['Connecticut', 'Maine', 'New Hampshire', 'Massachusetts', 'New Jersey', 'New York', 'Pennsylvania',
            'Rhode Island', 'Vermont']

print('Number of states in the west region: ', len(west))
print('Number of states in the midwest region: ', len(midwest))
print('Number of states in the south region: ', len(south))
print('Number of states in the northeast region: ', len(northeast))
# Out:
# Number of states in the west region:  13
# Number of states in the midwest region:  12
# Number of states in the south region:  17
# Number of states in the northeast region:  9

# %%
# To create 1 new feature 'region' for indicating the region of the states
region = []

for s in res_df['state_name']:
    if s in west:
        region.append('west')
    elif s in midwest:
        region.append('midwest')
    elif s in south:
        region.append('south')
    else:
        region.append('northeast')
        
res_df['region'] = region
res_df.head()
# Out:
#                                                       industry state_name  \
# index
# R_82470_auditor                                     Accounting      Texas
# R_82450_senior accountant                           Accounting       Ohio
# R_82423_senior/mid-level financial services man...  Accounting      Texas
# R_82397_ brokerage operations                       Accounting   New York
# R_82338_full charge bookkeeper                      Accounting   Colorado
#
#                                                      emp_type   job_level  \
# index
# R_82470_auditor                                      contract  mid_senior
# R_82450_senior accountant                           full-time  mid_senior
# R_82423_senior/mid-level financial services man...  full-time  mid_senior
# R_82397_ brokerage operations                       full-time  mid_senior
# R_82338_full charge bookkeeper                      full-time   associate
#
#                                                       edu_level     region
# index
# R_82470_auditor                                         masters      south
# R_82450_senior accountant                           high_school    midwest
# R_82423_senior/mid-level financial services man...    bachelors      south
# R_82397_ brokerage operations                       certificate  northeast
# R_82338_full charge bookkeeper                        bachelors       west

# %%
# Import job ads dataset
jobs = pd.read_csv('.\datasets\\job_ads.csv')
print(jobs.shape)
jobs.head()
# Out:
# (792, 19)
#    job_id                                              title state  \
# 0       9  ASP.net Developer Job opportunity at United St...    NJ
# 1      10                   Applications Developer, Digital     CT
# 2      38                          Technical Project Manager    NY
# 3      49  Ruby Automation Engineer & Ruby on Rails Engin...    CA
# 4      54               Mid-Senior .NET or Xamarin Developer    GA
#
#     state_name department   salary_range  \
# 0   New Jersey        NaN  100000-120000
# 1  Connecticut        NaN            NaN
# 2     New York        NaN            NaN
# 3   California         IT            NaN
# 4      Georgia        NaN         75-115
#
#                                      company_profile  \
# 0                                                NaN
# 1  Novitex Enterprise Solutions, formerly Pitney ...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          description  \
# 0  DeveloperJob Location :United States-New Jerse...
# 1  The Applications Developer, Digital will devel...
# 2  GBI is a growing company developing several cu...
# 3   # 1Ruby Automation Engineer Menlo Park, CA # ...
# 4  DataFinch Technologies is the leader in electr...
#
#                                          requirement  \
# 0   #URL_86fd830a95a64e2b30ceed829e63fd384c289e4f...
# 1  s:4 â 5 yearsâ experience in developing an...
# 2  Must have excellent oral and written communica...
# 3  Position # 1Ruby Automation EngineerLocation: ...
# 4  We are looking for candidates who are generall...
#
#                                             benefits  telecommuting  \
# 0  Benefits - FullBonus Eligible - YesInterview T...              0
# 1                                                NaN              0
# 2  Experience with CRM, such as SugarCRM.Past emp...              0
# 3                                                NaN              0
# 4  Health, Vision, Dental, FSA, HSA, 401(k)Privat...              0
#
#    has_company_logo  has_questions employment_type required_experience  \
# 0                 0              0       full-time          mid_senior
# 1                 1              0       full-time           associate
# 2                 0              0       full-time           associate
# 3                 0              1        contract          mid_senior
# 4                 0              0       full-time          mid_senior
#
#   required_education                             industry  \
# 0          bachelors  Information Technology and Services
# 1          bachelors                Management Consulting
# 2          bachelors                   Financial Services
# 3             degree                                  NaN
# 4          bachelors                    Computer Software
#
#                  function                                       combine_text
# 0  Information Technology  asp net developer job opportunity united state...
# 1  Information Technology  application developer digital application deve...
# 2  Information Technology  technical project manager gbi growing company ...
# 3  Information Technology  ruby automation engineer ruby rail engineer 2 ...
# 4  Information Technology  mid senior net xamarin developer datafinch tec...

# %%
# combine id and job_title as 1 for our index
jobs['index'] = 'J' + '_' + jobs['job_id'].astype(str) + '_' + jobs['title']

# %%
# Select features that we want to keep
jobs_df = jobs[['index', 'function', 'state_name', 'employment_type', 'required_experience', 'required_education']]

# set id as the index
jobs_df = jobs_df.set_index('index')
print(jobs_df.shape)
jobs_df.head()
# Out:
# (792, 5)
#                                                                   function  \
# index
# J_9_ASP.net Developer Job opportunity at United...  Information Technology
# J_10_Applications Developer, Digital                Information Technology
# J_38_Technical Project Manager                      Information Technology
# J_49_Ruby Automation Engineer & Ruby on Rails E...  Information Technology
# J_54_Mid-Senior .NET or Xamarin Developer           Information Technology
#
#                                                      state_name  \
# index
# J_9_ASP.net Developer Job opportunity at United...   New Jersey
# J_10_Applications Developer, Digital                Connecticut
# J_38_Technical Project Manager                         New York
# J_49_Ruby Automation Engineer & Ruby on Rails E...   California
# J_54_Mid-Senior .NET or Xamarin Developer               Georgia
#
#                                                    employment_type  \
# index
# J_9_ASP.net Developer Job opportunity at United...       full-time
# J_10_Applications Developer, Digital                     full-time
# J_38_Technical Project Manager                           full-time
# J_49_Ruby Automation Engineer & Ruby on Rails E...        contract
# J_54_Mid-Senior .NET or Xamarin Developer                full-time
#
#                                                    required_experience  \
# index
# J_9_ASP.net Developer Job opportunity at United...          mid_senior
# J_10_Applications Developer, Digital                         associate
# J_38_Technical Project Manager                               associate
# J_49_Ruby Automation Engineer & Ruby on Rails E...          mid_senior
# J_54_Mid-Senior .NET or Xamarin Developer                   mid_senior
#
#                                                    required_education
# index
# J_9_ASP.net Developer Job opportunity at United...          bachelors
# J_10_Applications Developer, Digital                        bachelors
# J_38_Technical Project Manager                              bachelors
# J_49_Ruby Automation Engineer & Ruby on Rails E...             degree
# J_54_Mid-Senior .NET or Xamarin Developer                   bachelors

# %%
# Check out the columns for each dataset
print(res_df.columns)
print('---------------------------------------------------------------------------------------')
print(jobs_df.columns)
# Out:
# Index(['industry', 'state_name', 'emp_type', 'job_level', 'edu_level',
#        'region'],
#       dtype='object')
# ---------------------------------------------------------------------------------------
# Index(['function', 'state_name', 'employment_type', 'required_experience',
#        'required_education'],
#       dtype='object')

# %%
# Rename industry in res_df to function
res_df.rename(columns={'industry':'function'}, inplace=True)

# Rename employment_type, required_experience and required_education in jobs_df to the same as res_df
jobs_df.rename(columns={'employment_type':'emp_type', 'required_experience': 'job_level',
                       'required_education':'edu_level'}, inplace=True)

# %%
# Check the revised columns name
print(res_df.columns)
print('---------------------------------------------------------------------------------------')
print(jobs_df.columns)
# Out:
# Index(['function', 'state_name', 'emp_type', 'job_level', 'edu_level',
#        'region'],
#       dtype='object')
# ---------------------------------------------------------------------------------------
# Index(['function', 'state_name', 'emp_type', 'job_level', 'edu_level'], dtype='object')

# %%
# To create 1 new feature 'region' for indicating the region of the states
region = []

for s in jobs_df['state_name']:
    if s in west:
        region.append('west')
    elif s in midwest:
        region.append('midwest')
    elif s in south:
        region.append('south')
    else:
        region.append('northeast')
        
jobs_df['region'] = region
jobs_df.head()
# Out:
#                                                                   function  \
# index
# J_9_ASP.net Developer Job opportunity at United...  Information Technology
# J_10_Applications Developer, Digital                Information Technology
# J_38_Technical Project Manager                      Information Technology
# J_49_Ruby Automation Engineer & Ruby on Rails E...  Information Technology
# J_54_Mid-Senior .NET or Xamarin Developer           Information Technology
#
#                                                      state_name   emp_type  \
# index
# J_9_ASP.net Developer Job opportunity at United...   New Jersey  full-time
# J_10_Applications Developer, Digital                Connecticut  full-time
# J_38_Technical Project Manager                         New York  full-time
# J_49_Ruby Automation Engineer & Ruby on Rails E...   California   contract
# J_54_Mid-Senior .NET or Xamarin Developer               Georgia  full-time
#
#                                                      job_level  edu_level  \
# index
# J_9_ASP.net Developer Job opportunity at United...  mid_senior  bachelors
# J_10_Applications Developer, Digital                 associate  bachelors
# J_38_Technical Project Manager                       associate  bachelors
# J_49_Ruby Automation Engineer & Ruby on Rails E...  mid_senior     degree
# J_54_Mid-Senior .NET or Xamarin Developer           mid_senior  bachelors
#
#                                                        region
# index
# J_9_ASP.net Developer Job opportunity at United...  northeast
# J_10_Applications Developer, Digital                northeast
# J_38_Technical Project Manager                      northeast
# J_49_Ruby Automation Engineer & Ruby on Rails E...       west
# J_54_Mid-Senior .NET or Xamarin Developer               south

# %%
# Append both datasets together
combine = res_df.append(jobs_df, sort=False)

# %%
# Check to ensure we append correctly
print('res_df shape: ', res_df.shape)
print('job_df shape: ', jobs_df.shape)
print('combine shape: ', combine.shape)
combine.head()
# Out:
# res_df shape:  (1286, 6)
# job_df shape:  (792, 6)
# combine shape:  (2078, 6)
#                                                       function state_name  \
# index
# R_82470_auditor                                     Accounting      Texas
# R_82450_senior accountant                           Accounting       Ohio
# R_82423_senior/mid-level financial services man...  Accounting      Texas
# R_82397_ brokerage operations                       Accounting   New York
# R_82338_full charge bookkeeper                      Accounting   Colorado
#
#                                                      emp_type   job_level  \
# index
# R_82470_auditor                                      contract  mid_senior
# R_82450_senior accountant                           full-time  mid_senior
# R_82423_senior/mid-level financial services man...  full-time  mid_senior
# R_82397_ brokerage operations                       full-time  mid_senior
# R_82338_full charge bookkeeper                      full-time   associate
#
#                                                       edu_level     region
# index
# R_82470_auditor                                         masters      south
# R_82450_senior accountant                           high_school    midwest
# R_82423_senior/mid-level financial services man...    bachelors      south
# R_82397_ brokerage operations                       certificate  northeast
# R_82338_full charge bookkeeper                        bachelors       west

# %% [markdown]
# Let's change all categorical features to nominal/ordinal.

# %%
# Change function to 1 is Accounting and 5 is Information Technology
combine['function'].replace(to_replace=['Accounting', 'Information Technology'], value=[1, 5], inplace=True)

# %%
# Change state_name to be represented by a number
# Check the number of state
print('There are {} unique states in state_name feature'. format(len(set(combine['state_name']))))
print('------------------------------------------------- ')
print(sorted(set(combine['state_name'])))
# Out:
# There are 49 unique states in state_name feature
# -------------------------------------------------
# ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Virginia', 'Washington', 'WashingtonDC', 'West Virginia', 'Wisconsin', 'Wyoming']

# %%
# Use pd.factorize to assign number to the state and create an nominal variable
combine['state_name'] = pd.factorize(combine['state_name'], sort=True)[0]

# %%
# Change emp_type to be represented by a number
# Check the number of emp_type
print('There are {} unique employment type in emp_type feature'. format(len(set(combine['emp_type']))))
print('-------------------------------------------------------- ')
print(set(combine['emp_type']))
# Out:
# There are 5 unique employment type in emp_type feature
# --------------------------------------------------------
# {'full-time', 'part-time', 'internship', 'other', 'contract'}

# %%
# Change emp_type to nominal
combine['emp_type'].replace(to_replace=['internship', 'part-time', 'contract', 'full-time', 'other'],
                           value=[1, 2, 3, 4, 5], inplace=True)

# %%
# Change job_level to be represented by a number
# Check the number of job_level
print('There are {} unique job level in job_level feature'. format(len(set(combine['job_level']))))
print('--------------------------------------------------- ')
print(set(combine['job_level']))
# Out:
# There are 5 unique job level in job_level feature
# ---------------------------------------------------
# {'executive', 'mid_senior', 'internship', 'entry_level', 'associate'}

# %%
# Change job_level to ordinal where 1 is internship, 2 is entry_level..... 5 is executive
combine['job_level'].replace(to_replace=['internship', 'entry_level', 'associate', 'mid_senior', 'executive'],
                           value=[1, 2, 3, 4, 5], inplace=True)

# %%
# Change edu_level to be represented by a number
# Check the number of edu_level
print('There are {} unique education level in edu_level feature'. format(len(set(combine['edu_level']))))
print('--------------------------------------------------------')
print(set(combine['edu_level']))
# Out:
# There are 7 unique education level in edu_level feature
# --------------------------------------------------------
# {'college', 'masters', 'bachelors', 'certificate', 'high_school', 'unspecified', 'degree'}

# %%
# Change edu_level to ordinal where 1 is unspecified, 2 is high_school, 3 is college..... 7 is masters
combine['edu_level'].replace(to_replace=['unspecified', 'high_school', 'college', 'certificate',
                                        'degree', 'bachelors', 'masters'],
                           value=[1, 2, 3, 4, 5, 6, 7], inplace=True)

# %%
# Change region to ordinal where 1 is west, 2 is midwest, 3 is south and 4 is northeast
combine['region'].replace(to_replace=['west', 'midwest', 'south', 'northeast'],
                           value=[1, 2, 3, 4], inplace=True)

# %%
# Check out the final output for the changes
combine.head()
# Out:
#                                                     function  state_name  \
# index
# R_82470_auditor                                            1          41
# R_82450_senior accountant                                  1          33
# R_82423_senior/mid-level financial services man...         1          41
# R_82397_ brokerage operations                              1          31
# R_82338_full charge bookkeeper                             1           5
#
#                                                     emp_type  job_level  \
# index
# R_82470_auditor                                            3          4
# R_82450_senior accountant                                  4          4
# R_82423_senior/mid-level financial services man...         4          4
# R_82397_ brokerage operations                              4          4
# R_82338_full charge bookkeeper                             4          3
#
#                                                     edu_level  region
# index
# R_82470_auditor                                             7       3
# R_82450_senior accountant                                   2       2
# R_82423_senior/mid-level financial services man...          6       3
# R_82397_ brokerage operations                               4       4
# R_82338_full charge bookkeeper                              6       1

# %% [markdown]
# ## Data Dictionary

# %%
# %%html
# <style>
# table {float:left}
# </style>
# Out:
# <style>
# table {float:left}
# </style>

# %% [markdown]
# | Data Dictionary selected features 	|                                                                                                        	|
# |:-----------------------------------	|:--------------------------------------------------------------------------------------------------------	|
# | function                          	| Accounting = 1 and Information Technology = 5                                                          	|
# | state_name                        	| Assigned number to each state in alphabetical order                                                    	|
# | emp_type                          	| internship = 1, part-time = 2, contract = 3, full-time = 4, other = 5                                  	|
# | job_level                         	| internship = 1, entry_level = 2, associate = 3, mid_senior = 4, executive = 5                          	|
# | edu_level                         	| unspecified = 1, high_school = 2, college = 3, certificate = 4, degree = 5, bachelors = 6, masters = 7 	|
# | region                            	| states by region where west = 1, midwest = 2, south = 3, northeast = 4                                 	|

# %%
# Get the mean centre of the matrix
def mean_centre(df):
    return(df.T - df.mean(axis=1)).T

combine_mc = mean_centre(combine)

# %%
# Get the similarity
sim_matrix = cosine_similarity(combine_mc)
combine_sim = pd.DataFrame(sim_matrix, columns=combine.index, index=combine.index)
combine_sim.head()
# Out:
# index                                               R_82470_auditor  \
# index
# R_82470_auditor                                            1.000000
# R_82450_senior accountant                                  0.989553
# R_82423_senior/mid-level financial services man...         0.999157
# R_82397_ brokerage operations                              0.995230
# R_82338_full charge bookkeeper                             0.492707
#
# index                                               R_82450_senior accountant  \
# index
# R_82470_auditor                                                      0.989553
# R_82450_senior accountant                                            1.000000
# R_82423_senior/mid-level financial services man...                   0.994157
# R_82397_ brokerage operations                                        0.996556
# R_82338_full charge bookkeeper                                       0.424512
#
# index                                               R_82423_senior/mid-level financial services manager  \
# index
# R_82470_auditor                                                                              0.999157
# R_82450_senior accountant                                                                    0.994157
# R_82423_senior/mid-level financial services man...                                           1.000000
# R_82397_ brokerage operations                                                                0.997760
# R_82338_full charge bookkeeper                                                               0.481347
#
# index                                               R_82397_ brokerage operations  \
# index
# R_82470_auditor                                                          0.995230
# R_82450_senior accountant                                                0.996556
# R_82423_senior/mid-level financial services man...                       0.997760
# R_82397_ brokerage operations                                            1.000000
# R_82338_full charge bookkeeper                                           0.444331
#
# index                                               R_82338_full charge bookkeeper  \
# index
# R_82470_auditor                                                           0.492707
# R_82450_senior accountant                                                 0.424512
# R_82423_senior/mid-level financial services man...                        0.481347
# R_82397_ brokerage operations                                             0.444331
# R_82338_full charge bookkeeper                                            1.000000
#
# index                                               R_82293_remote bookkeeper or ranch management  \
# index
# R_82470_auditor                                                                          0.454494
# R_82450_senior accountant                                                                0.514949
# R_82423_senior/mid-level financial services man...                                       0.472953
# R_82397_ brokerage operations                                                            0.480659
# R_82338_full charge bookkeeper                                                           0.557370
#
# index                                               R_82266_financial analyst  \
# index
# R_82470_auditor                                                      0.998301
# R_82450_senior accountant                                            0.989081
# R_82423_senior/mid-level financial services man...                   0.998337
# R_82397_ brokerage operations                                        0.996805
# R_82338_full charge bookkeeper                                       0.502186
#
# index                                               R_81922_financial analyst  \
# index
# R_82470_auditor                                                      0.315750
# R_82450_senior accountant                                            0.242434
# R_82423_senior/mid-level financial services man...                   0.303130
# R_82397_ brokerage operations                                        0.263734
# R_82338_full charge bookkeeper                                       0.981155
#
# index                                               R_81888_full or part time bookkeeping accounting  \
# index
# R_82470_auditor                                                                             0.997344
# R_82450_senior accountant                                                                   0.992535
# R_82423_senior/mid-level financial services man...                                          0.998959
# R_82397_ brokerage operations                                                               0.996529
# R_82338_full charge bookkeeper                                                              0.494903
#
# index                                               R_81854_accounting manager  \
# index
# R_82470_auditor                                                       0.273098
# R_82450_senior accountant                                             0.209369
# R_82423_senior/mid-level financial services man...                    0.260544
# R_82397_ brokerage operations                                         0.224398
# R_82338_full charge bookkeeper                                        0.951972
#
# index                                               ...  \
# index                                               ...
# R_82470_auditor                                     ...
# R_82450_senior accountant                           ...
# R_82423_senior/mid-level financial services man...  ...
# R_82397_ brokerage operations                       ...
# R_82338_full charge bookkeeper                      ...
#
# index                                               J_10240_Payroll Clerk  \
# index
# R_82470_auditor                                                  0.987488
# R_82450_senior accountant                                        0.996667
# R_82423_senior/mid-level financial services man...               0.992249
# R_82397_ brokerage operations                                    0.997551
# R_82338_full charge bookkeeper                                   0.393272
#
# index                                               J_10248_Accounting Clerk($20/hr)  \
# index
# R_82470_auditor                                                             0.986817
# R_82450_senior accountant                                                   0.994473
# R_82423_senior/mid-level financial services man...                          0.991560
# R_82397_ brokerage operations                                               0.996361
# R_82338_full charge bookkeeper                                              0.393184
#
# index                                               J_10257_Data Center Migration App Lead for FULL-TIME Opportunity.  \
# index
# R_82470_auditor                                                                              0.994187
# R_82450_senior accountant                                                                    0.989929
# R_82423_senior/mid-level financial services man...                                           0.994686
# R_82397_ brokerage operations                                                                0.990797
# R_82338_full charge bookkeeper                                                               0.424671
#
# index                                               J_10282_ iSeries Team Lead  \
# index
# R_82470_auditor                                                       0.962191
# R_82450_senior accountant                                             0.982086
# R_82423_senior/mid-level financial services man...                    0.967635
# R_82397_ brokerage operations                                         0.968930
# R_82338_full charge bookkeeper                                        0.300868
#
# index                                               J_10330_Accounts Payable Clerk  \
# index
# R_82470_auditor                                                           0.978802
# R_82450_senior accountant                                                 0.995816
# R_82423_senior/mid-level financial services man...                        0.986278
# R_82397_ brokerage operations                                             0.991366
# R_82338_full charge bookkeeper                                            0.403761
#
# index                                               J_10403_Payroll Clerk   \
# index
# R_82470_auditor                                                   0.986817
# R_82450_senior accountant                                         0.994473
# R_82423_senior/mid-level financial services man...                0.991560
# R_82397_ brokerage operations                                     0.996361
# R_82338_full charge bookkeeper                                    0.393184
#
# index                                               J_10412_Sr. Scm Web Development Technical Lead  \
# index
# R_82470_auditor                                                                           0.096804
# R_82450_senior accountant                                                                 0.024834
# R_82423_senior/mid-level financial services man...                                        0.074363
# R_82397_ brokerage operations                                                             0.010247
# R_82338_full charge bookkeeper                                                            0.524672
#
# index                                               J_10414_User Support Technician  \
# index
# R_82470_auditor                                                            0.976433
# R_82450_senior accountant                                                  0.988677
# R_82423_senior/mid-level financial services man...                         0.981234
# R_82397_ brokerage operations                                              0.983670
# R_82338_full charge bookkeeper                                             0.324691
#
# index                                               J_10422_Sr. SQL Server DBA  \
# index
# R_82470_auditor                                                       0.209639
# R_82450_senior accountant                                             0.297163
# R_82423_senior/mid-level financial services man...                    0.225740
# R_82397_ brokerage operations                                         0.221507
# R_82338_full charge bookkeeper                                       -0.231455
#
# index                                               J_10433_Payroll Accountant
# index
# R_82470_auditor                                                       0.998922
# R_82450_senior accountant                                             0.992427
# R_82423_senior/mid-level financial services man...                    0.999494
# R_82397_ brokerage operations                                         0.998288
# R_82338_full charge bookkeeper                                        0.480128
#
# [5 rows x 2078 columns]

# %%
# Using for and if to filter index that is only resumes
for i in range(len(combine_sim.index)):
    if combine_sim.index[i][0] == 'R':
        index_res = combine_sim.iloc[:i]

# Check the shape and head of the filtered dataframe
print(index_res.shape)
index_res.head()
# Out:
# (1285, 2078)
# index                                               R_82470_auditor  \
# index
# R_82470_auditor                                            1.000000
# R_82450_senior accountant                                  0.989553
# R_82423_senior/mid-level financial services man...         0.999157
# R_82397_ brokerage operations                              0.995230
# R_82338_full charge bookkeeper                             0.492707
#
# index                                               R_82450_senior accountant  \
# index
# R_82470_auditor                                                      0.989553
# R_82450_senior accountant                                            1.000000
# R_82423_senior/mid-level financial services man...                   0.994157
# R_82397_ brokerage operations                                        0.996556
# R_82338_full charge bookkeeper                                       0.424512
#
# index                                               R_82423_senior/mid-level financial services manager  \
# index
# R_82470_auditor                                                                              0.999157
# R_82450_senior accountant                                                                    0.994157
# R_82423_senior/mid-level financial services man...                                           1.000000
# R_82397_ brokerage operations                                                                0.997760
# R_82338_full charge bookkeeper                                                               0.481347
#
# index                                               R_82397_ brokerage operations  \
# index
# R_82470_auditor                                                          0.995230
# R_82450_senior accountant                                                0.996556
# R_82423_senior/mid-level financial services man...                       0.997760
# R_82397_ brokerage operations                                            1.000000
# R_82338_full charge bookkeeper                                           0.444331
#
# index                                               R_82338_full charge bookkeeper  \
# index
# R_82470_auditor                                                           0.492707
# R_82450_senior accountant                                                 0.424512
# R_82423_senior/mid-level financial services man...                        0.481347
# R_82397_ brokerage operations                                             0.444331
# R_82338_full charge bookkeeper                                            1.000000
#
# index                                               R_82293_remote bookkeeper or ranch management  \
# index
# R_82470_auditor                                                                          0.454494
# R_82450_senior accountant                                                                0.514949
# R_82423_senior/mid-level financial services man...                                       0.472953
# R_82397_ brokerage operations                                                            0.480659
# R_82338_full charge bookkeeper                                                           0.557370
#
# index                                               R_82266_financial analyst  \
# index
# R_82470_auditor                                                      0.998301
# R_82450_senior accountant                                            0.989081
# R_82423_senior/mid-level financial services man...                   0.998337
# R_82397_ brokerage operations                                        0.996805
# R_82338_full charge bookkeeper                                       0.502186
#
# index                                               R_81922_financial analyst  \
# index
# R_82470_auditor                                                      0.315750
# R_82450_senior accountant                                            0.242434
# R_82423_senior/mid-level financial services man...                   0.303130
# R_82397_ brokerage operations                                        0.263734
# R_82338_full charge bookkeeper                                       0.981155
#
# index                                               R_81888_full or part time bookkeeping accounting  \
# index
# R_82470_auditor                                                                             0.997344
# R_82450_senior accountant                                                                   0.992535
# R_82423_senior/mid-level financial services man...                                          0.998959
# R_82397_ brokerage operations                                                               0.996529
# R_82338_full charge bookkeeper                                                              0.494903
#
# index                                               R_81854_accounting manager  \
# index
# R_82470_auditor                                                       0.273098
# R_82450_senior accountant                                             0.209369
# R_82423_senior/mid-level financial services man...                    0.260544
# R_82397_ brokerage operations                                         0.224398
# R_82338_full charge bookkeeper                                        0.951972
#
# index                                               ...  \
# index                                               ...
# R_82470_auditor                                     ...
# R_82450_senior accountant                           ...
# R_82423_senior/mid-level financial services man...  ...
# R_82397_ brokerage operations                       ...
# R_82338_full charge bookkeeper                      ...
#
# index                                               J_10240_Payroll Clerk  \
# index
# R_82470_auditor                                                  0.987488
# R_82450_senior accountant                                        0.996667
# R_82423_senior/mid-level financial services man...               0.992249
# R_82397_ brokerage operations                                    0.997551
# R_82338_full charge bookkeeper                                   0.393272
#
# index                                               J_10248_Accounting Clerk($20/hr)  \
# index
# R_82470_auditor                                                             0.986817
# R_82450_senior accountant                                                   0.994473
# R_82423_senior/mid-level financial services man...                          0.991560
# R_82397_ brokerage operations                                               0.996361
# R_82338_full charge bookkeeper                                              0.393184
#
# index                                               J_10257_Data Center Migration App Lead for FULL-TIME Opportunity.  \
# index
# R_82470_auditor                                                                              0.994187
# R_82450_senior accountant                                                                    0.989929
# R_82423_senior/mid-level financial services man...                                           0.994686
# R_82397_ brokerage operations                                                                0.990797
# R_82338_full charge bookkeeper                                                               0.424671
#
# index                                               J_10282_ iSeries Team Lead  \
# index
# R_82470_auditor                                                       0.962191
# R_82450_senior accountant                                             0.982086
# R_82423_senior/mid-level financial services man...                    0.967635
# R_82397_ brokerage operations                                         0.968930
# R_82338_full charge bookkeeper                                        0.300868
#
# index                                               J_10330_Accounts Payable Clerk  \
# index
# R_82470_auditor                                                           0.978802
# R_82450_senior accountant                                                 0.995816
# R_82423_senior/mid-level financial services man...                        0.986278
# R_82397_ brokerage operations                                             0.991366
# R_82338_full charge bookkeeper                                            0.403761
#
# index                                               J_10403_Payroll Clerk   \
# index
# R_82470_auditor                                                   0.986817
# R_82450_senior accountant                                         0.994473
# R_82423_senior/mid-level financial services man...                0.991560
# R_82397_ brokerage operations                                     0.996361
# R_82338_full charge bookkeeper                                    0.393184
#
# index                                               J_10412_Sr. Scm Web Development Technical Lead  \
# index
# R_82470_auditor                                                                           0.096804
# R_82450_senior accountant                                                                 0.024834
# R_82423_senior/mid-level financial services man...                                        0.074363
# R_82397_ brokerage operations                                                             0.010247
# R_82338_full charge bookkeeper                                                            0.524672
#
# index                                               J_10414_User Support Technician  \
# index
# R_82470_auditor                                                            0.976433
# R_82450_senior accountant                                                  0.988677
# R_82423_senior/mid-level financial services man...                         0.981234
# R_82397_ brokerage operations                                              0.983670
# R_82338_full charge bookkeeper                                             0.324691
#
# index                                               J_10422_Sr. SQL Server DBA  \
# index
# R_82470_auditor                                                       0.209639
# R_82450_senior accountant                                             0.297163
# R_82423_senior/mid-level financial services man...                    0.225740
# R_82397_ brokerage operations                                         0.221507
# R_82338_full charge bookkeeper                                       -0.231455
#
# index                                               J_10433_Payroll Accountant
# index
# R_82470_auditor                                                       0.998922
# R_82450_senior accountant                                             0.992427
# R_82423_senior/mid-level financial services man...                    0.999494
# R_82397_ brokerage operations                                         0.998288
# R_82338_full charge bookkeeper                                        0.480128
#
# [5 rows x 2078 columns]

# %%
# Now we need to further filter the column of index_res dataframe to list only the jobs
res_jobs = index_res.filter(regex='J_')

# Check the shape and head of the res_jobs dataframe
print(res_jobs.shape)
res_jobs.head()
# Out:
# (1285, 792)
# index                                               J_9_ASP.net Developer Job opportunity at United States,New Jersey  \
# index
# R_82470_auditor                                                                              0.994142
# R_82450_senior accountant                                                                    0.987669
# R_82423_senior/mid-level financial services man...                                           0.994062
# R_82397_ brokerage operations                                                                0.989066
# R_82338_full charge bookkeeper                                                               0.432772
#
# index                                               J_10_Applications Developer, Digital   \
# index
# R_82470_auditor                                                                  0.575739
# R_82450_senior accountant                                                        0.481228
# R_82423_senior/mid-level financial services man...                               0.555691
# R_82397_ brokerage operations                                                    0.510094
# R_82338_full charge bookkeeper                                                   0.533002
#
# index                                               J_38_Technical Project Manager  \
# index
# R_82470_auditor                                                           0.992046
# R_82450_senior accountant                                                 0.984821
# R_82423_senior/mid-level financial services man...                        0.992179
# R_82397_ brokerage operations                                             0.987108
# R_82338_full charge bookkeeper                                            0.429062
#
# index                                               J_49_Ruby Automation Engineer & Ruby on Rails Engineer - 2 roles  \
# index
# R_82470_auditor                                                                              0.135198
# R_82450_senior accountant                                                                    0.088784
# R_82423_senior/mid-level financial services man...                                           0.118238
# R_82397_ brokerage operations                                                                0.058617
# R_82338_full charge bookkeeper                                                               0.428746
#
# index                                               J_54_Mid-Senior .NET or Xamarin Developer  \
# index
# R_82470_auditor                                                                      0.900818
# R_82450_senior accountant                                                            0.858192
# R_82423_senior/mid-level financial services man...                                   0.890917
# R_82397_ brokerage operations                                                        0.858976
# R_82338_full charge bookkeeper                                                       0.619225
#
# index                                               J_103_Web Developer  \
# index
# R_82470_auditor                                               -0.289073
# R_82450_senior accountant                                     -0.193178
# R_82423_senior/mid-level financial services man...            -0.265878
# R_82397_ brokerage operations                                 -0.270211
# R_82338_full charge bookkeeper                                -0.375520
#
# index                                               J_128_Manager, Network Engineering   \
# index
# R_82470_auditor                                                                0.632090
# R_82450_senior accountant                                                      0.532939
# R_82423_senior/mid-level financial services man...                             0.607200
# R_82397_ brokerage operations                                                  0.556507
# R_82338_full charge bookkeeper                                                 0.623706
#
# index                                               J_147_Service Desk (Help Desk/ Desktop Support) Tier 1/2 - Healthcare IT  \
# index
# R_82470_auditor                                                                              0.988488
# R_82450_senior accountant                                                                    0.991483
# R_82423_senior/mid-level financial services man...                                           0.991001
# R_82397_ brokerage operations                                                                0.988810
# R_82338_full charge bookkeeper                                                               0.394779
#
# index                                               J_149_SharePoint Developer and Administrator  \
# index
# R_82470_auditor                                                                         0.993644
# R_82450_senior accountant                                                               0.989469
# R_82423_senior/mid-level financial services man...                                      0.993829
# R_82397_ brokerage operations                                                           0.989411
# R_82338_full charge bookkeeper                                                          0.423313
#
# index                                               J_165_Senior Programme Analyst  \
# index
# R_82470_auditor                                                           0.972873
# R_82450_senior accountant                                                 0.988268
# R_82423_senior/mid-level financial services man...                        0.977547
# R_82397_ brokerage operations                                             0.980051
# R_82338_full charge bookkeeper                                            0.310960
#
# index                                               ...  \
# index                                               ...
# R_82470_auditor                                     ...
# R_82450_senior accountant                           ...
# R_82423_senior/mid-level financial services man...  ...
# R_82397_ brokerage operations                       ...
# R_82338_full charge bookkeeper                      ...
#
# index                                               J_10240_Payroll Clerk  \
# index
# R_82470_auditor                                                  0.987488
# R_82450_senior accountant                                        0.996667
# R_82423_senior/mid-level financial services man...               0.992249
# R_82397_ brokerage operations                                    0.997551
# R_82338_full charge bookkeeper                                   0.393272
#
# index                                               J_10248_Accounting Clerk($20/hr)  \
# index
# R_82470_auditor                                                             0.986817
# R_82450_senior accountant                                                   0.994473
# R_82423_senior/mid-level financial services man...                          0.991560
# R_82397_ brokerage operations                                               0.996361
# R_82338_full charge bookkeeper                                              0.393184
#
# index                                               J_10257_Data Center Migration App Lead for FULL-TIME Opportunity.  \
# index
# R_82470_auditor                                                                              0.994187
# R_82450_senior accountant                                                                    0.989929
# R_82423_senior/mid-level financial services man...                                           0.994686
# R_82397_ brokerage operations                                                                0.990797
# R_82338_full charge bookkeeper                                                               0.424671
#
# index                                               J_10282_ iSeries Team Lead  \
# index
# R_82470_auditor                                                       0.962191
# R_82450_senior accountant                                             0.982086
# R_82423_senior/mid-level financial services man...                    0.967635
# R_82397_ brokerage operations                                         0.968930
# R_82338_full charge bookkeeper                                        0.300868
#
# index                                               J_10330_Accounts Payable Clerk  \
# index
# R_82470_auditor                                                           0.978802
# R_82450_senior accountant                                                 0.995816
# R_82423_senior/mid-level financial services man...                        0.986278
# R_82397_ brokerage operations                                             0.991366
# R_82338_full charge bookkeeper                                            0.403761
#
# index                                               J_10403_Payroll Clerk   \
# index
# R_82470_auditor                                                   0.986817
# R_82450_senior accountant                                         0.994473
# R_82423_senior/mid-level financial services man...                0.991560
# R_82397_ brokerage operations                                     0.996361
# R_82338_full charge bookkeeper                                    0.393184
#
# index                                               J_10412_Sr. Scm Web Development Technical Lead  \
# index
# R_82470_auditor                                                                           0.096804
# R_82450_senior accountant                                                                 0.024834
# R_82423_senior/mid-level financial services man...                                        0.074363
# R_82397_ brokerage operations                                                             0.010247
# R_82338_full charge bookkeeper                                                            0.524672
#
# index                                               J_10414_User Support Technician  \
# index
# R_82470_auditor                                                            0.976433
# R_82450_senior accountant                                                  0.988677
# R_82423_senior/mid-level financial services man...                         0.981234
# R_82397_ brokerage operations                                              0.983670
# R_82338_full charge bookkeeper                                             0.324691
#
# index                                               J_10422_Sr. SQL Server DBA  \
# index
# R_82470_auditor                                                       0.209639
# R_82450_senior accountant                                             0.297163
# R_82423_senior/mid-level financial services man...                    0.225740
# R_82397_ brokerage operations                                         0.221507
# R_82338_full charge bookkeeper                                       -0.231455
#
# index                                               J_10433_Payroll Accountant
# index
# R_82470_auditor                                                       0.998922
# R_82450_senior accountant                                             0.992427
# R_82423_senior/mid-level financial services man...                    0.999494
# R_82397_ brokerage operations                                         0.998288
# R_82338_full charge bookkeeper                                        0.480128
#
# [5 rows x 792 columns]

# %%
# Saving a copy of the recommender system
res_jobs.to_csv('./datasets/res_jobs.csv', index=False)

# %% [markdown]
# ## Recommender System

# %%
# Check the job recommendation for job seekers in Accounting function
print('Job seeker id {} is looking for {} job'.format(res_jobs.index[0][2:7], res_jobs.index[0][8:15]))
print('----------------------------------------------')
print('Top 10 job recommendations:')
res_jobs.iloc[0,:].sort_values(ascending=False)[0:10]
# Out:
# Job seeker id 82470 is looking for auditor job
# ----------------------------------------------
# Top 10 job recommendations:
# index
# J_915_IT- Auditor                                            0.999812
# J_6736_Senior Accountant                                     0.999472
# J_4871_CPA Accounting Manager / Medical Billing              0.999157
# J_701_Accountant / Book Keeper                               0.999058
# J_4873_Controller - High Growth Specialty Finance Company    0.999058
# J_10433_Payroll Accountant                                   0.998922
# J_4193_Corporate Controller                                  0.998922
# J_268_Sr. Accountant                                         0.998922
# J_2128_Accounts Payable Supervisor                           0.998844
# J_6081_Corporate Controller                                  0.998634
# Name: R_82470_auditor, dtype: float64

# %%
# Using np.where to find the index number of the top 10 positions
print(np.where(jobs_df.index == "J_915_IT- Auditor"))
print(np.where(jobs_df.index == "J_6736_Senior Accountant"))
print(np.where(jobs_df.index == "J_4871_CPA Accounting Manager / Medical Billing"))
print(np.where(jobs_df.index == "J_701_Accountant / Book Keeper"))
print(np.where(jobs_df.index == "J_4873_Controller - High Growth Specialty Finance Company"))
print(np.where(jobs_df.index == "J_2128_Accounts Payable Supervisor"))
print(np.where(jobs_df.index == "J_687_Accountant"))
print(np.where(jobs_df.index == "J_3057_Accounting Manager"))
print(np.where(jobs_df.index == "J_6081_Corporate Controller "))
print(np.where(jobs_df.index == "J_10433_Payroll Accountant"))
# Out:
# (array([68], dtype=int64),)
# (array([509], dtype=int64),)
# (array([373], dtype=int64),)
# (array([58], dtype=int64),)
# (array([374], dtype=int64),)
# (array([144], dtype=int64),)
# (array([55], dtype=int64),)
# (array([213], dtype=int64),)
# (array([462], dtype=int64),)
# (array([791], dtype=int64),)

# %%
# Creating the list of jobs into a dataframe
reco_acct = pd.DataFrame(jobs_df.iloc[[68, 509, 373, 58, 374, 144, 55, 213, 462, 791]])
reco_acct
# Out:
#                                                       function  \
# index
# J_915_IT- Auditor                                   Accounting
# J_6736_Senior Accountant                            Accounting
# J_4871_CPA Accounting Manager / Medical Billing     Accounting
# J_701_Accountant / Book Keeper                      Accounting
# J_4873_Controller - High Growth Specialty Finan...  Accounting
# J_2128_Accounts Payable Supervisor                  Accounting
# J_687_Accountant                                    Accounting
# J_3057_Accounting Manager                           Accounting
# J_6081_Corporate Controller                         Accounting
# J_10433_Payroll Accountant                          Accounting
#
#                                                         state_name   emp_type  \
# index
# J_915_IT- Auditor                                   North Carolina   contract
# J_6736_Senior Accountant                                     Texas   contract
# J_4871_CPA Accounting Manager / Medical Billing              Texas  full-time
# J_701_Accountant / Book Keeper                            Virginia  full-time
# J_4873_Controller - High Growth Specialty Finan...        Virginia  full-time
# J_2128_Accounts Payable Supervisor                        Oklahoma  full-time
# J_687_Accountant                                          New York  full-time
# J_3057_Accounting Manager                                    Maine  full-time
# J_6081_Corporate Controller                               New York  full-time
# J_10433_Payroll Accountant                            Pennsylvania  full-time
#
#                                                      job_level  edu_level  \
# index
# J_915_IT- Auditor                                   mid_senior  bachelors
# J_6736_Senior Accountant                             associate  bachelors
# J_4871_CPA Accounting Manager / Medical Billing     mid_senior  bachelors
# J_701_Accountant / Book Keeper                      mid_senior  bachelors
# J_4873_Controller - High Growth Specialty Finan...  mid_senior  bachelors
# J_2128_Accounts Payable Supervisor                   associate  bachelors
# J_687_Accountant                                    mid_senior  bachelors
# J_3057_Accounting Manager                           mid_senior  bachelors
# J_6081_Corporate Controller                         mid_senior  bachelors
# J_10433_Payroll Accountant                          mid_senior  bachelors
#
#                                                        region
# index
# J_915_IT- Auditor                                       south
# J_6736_Senior Accountant                                south
# J_4871_CPA Accounting Manager / Medical Billing         south
# J_701_Accountant / Book Keeper                          south
# J_4873_Controller - High Growth Specialty Finan...      south
# J_2128_Accounts Payable Supervisor                      south
# J_687_Accountant                                    northeast
# J_3057_Accounting Manager                           northeast
# J_6081_Corporate Controller                         northeast
# J_10433_Payroll Accountant                          northeast

# %%
# Checking out the features of job seeker 82470
cdd_acct = res_df.head(1)
cdd_acct
# Out:
#                    function state_name  emp_type   job_level edu_level region
# index
# R_82470_auditor  Accounting      Texas  contract  mid_senior   masters  south

# %%
# Putting both dataframe together where 1st row is the job seeker and remaining are recommendations
cdd_acct.append(reco_acct)
# Out:
#                                                       function  \
# index
# R_82470_auditor                                     Accounting
# J_915_IT- Auditor                                   Accounting
# J_6736_Senior Accountant                            Accounting
# J_4871_CPA Accounting Manager / Medical Billing     Accounting
# J_701_Accountant / Book Keeper                      Accounting
# J_4873_Controller - High Growth Specialty Finan...  Accounting
# J_2128_Accounts Payable Supervisor                  Accounting
# J_687_Accountant                                    Accounting
# J_3057_Accounting Manager                           Accounting
# J_6081_Corporate Controller                         Accounting
# J_10433_Payroll Accountant                          Accounting
#
#                                                         state_name   emp_type  \
# index
# R_82470_auditor                                              Texas   contract
# J_915_IT- Auditor                                   North Carolina   contract
# J_6736_Senior Accountant                                     Texas   contract
# J_4871_CPA Accounting Manager / Medical Billing              Texas  full-time
# J_701_Accountant / Book Keeper                            Virginia  full-time
# J_4873_Controller - High Growth Specialty Finan...        Virginia  full-time
# J_2128_Accounts Payable Supervisor                        Oklahoma  full-time
# J_687_Accountant                                          New York  full-time
# J_3057_Accounting Manager                                    Maine  full-time
# J_6081_Corporate Controller                               New York  full-time
# J_10433_Payroll Accountant                            Pennsylvania  full-time
#
#                                                      job_level  edu_level  \
# index
# R_82470_auditor                                     mid_senior    masters
# J_915_IT- Auditor                                   mid_senior  bachelors
# J_6736_Senior Accountant                             associate  bachelors
# J_4871_CPA Accounting Manager / Medical Billing     mid_senior  bachelors
# J_701_Accountant / Book Keeper                      mid_senior  bachelors
# J_4873_Controller - High Growth Specialty Finan...  mid_senior  bachelors
# J_2128_Accounts Payable Supervisor                   associate  bachelors
# J_687_Accountant                                    mid_senior  bachelors
# J_3057_Accounting Manager                           mid_senior  bachelors
# J_6081_Corporate Controller                         mid_senior  bachelors
# J_10433_Payroll Accountant                          mid_senior  bachelors
#
#                                                        region
# index
# R_82470_auditor                                         south
# J_915_IT- Auditor                                       south
# J_6736_Senior Accountant                                south
# J_4871_CPA Accounting Manager / Medical Billing         south
# J_701_Accountant / Book Keeper                          south
# J_4873_Controller - High Growth Specialty Finan...      south
# J_2128_Accounts Payable Supervisor                      south
# J_687_Accountant                                    northeast
# J_3057_Accounting Manager                           northeast
# J_6081_Corporate Controller                         northeast
# J_10433_Payroll Accountant                          northeast

# %%
# Check the job recommendation for job seekers in Information Technology function
print('Job seeker id {} is looking for {} job'.format(res_jobs.index[1017][2:7], res_jobs.index[1017][8:45]))
print('---------------------------------------------------------------------')
print('Top 10 job recommendations:')
res_jobs.iloc[1017,:].sort_values(ascending=False)[0:10]
# Out:
# Job seeker id 75818 is looking for oracle database administrator job
# ---------------------------------------------------------------------
# Top 10 job recommendations:
# index
# J_3500_IT Security Engineer, Immediate full time opening at Fortune 500 Co.    0.994085
# J_2193_Sr. Java Developer                                                      0.994085
# J_1478_IT Software Tester                                                      0.994085
# J_3277_Oracle Applications DBA                                                 0.994085
# J_8971_Java Integration Engineer                                               0.994085
# J_6044_Lead Software Engineer                                                  0.994085
# J_6523_Senior Software Engineer                                                0.994085
# J_4945_Senior Systems Administrator                                            0.994085
# J_2279_Web Developer                                                           0.994085
# J_9842_Director, Information Security                                          0.994085
# Name: R_75818_oracle database administrator, dtype: float64

# %%
# Using np.where to find the index number of the top 10 positions
print(np.where(jobs_df.index == "J_2433_Enterprise Architect"))
print(np.where(jobs_df.index == "J_1787_Software Engineer - IL"))
print(np.where(jobs_df.index == "J_1460_MOBILE FRONT END PROGRAMMERS - VLinks Media"))
print(np.where(jobs_df.index == "J_5653_Junior .NET Software Engineer"))
print(np.where(jobs_df.index == "J_4065_Senior Software Engineer - CloudSpotter Technologies"))
print(np.where(jobs_df.index == "J_666_Javascript Developer - Rippleshot"))
print(np.where(jobs_df.index == "J_6544_Linux System Manager - SaaS"))
print(np.where(jobs_df.index == "J_1677_SAP BI/HANA Managing Consultant"))
print(np.where(jobs_df.index == "J_496_Front-End Web Developer"))
print(np.where(jobs_df.index == "J_4498_Curam Developer"))
# Out:
# (array([165], dtype=int64),)
# (array([117], dtype=int64),)
# (array([100], dtype=int64),)
# (array([440], dtype=int64),)
# (array([293], dtype=int64),)
# (array([53], dtype=int64),)
# (array([491], dtype=int64),)
# (array([111], dtype=int64),)
# (array([29], dtype=int64),)
# (array([333], dtype=int64),)

# %%
reco_it = pd.DataFrame(jobs_df.iloc[[165, 117, 100, 440, 293, 53, 491, 111, 29, 333]])
reco_it
# Out:
#                                                                   function  \
# index
# J_2433_Enterprise Architect                         Information Technology
# J_1787_Software Engineer - IL                       Information Technology
# J_1460_MOBILE FRONT END PROGRAMMERS - VLinks Media  Information Technology
# J_5653_Junior .NET Software Engineer                Information Technology
# J_4065_Senior Software Engineer - CloudSpotter ...  Information Technology
# J_666_Javascript Developer - Rippleshot             Information Technology
# J_6544_Linux System Manager - SaaS                  Information Technology
# J_1677_SAP BI/HANA Managing Consultant              Information Technology
# J_496_Front-End Web Developer                       Information Technology
# J_4498_Curam Developer                              Information Technology
#
#                                                    state_name   emp_type  \
# index
# J_2433_Enterprise Architect                          Michigan   contract
# J_1787_Software Engineer - IL                        Illinois  full-time
# J_1460_MOBILE FRONT END PROGRAMMERS - VLinks Media   Illinois  full-time
# J_5653_Junior .NET Software Engineer                 Illinois  full-time
# J_4065_Senior Software Engineer - CloudSpotter ...   Illinois  full-time
# J_666_Javascript Developer - Rippleshot              Illinois  full-time
# J_6544_Linux System Manager - SaaS                   Illinois  full-time
# J_1677_SAP BI/HANA Managing Consultant               Illinois  full-time
# J_496_Front-End Web Developer                        Illinois  full-time
# J_4498_Curam Developer                               Illinois  full-time
#
#                                                      job_level  edu_level  \
# index
# J_2433_Enterprise Architect                         mid_senior    masters
# J_1787_Software Engineer - IL                        associate  bachelors
# J_1460_MOBILE FRONT END PROGRAMMERS - VLinks Media   associate  bachelors
# J_5653_Junior .NET Software Engineer                 associate  bachelors
# J_4065_Senior Software Engineer - CloudSpotter ...  mid_senior  bachelors
# J_666_Javascript Developer - Rippleshot             mid_senior  bachelors
# J_6544_Linux System Manager - SaaS                  mid_senior  bachelors
# J_1677_SAP BI/HANA Managing Consultant              mid_senior  bachelors
# J_496_Front-End Web Developer                       mid_senior  bachelors
# J_4498_Curam Developer                              mid_senior  bachelors
#
#                                                      region
# index
# J_2433_Enterprise Architect                         midwest
# J_1787_Software Engineer - IL                       midwest
# J_1460_MOBILE FRONT END PROGRAMMERS - VLinks Media  midwest
# J_5653_Junior .NET Software Engineer                midwest
# J_4065_Senior Software Engineer - CloudSpotter ...  midwest
# J_666_Javascript Developer - Rippleshot             midwest
# J_6544_Linux System Manager - SaaS                  midwest
# J_1677_SAP BI/HANA Managing Consultant              midwest
# J_496_Front-End Web Developer                       midwest
# J_4498_Curam Developer                              midwest

# %%
# Checking out the features of job seeker 75818
cdd_it = pd.DataFrame(res_df.iloc[1017]).T
cdd_it
# Out:
#                                                      function state_name  \
# R_75818_oracle database administrator  Information Technology   Illinois
#
#                                        emp_type  job_level  edu_level   region
# R_75818_oracle database administrator  contract  associate  bachelors  midwest

# %%
# Putting both dataframe together where 1st row is the job seeker and remaining are recommendations
cdd_it.append(reco_it)
# Out:
#                                                                   function  \
# R_75818_oracle database administrator               Information Technology
# J_2433_Enterprise Architect                         Information Technology
# J_1787_Software Engineer - IL                       Information Technology
# J_1460_MOBILE FRONT END PROGRAMMERS - VLinks Media  Information Technology
# J_5653_Junior .NET Software Engineer                Information Technology
# J_4065_Senior Software Engineer - CloudSpotter ...  Information Technology
# J_666_Javascript Developer - Rippleshot             Information Technology
# J_6544_Linux System Manager - SaaS                  Information Technology
# J_1677_SAP BI/HANA Managing Consultant              Information Technology
# J_496_Front-End Web Developer                       Information Technology
# J_4498_Curam Developer                              Information Technology
#
#                                                    state_name   emp_type  \
# R_75818_oracle database administrator                Illinois   contract
# J_2433_Enterprise Architect                          Michigan   contract
# J_1787_Software Engineer - IL                        Illinois  full-time
# J_1460_MOBILE FRONT END PROGRAMMERS - VLinks Media   Illinois  full-time
# J_5653_Junior .NET Software Engineer                 Illinois  full-time
# J_4065_Senior Software Engineer - CloudSpotter ...   Illinois  full-time
# J_666_Javascript Developer - Rippleshot              Illinois  full-time
# J_6544_Linux System Manager - SaaS                   Illinois  full-time
# J_1677_SAP BI/HANA Managing Consultant               Illinois  full-time
# J_496_Front-End Web Developer                        Illinois  full-time
# J_4498_Curam Developer                               Illinois  full-time
#
#                                                      job_level  edu_level  \
# R_75818_oracle database administrator                associate  bachelors
# J_2433_Enterprise Architect                         mid_senior    masters
# J_1787_Software Engineer - IL                        associate  bachelors
# J_1460_MOBILE FRONT END PROGRAMMERS - VLinks Media   associate  bachelors
# J_5653_Junior .NET Software Engineer                 associate  bachelors
# J_4065_Senior Software Engineer - CloudSpotter ...  mid_senior  bachelors
# J_666_Javascript Developer - Rippleshot             mid_senior  bachelors
# J_6544_Linux System Manager - SaaS                  mid_senior  bachelors
# J_1677_SAP BI/HANA Managing Consultant              mid_senior  bachelors
# J_496_Front-End Web Developer                       mid_senior  bachelors
# J_4498_Curam Developer                              mid_senior  bachelors
#
#                                                      region
# R_75818_oracle database administrator               midwest
# J_2433_Enterprise Architect                         midwest
# J_1787_Software Engineer - IL                       midwest
# J_1460_MOBILE FRONT END PROGRAMMERS - VLinks Media  midwest
# J_5653_Junior .NET Software Engineer                midwest
# J_4065_Senior Software Engineer - CloudSpotter ...  midwest
# J_666_Javascript Developer - Rippleshot             midwest
# J_6544_Linux System Manager - SaaS                  midwest
# J_1677_SAP BI/HANA Managing Consultant              midwest
# J_496_Front-End Web Developer                       midwest
# J_4498_Curam Developer                              midwest

# %% [markdown]
# ### Let's check out the candidates for HR/Hiring managers based on job ads

# %%
# Let's transpose the dataset
jobs_res = res_jobs.T
jobs_res.head()
# Out:
# index                                               R_82470_auditor  \
# index
# J_9_ASP.net Developer Job opportunity at United...         0.994142
# J_10_Applications Developer, Digital                       0.575739
# J_38_Technical Project Manager                             0.992046
# J_49_Ruby Automation Engineer & Ruby on Rails E...         0.135198
# J_54_Mid-Senior .NET or Xamarin Developer                  0.900818
#
# index                                               R_82450_senior accountant  \
# index
# J_9_ASP.net Developer Job opportunity at United...                   0.987669
# J_10_Applications Developer, Digital                                 0.481228
# J_38_Technical Project Manager                                       0.984821
# J_49_Ruby Automation Engineer & Ruby on Rails E...                   0.088784
# J_54_Mid-Senior .NET or Xamarin Developer                            0.858192
#
# index                                               R_82423_senior/mid-level financial services manager  \
# index
# J_9_ASP.net Developer Job opportunity at United...                                           0.994062
# J_10_Applications Developer, Digital                                                         0.555691
# J_38_Technical Project Manager                                                               0.992179
# J_49_Ruby Automation Engineer & Ruby on Rails E...                                           0.118238
# J_54_Mid-Senior .NET or Xamarin Developer                                                    0.890917
#
# index                                               R_82397_ brokerage operations  \
# index
# J_9_ASP.net Developer Job opportunity at United...                       0.989066
# J_10_Applications Developer, Digital                                     0.510094
# J_38_Technical Project Manager                                           0.987108
# J_49_Ruby Automation Engineer & Ruby on Rails E...                       0.058617
# J_54_Mid-Senior .NET or Xamarin Developer                                0.858976
#
# index                                               R_82338_full charge bookkeeper  \
# index
# J_9_ASP.net Developer Job opportunity at United...                        0.432772
# J_10_Applications Developer, Digital                                      0.533002
# J_38_Technical Project Manager                                            0.429062
# J_49_Ruby Automation Engineer & Ruby on Rails E...                        0.428746
# J_54_Mid-Senior .NET or Xamarin Developer                                 0.619225
#
# index                                               R_82293_remote bookkeeper or ranch management  \
# index
# J_9_ASP.net Developer Job opportunity at United...                                       0.403224
# J_10_Applications Developer, Digital                                                    -0.182818
# J_38_Technical Project Manager                                                           0.385679
# J_49_Ruby Automation Engineer & Ruby on Rails E...                                       0.117647
# J_54_Mid-Senior .NET or Xamarin Developer                                                0.331539
#
# index                                               R_82266_financial analyst  \
# index
# J_9_ASP.net Developer Job opportunity at United...                   0.988026
# J_10_Applications Developer, Digital                                 0.555159
# J_38_Technical Project Manager                                       0.986258
# J_49_Ruby Automation Engineer & Ruby on Rails E...                   0.089314
# J_54_Mid-Senior .NET or Xamarin Developer                            0.880931
#
# index                                               R_81922_financial analyst  \
# index
# J_9_ASP.net Developer Job opportunity at United...                   0.250924
# J_10_Applications Developer, Digital                                 0.453821
# J_38_Technical Project Manager                                       0.247222
# J_49_Ruby Automation Engineer & Ruby on Rails E...                   0.433501
# J_54_Mid-Senior .NET or Xamarin Developer                            0.474190
#
# index                                               R_81888_full or part time bookkeeping accounting  \
# index
# J_9_ASP.net Developer Job opportunity at United...                                          0.992307
# J_10_Applications Developer, Digital                                                        0.567926
# J_38_Technical Project Manager                                                              0.991662
# J_49_Ruby Automation Engineer & Ruby on Rails E...                                          0.109516
# J_54_Mid-Senior .NET or Xamarin Developer                                                   0.890607
#
# index                                               R_81854_accounting manager  \
# index
# J_9_ASP.net Developer Job opportunity at United...                    0.200162
# J_10_Applications Developer, Digital                                  0.307941
# J_38_Technical Project Manager                                        0.189608
# J_49_Ruby Automation Engineer & Ruby on Rails E...                    0.450377
# J_54_Mid-Senior .NET or Xamarin Developer                             0.412491
#
# index                                               ...  \
# index                                               ...
# J_9_ASP.net Developer Job opportunity at United...  ...
# J_10_Applications Developer, Digital                ...
# J_38_Technical Project Manager                      ...
# J_49_Ruby Automation Engineer & Ruby on Rails E...  ...
# J_54_Mid-Senior .NET or Xamarin Developer           ...
#
# index                                               R_72754_sql developer  \
# index
# J_9_ASP.net Developer Job opportunity at United...               0.984075
# J_10_Applications Developer, Digital                             0.497797
# J_38_Technical Project Manager                                   0.983669
# J_49_Ruby Automation Engineer & Ruby on Rails E...               0.075080
# J_54_Mid-Senior .NET or Xamarin Developer                        0.841922
#
# index                                               R_72752_network engineer  \
# index
# J_9_ASP.net Developer Job opportunity at United...                  0.996966
# J_10_Applications Developer, Digital                                0.568389
# J_38_Technical Project Manager                                      0.997306
# J_49_Ruby Automation Engineer & Ruby on Rails E...                  0.120319
# J_54_Mid-Senior .NET or Xamarin Developer                           0.885819
#
# index                                               R_72742_sr java/j2ee developer  \
# index
# J_9_ASP.net Developer Job opportunity at United...                        0.990922
# J_10_Applications Developer, Digital                                      0.516356
# J_38_Technical Project Manager                                            0.989970
# J_49_Ruby Automation Engineer & Ruby on Rails E...                        0.108106
# J_54_Mid-Senior .NET or Xamarin Developer                                 0.863852
#
# index                                               R_72741_ms sql bi developer  \
# index
# J_9_ASP.net Developer Job opportunity at United...                     0.871152
# J_10_Applications Developer, Digital                                   0.359425
# J_38_Technical Project Manager                                         0.871328
# J_49_Ruby Automation Engineer & Ruby on Rails E...                     0.096374
# J_54_Mid-Senior .NET or Xamarin Developer                              0.712923
#
# index                                               R_72740_java/j2ee developer  \
# index
# J_9_ASP.net Developer Job opportunity at United...                    -0.739588
# J_10_Applications Developer, Digital                                   0.053300
# J_38_Technical Project Manager                                        -0.733843
# J_49_Ruby Automation Engineer & Ruby on Rails E...                     0.364434
# J_54_Mid-Senior .NET or Xamarin Developer                             -0.422885
#
# index                                               R_72739_biz talk developer  \
# index
# J_9_ASP.net Developer Job opportunity at United...                    0.992559
# J_10_Applications Developer, Digital                                  0.523304
# J_38_Technical Project Manager                                        0.991318
# J_49_Ruby Automation Engineer & Ruby on Rails E...                    0.127263
# J_54_Mid-Senior .NET or Xamarin Developer                             0.873316
#
# index                                               R_72738_oracle pl/sql developer / etl developer  \
# index
# J_9_ASP.net Developer Job opportunity at United...                                         0.998305
# J_10_Applications Developer, Digital                                                       0.568864
# J_38_Technical Project Manager                                                             0.997614
# J_49_Ruby Automation Engineer & Ruby on Rails E...                                         0.144808
# J_54_Mid-Senior .NET or Xamarin Developer                                                  0.894721
#
# index                                               R_72736_qa tester  \
# index
# J_9_ASP.net Developer Job opportunity at United...           0.620944
# J_10_Applications Developer, Digital                         0.125739
# J_38_Technical Project Manager                               0.624764
# J_49_Ruby Automation Engineer & Ruby on Rails E...          -0.126430
# J_54_Mid-Senior .NET or Xamarin Developer                    0.391921
#
# index                                               R_72735_oracle pl/sql developer  \
# index
# J_9_ASP.net Developer Job opportunity at United...                         0.997268
# J_10_Applications Developer, Digital                                       0.576363
# J_38_Technical Project Manager                                             0.997262
# J_49_Ruby Automation Engineer & Ruby on Rails E...                         0.128785
# J_54_Mid-Senior .NET or Xamarin Developer                                  0.889172
#
# index                                               R_72731_vp of it, it director, it project director
# index
# J_9_ASP.net Developer Job opportunity at United...                                           0.059801
# J_10_Applications Developer, Digital                                                         0.493464
# J_38_Technical Project Manager                                                               0.054791
# J_49_Ruby Automation Engineer & Ruby on Rails E...                                           0.952661
# J_54_Mid-Senior .NET or Xamarin Developer                                                    0.447447
#
# [5 rows x 1285 columns]

# %%
# Check the candidates for job ads in Accounting function
print('Job ad position: {} '.format(jobs_res.index[10][6:26]))
print('---------------------------------------')
print('Top 10 candidates recommendations:')
jobs_res.iloc[10,:].sort_values(ascending=False)[0:10]
# Out:
# Job ad position: Financial Accountant
# ---------------------------------------
# Top 10 candidates recommendations:
# index
# R_57471_staff accountant                      1.0
# R_67483_data entry/accounting                 1.0
# R_59270_invoicing specialist                  1.0
# R_71690_bookkeeping/ office administrative    1.0
# R_74990_senior staff accountant               1.0
# R_75007_accounting assistant                  1.0
# R_75465_bookkeeping, AR AP                    1.0
# R_65285_senior accountant                     1.0
# R_64594_accounts payable                      1.0
# R_65175_accountant                            1.0
# Name: J_187_Financial Accountant, dtype: float64

# %%
# Using np.where to find the index number of the top 10 job seekers
print(np.where(res_df.index == "R_75465_bookkeeping, AR AP"))
print(np.where(res_df.index == "R_67483_data entry/accounting"))
print(np.where(res_df.index == "R_59270_invoicing specialist"))
print(np.where(res_df.index == "R_65175_accountant"))
print(np.where(res_df.index == "R_65285_senior accountant"))
print(np.where(res_df.index == "R_57471_staff accountant"))
print(np.where(res_df.index == "R_74990_senior staff accountant"))
print(np.where(res_df.index == "R_75007_accounting assistant"))
print(np.where(res_df.index == "R_71690_bookkeeping/ office administrative"))
print(np.where(res_df.index == "R_68481_accountant"))
# Out:
# (array([136], dtype=int64),)
# (array([265], dtype=int64),)
# (array([433], dtype=int64),)
# (array([320], dtype=int64),)
# (array([317], dtype=int64),)
# (array([462], dtype=int64),)
# (array([152], dtype=int64),)
# (array([151], dtype=int64),)
# (array([206], dtype=int64),)
# (array([246], dtype=int64),)

# %%
rec_acct = pd.DataFrame(res_df.iloc[[136,265, 433, 320, 317, 462, 152, 151, 206, 246]])
rec_acct
# Out:
#                                               function state_name   emp_type  \
# index
# R_75465_bookkeeping, AR AP                  Accounting   New York  full-time
# R_67483_data entry/accounting               Accounting   New York  full-time
# R_59270_invoicing specialist                Accounting   New York  full-time
# R_65175_accountant                          Accounting   New York  full-time
# R_65285_senior accountant                   Accounting   New York  full-time
# R_57471_staff accountant                    Accounting   New York  full-time
# R_74990_senior staff accountant             Accounting   New York  full-time
# R_75007_accounting assistant                Accounting   New York  full-time
# R_71690_bookkeeping/ office administrative  Accounting   New York  full-time
# R_68481_accountant                          Accounting   New York  full-time
#
#                                             job_level  edu_level     region
# index
# R_75465_bookkeeping, AR AP                  associate  bachelors  northeast
# R_67483_data entry/accounting               associate  bachelors  northeast
# R_59270_invoicing specialist                associate  bachelors  northeast
# R_65175_accountant                          associate  bachelors  northeast
# R_65285_senior accountant                   associate  bachelors  northeast
# R_57471_staff accountant                    associate  bachelors  northeast
# R_74990_senior staff accountant             associate  bachelors  northeast
# R_75007_accounting assistant                associate  bachelors  northeast
# R_71690_bookkeeping/ office administrative  associate  bachelors  northeast
# R_68481_accountant                          associate  bachelors  northeast

# %%
# Checking out the features of job ads 187
job_acct = pd.DataFrame(jobs_df.iloc[10]).T
job_acct
# Out:
#                               function state_name   emp_type  job_level  \
# J_187_Financial Accountant  Accounting   New York  full-time  associate
#
#                             edu_level     region
# J_187_Financial Accountant  bachelors  northeast

# %%
# Putting both dataframe together where 1st row is the job ads and remaining are recommendations
job_acct.append(rec_acct)
# Out:
#                                               function state_name   emp_type  \
# J_187_Financial Accountant                  Accounting   New York  full-time
# R_75465_bookkeeping, AR AP                  Accounting   New York  full-time
# R_67483_data entry/accounting               Accounting   New York  full-time
# R_59270_invoicing specialist                Accounting   New York  full-time
# R_65175_accountant                          Accounting   New York  full-time
# R_65285_senior accountant                   Accounting   New York  full-time
# R_57471_staff accountant                    Accounting   New York  full-time
# R_74990_senior staff accountant             Accounting   New York  full-time
# R_75007_accounting assistant                Accounting   New York  full-time
# R_71690_bookkeeping/ office administrative  Accounting   New York  full-time
# R_68481_accountant                          Accounting   New York  full-time
#
#                                             job_level  edu_level     region
# J_187_Financial Accountant                  associate  bachelors  northeast
# R_75465_bookkeeping, AR AP                  associate  bachelors  northeast
# R_67483_data entry/accounting               associate  bachelors  northeast
# R_59270_invoicing specialist                associate  bachelors  northeast
# R_65175_accountant                          associate  bachelors  northeast
# R_65285_senior accountant                   associate  bachelors  northeast
# R_57471_staff accountant                    associate  bachelors  northeast
# R_74990_senior staff accountant             associate  bachelors  northeast
# R_75007_accounting assistant                associate  bachelors  northeast
# R_71690_bookkeeping/ office administrative  associate  bachelors  northeast
# R_68481_accountant                          associate  bachelors  northeast

# %%
# Check the candidates for job ads in Information Technology function
print('Job ad position: {} '.format(jobs_res.index[2][5:30]))
print('---------------------------------------')
print('Top 10 candidates recommendations:')
jobs_res.iloc[2,:].sort_values(ascending=False)[0:10]
# Out:
# Job ad position: Technical Project Manager
# ---------------------------------------
# Top 10 candidates recommendations:
# index
# R_78734_it service desk lead analyst\it service desk manager    1.000000
# R_81761_sql server database administrator                       1.000000
# R_79802_business system analyst                                 1.000000
# R_72842_it support, it technician, systems administrator        1.000000
# R_74072_windows systems engineer                                0.999971
# R_74244_technical writer/editor                                 0.999971
# R_81453_systems administrator                                   0.999971
# R_75521_network engineer                                        0.999971
# R_74692_business analyst / business systems analyst             0.999971
# R_79968_system administrator                                    0.999971
# Name: J_38_Technical Project Manager, dtype: float64

# %%
# Using np.where to find the index number of the top 10 job seekers
print(np.where(res_df.index == "R_72842_it support, it technician, systems administrator"))
print(np.where(res_df.index == "R_79802_business system analyst"))
print(np.where(res_df.index == "R_78734_it service desk lead analyst\it service desk manager"))
print(np.where(res_df.index == "R_81761_sql server database administrator"))
print(np.where(res_df.index == "R_74072_windows systems engineer"))
print(np.where(res_df.index == "R_74244_technical writer/editor"))
print(np.where(res_df.index == "R_75521_network engineer"))
print(np.where(res_df.index == "R_81453_systems administrator"))
print(np.where(res_df.index == "R_74692_business analyst / business systems analyst"))
print(np.where(res_df.index == "R_79968_system administrator"))
# Out:
# (array([1268], dtype=int64),)
# (array([704], dtype=int64),)
# (array([787], dtype=int64),)
# (array([541], dtype=int64),)
# (array([1183], dtype=int64),)
# (array([1171], dtype=int64),)
# (array([1069], dtype=int64),)
# (array([563], dtype=int64),)
# (array([1134], dtype=int64),)
# (array([684], dtype=int64),)

# %%
rec_it = pd.DataFrame(res_df.iloc[[1268, 704, 787, 541, 1183, 1171, 1069, 563, 1134, 684]])
rec_it
# Out:
#                                                                   function  \
# index
# R_72842_it support, it technician, systems admi...  Information Technology
# R_79802_business system analyst                     Information Technology
# R_78734_it service desk lead analyst\it service...  Information Technology
# R_81761_sql server database administrator           Information Technology
# R_74072_windows systems engineer                    Information Technology
# R_74244_technical writer/editor                     Information Technology
# R_75521_network engineer                            Information Technology
# R_81453_systems administrator                       Information Technology
# R_74692_business analyst / business systems ana...  Information Technology
# R_79968_system administrator                        Information Technology
#
#                                                     state_name   emp_type  \
# index
# R_72842_it support, it technician, systems admi...    New York  full-time
# R_79802_business system analyst                       New York  full-time
# R_78734_it service desk lead analyst\it service...    New York  full-time
# R_81761_sql server database administrator             New York  full-time
# R_74072_windows systems engineer                    New Jersey  full-time
# R_74244_technical writer/editor                     New Jersey  full-time
# R_75521_network engineer                            New Jersey  full-time
# R_81453_systems administrator                       New Jersey  full-time
# R_74692_business analyst / business systems ana...  New Jersey  full-time
# R_79968_system administrator                        New Jersey  full-time
#
#                                                     job_level  edu_level  \
# index
# R_72842_it support, it technician, systems admi...  associate  bachelors
# R_79802_business system analyst                     associate  bachelors
# R_78734_it service desk lead analyst\it service...  associate  bachelors
# R_81761_sql server database administrator           associate  bachelors
# R_74072_windows systems engineer                    associate  bachelors
# R_74244_technical writer/editor                     associate  bachelors
# R_75521_network engineer                            associate  bachelors
# R_81453_systems administrator                       associate  bachelors
# R_74692_business analyst / business systems ana...  associate  bachelors
# R_79968_system administrator                        associate  bachelors
#
#                                                        region
# index
# R_72842_it support, it technician, systems admi...  northeast
# R_79802_business system analyst                     northeast
# R_78734_it service desk lead analyst\it service...  northeast
# R_81761_sql server database administrator           northeast
# R_74072_windows systems engineer                    northeast
# R_74244_technical writer/editor                     northeast
# R_75521_network engineer                            northeast
# R_81453_systems administrator                       northeast
# R_74692_business analyst / business systems ana...  northeast
# R_79968_system administrator                        northeast

# %%
# Checking out the features of job seeker 38
job_it = pd.DataFrame(jobs_df.iloc[2]).T
job_it
# Out:
#                                               function state_name   emp_type  \
# J_38_Technical Project Manager  Information Technology   New York  full-time
#
#                                 job_level  edu_level     region
# J_38_Technical Project Manager  associate  bachelors  northeast

# %%
# Putting both dataframe together where 1st row is the job ads and remaining are recommendations
job_it.append(rec_it)
# Out:
#                                                                   function  \
# J_38_Technical Project Manager                      Information Technology
# R_72842_it support, it technician, systems admi...  Information Technology
# R_79802_business system analyst                     Information Technology
# R_78734_it service desk lead analyst\it service...  Information Technology
# R_81761_sql server database administrator           Information Technology
# R_74072_windows systems engineer                    Information Technology
# R_74244_technical writer/editor                     Information Technology
# R_75521_network engineer                            Information Technology
# R_81453_systems administrator                       Information Technology
# R_74692_business analyst / business systems ana...  Information Technology
# R_79968_system administrator                        Information Technology
#
#                                                     state_name   emp_type  \
# J_38_Technical Project Manager                        New York  full-time
# R_72842_it support, it technician, systems admi...    New York  full-time
# R_79802_business system analyst                       New York  full-time
# R_78734_it service desk lead analyst\it service...    New York  full-time
# R_81761_sql server database administrator             New York  full-time
# R_74072_windows systems engineer                    New Jersey  full-time
# R_74244_technical writer/editor                     New Jersey  full-time
# R_75521_network engineer                            New Jersey  full-time
# R_81453_systems administrator                       New Jersey  full-time
# R_74692_business analyst / business systems ana...  New Jersey  full-time
# R_79968_system administrator                        New Jersey  full-time
#
#                                                     job_level  edu_level  \
# J_38_Technical Project Manager                      associate  bachelors
# R_72842_it support, it technician, systems admi...  associate  bachelors
# R_79802_business system analyst                     associate  bachelors
# R_78734_it service desk lead analyst\it service...  associate  bachelors
# R_81761_sql server database administrator           associate  bachelors
# R_74072_windows systems engineer                    associate  bachelors
# R_74244_technical writer/editor                     associate  bachelors
# R_75521_network engineer                            associate  bachelors
# R_81453_systems administrator                       associate  bachelors
# R_74692_business analyst / business systems ana...  associate  bachelors
# R_79968_system administrator                        associate  bachelors
#
#                                                        region
# J_38_Technical Project Manager                      northeast
# R_72842_it support, it technician, systems admi...  northeast
# R_79802_business system analyst                     northeast
# R_78734_it service desk lead analyst\it service...  northeast
# R_81761_sql server database administrator           northeast
# R_74072_windows systems engineer                    northeast
# R_74244_technical writer/editor                     northeast
# R_75521_network engineer                            northeast
# R_81453_systems administrator                       northeast
# R_74692_business analyst / business systems ana...  northeast
# R_79968_system administrator                        northeast

# %% [markdown]
# # Conclusion

# %% [markdown]
# Study shows that resumes screening remains the most time-consuming part of recruiting process where 52% of Talent Acquisition leaders cited that the hardest part of recruitment is screening candidates from a large applicant pool.
# This process takes approximately 23 hours for just one hire and typically 75% to 88% of the resumes from the pool are unqualified.
#
# Likewise for job seekers, we tend to send out tons of application only to hear nothing back in return. In addition, to ensure that the resume stands out, it is strongly recommended to tailor made the application materials to each job application.
#
# What we are trying achieve with the above model is to be able to take away the time-consuming part of the work for both recruitment process and job seekers.
# This recommender system will return best-match profiles / job ads. So for the talent acquisition / job seekers, instead of looking through the large pool of information, they will be able to just focus on the recommendation which will already be matched based on their requirements.
#
# With this recommendations, we plan to introduce a selection function (`Yes` or `No`). Talent acquisition leader / job seekers can have the option to choose `Yes` or `No` where yes to show interest and no refers to not interested.
# When both job seeker and talent acquisition leader selected `Yes`, they will be connected to a chatroom to kickstart their conversation.

# %%
display(HTML("<table><tr><td><img src='images/app1.png'></td><td><img src='images/app2.png'></td><td><img src='images/app3.png'></td><td><img src='images/app4.png'></td></tr></table>"))
# Out:
# <table><tr><td><img src='images/app1.png'></td><td><img src='images/app2.png'></td><td><img src='images/app3.png'></td><td><img src='images/app4.png'></td></tr></table>

# %% [markdown]
# # Limitation and Future Works

# %% [markdown]
# **1. Unsupervised learning**\
# The current metric is based on unsupervised learning. Upon successful implementation, as we go along, we will be able to collect more data on the success rate of matching or hire based on our recommendation. From there, we can ehance our metric to include supervised learning for better recommendation in the future.
#
# **2. Adapt to local data**\
# Currently, both dataset are US based data. Next, we need to explore to scrape local data, otherwise collect data through the app.
#
# **3. Include all functions**\
# To include more functions so that the app can cater to wider community.
# FOCUS: General workers or student looking for part-time assignment to earn quick bucks. As there are many platforms to increase efficiency on recuitment for white collars / PMETs / Executive. This app aims to match quickly manpower that are needed urgently such as promoters, buffers, etc. Such roles typically don't require long interview process, thus the chat function allows employer to quickly connect to the job seeker for providing work information.
#
# **4. Skill sets**\
# As we observed earlier in EDA, job descriptions could consist of not only job description but experience, skills, compensation benefits, etc. The information we needed was the skill sets for better matching.
# We need to further clean the data to capture the 'right' skill sets from multiple features.
# Additionally, some function generally require more different skills and given the fast pace changing environment, need to take into consideration maintenance work for updating the set of skills.
